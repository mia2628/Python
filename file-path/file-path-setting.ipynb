# %%
# !move C:\Users\mia26\Downloads\도로교통공단_교통사고다발지역_20191010.csv .
# Out:
#         1개 파일을 이동했습니다.

# %%
# %ls
# Out:
#  C 드라이브의 볼륨에는 이름이 없습니다.
#  볼륨 일련 번호: 44B7-3D4A
#
#  C:\Users\mia26 디렉터리
#
# 2020-03-28  오후 03:56    <DIR>          .
# 2020-03-28  오후 03:56    <DIR>          ..
# 2020-02-23  오후 02:37               118 .bash_history
# 2019-09-03  오후 02:46                43 .condarc
# 2019-09-03  오후 02:45    <DIR>          .config
# 2019-04-24  오후 01:14    <DIR>          .dotnet
# 2019-08-01  오후 11:43    <DIR>          .eclipse
# 2019-05-11  오전 10:00                16 .emulator_console_auth_token
# 2020-02-12  오후 01:13               200 .gitconfig
# 2020-03-28  오후 03:49    <DIR>          .ipynb_checkpoints
# 2020-03-28  오후 02:35    <DIR>          .ipython
# 2019-09-03  오후 02:45    <DIR>          .matplotlib
# 2019-04-27  오후 02:29    <DIR>          .nuget
# 2019-08-08  오후 04:58    <DIR>          .p2
# 2019-08-12  오후 06:15    <DIR>          .templateengine
# 2019-08-01  오후 11:42    <DIR>          .tooling
# 2020-02-18  오후 12:29    <DIR>          .vscode
# ...

# %%
import pandas as pd

# %%
pd.read_csv("도로교통공단_교통사고다발지역_20191010.csv", encoding="cp949")
# Out:
#        사고지역관리번호  사고년도  사고유형구분       위치코드      시도시군구명  \
# 0       2013060  2012  스쿨존어린이   11110001  서울특별시 종로구1
# 1       2013060  2012  스쿨존어린이   11290001  서울특별시 성북구1
# 2       2013060  2012  스쿨존어린이   11290002  서울특별시 성북구2
# 3       2013060  2012  스쿨존어린이   11290003  서울특별시 성북구3
# 4       2013060  2012  스쿨존어린이   11320001  서울특별시 도봉구1
# ...         ...   ...     ...        ...         ...
# 10360   2019066  2018    무단횡단  280641002      경기 파주2
# 10361   2019066  2018    무단횡단  280641003      경기 파주3
# 10362   2019066  2018    무단횡단  280641004      경기 파주4
# 10363   2019066  2018    무단횡단  280941001      경기 구리1
# 10364   2019066  2018    무단횡단  281041001      경기 포천1
#
#                            사고지역위치명  발생건수  사상자수  사망자수  중상자수  경상자수  부상자수  \
# 0           서울특별시 종로구 혜화동(혜화초교 부근)     2     2     0     1     1     0
# 1           서울특별시 성북구 종암동(숭례초교 부근)     2     2     0     0     1     1
# 2        서울특별시 성북구 동소문동7가(정덕초교 부근)     2     2     0     2     0     0
# ...
