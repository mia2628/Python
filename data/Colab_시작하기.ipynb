# %%
# ============================================================
# COLAB ONE-CHUNK CODE
# NSGA-II baseline model
# + target sweep integration (without changing objective/constraint structure)
# + Pareto front visualization with dominated solutions
# + integrated trade-off map across multiple Ao targets
# ------------------------------------------------------------
# 핵심
#   - 목적함수/제약식 구조는 그대로 유지
#   - AO_TARGET 하나만 고정하지 않고 AO_TARGET_GRID를 순회
#   - 각 target에서 NSGA-II를 반복 수행
#   - 결과를 합쳐 cost-Ao 통합 시각화
#   - 대표 target(기본 0.94)에 대해서 상세 진단표 출력
# ============================================================

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ============================================================
# 0) File load
# ============================================================
USE_COLAB_UPLOAD = False

if USE_COLAB_UPLOAD:
    from google.colab import files
    uploaded = files.upload()
    XLSX_PATH = list(uploaded.keys())[0]
else:
    XLSX_PATH = "radar_1000_parts_bom.xlsx"

df = pd.read_excel(XLSX_PATH, sheet_name=0)
print(f"[LOAD] shape = {df.shape}")


# ============================================================
# 1) Column helpers
# ============================================================
def find_col(df, candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

col_part = find_col(df, ["Part_ID"])
col_parent = find_col(df, ["Parent_ID"])
col_level = find_col(df, ["Level"])
col_echelon = find_col(df, ["Maint_Echelon"])
col_fr = find_col(df, ["Failure_Rate"])
col_price = find_col(df, ["Unit_Price_KRW"])
col_transport_cost = find_col(df, ["Transport_Cost_KRW"])
col_lead = find_col(df, ["Total_Lead_Time_H"])
col_transport_time = find_col(df, ["Transport_Time_H"])
col_cm_cost = find_col(df, ["CM_Cost_KRW"])
col_cm_time = find_col(df, ["CM_Time_Hours"])
col_condemn = find_col(df, ["Condemnation_Rate_Pct"])
col_pm = find_col(df, ["PM_Cycle"])

required = [col_part, col_parent, col_level, col_echelon, col_fr]
if any(x is None for x in required):
    raise ValueError({
        "Part_ID": col_part,
        "Parent_ID": col_parent,
        "Level": col_level,
        "Maint_Echelon": col_echelon,
        "Failure_Rate": col_fr
    })

for c in [col_price, col_transport_cost, col_lead, col_transport_time, col_fr, col_cm_cost, col_cm_time, col_condemn]:
    if c is not None:
        df[c] = pd.to_numeric(df[c], errors="coerce")


# ============================================================
# 2) Settings
# ============================================================
YEARS = 2.0
T_OBS_HOURS = YEARS * 365.0 * 24.0
HOURS_PER_YEAR = 365.0 * 24.0

# ------------------------------------------------------------
# target sweep
# ------------------------------------------------------------
AO_TARGET_GRID = [
    0.10, 0.20, 0.30, 0.40, 0.50,
    0.60, 0.70, 0.80, 0.85, 0.90,
    0.92, 0.94
]
REPRESENTATIVE_TARGET = 0.94   # 상세 진단표/대표 Pareto plot 기준
AO_LINES = [0.90, 0.91, 0.92, 0.93, 0.94]

PMIN = 0.15
LONG_LEAD_PERCENTILE = 90
AO_IMPACT_PERCENTILE = 70
LONG_CORE_IMPACT_PERCENTILE = 70

POP = 80
GEN = 200
SEED = 42

AO_COST_PENALTY = 8.0e8
ITEM_COUNT_WEIGHT = 1.0
STOCK_UNIT_WEIGHT = 0.05
h_pre = 0.05

ABS_CAP_SMALL = 3
ABS_CAP_MED = 4
ABS_CAP_LARGE = 6

# ------------------------------------------------------------
# tuned baseline support parameters
# ------------------------------------------------------------
BASELINE_WAIT_FRACTION_BY_ECHELON = {
    "O": 0.75,
    "I": 0.90,
    "D": 1.00,
}
MIN_WAIT_FLOOR_H_BY_ECHELON = {
    "O": 1.0,
    "I": 6.0,
    "D": 24.0,
}

TOPK_PRINT = 15


# ============================================================
# 3) Helpers
# ============================================================
def minmax(x):
    x = np.asarray(x, dtype=float)
    lo, hi = np.nanmin(x), np.nanmax(x)
    if hi - lo < 1e-12:
        return np.zeros_like(x, dtype=float)
    return (x - lo) / (hi - lo)

def parse_level_to_int(v):
    if pd.isna(v):
        return 0
    s = str(v)
    m = re.search(r"(\d+)", s)
    return int(m.group(1)) if m else 0

def map_echelon(v):
    if pd.isna(v):
        return "X"
    s = str(v).strip().lower()

    if any(k in s for k in ["organizational", "operational", "operator", "field", "unit", "line", "o-level", "o level"]):
        return "O"
    if any(k in s for k in ["현장", "운용", "부대", "일선"]):
        return "O"

    if any(k in s for k in ["intermediate", "support", "shop", "base", "i-level", "i level", "direct support"]):
        return "I"
    if any(k in s for k in ["중간", "야전정비", "지원", "정비대"]):
        return "I"

    if any(k in s for k in ["depot", "factory", "overhaul", "sustainment", "d-level", "d level"]):
        return "D"
    if any(k in s for k in ["창정비", "공창", "후방"]):
        return "D"

    if s in ["o", "org", "op"]:
        return "O"
    if s in ["i", "int"]:
        return "I"
    if s in ["d", "dep"]:
        return "D"

    return "X"

def pm_cycle_to_days(v):
    if pd.isna(v):
        return np.nan

    if isinstance(v, (int, float, np.integer, np.floating)):
        x = float(v)
        if x <= 0:
            return np.nan
        return x if x <= 400 else np.nan

    s = str(v).strip().lower()
    if s in ["", "nan", "none", "null"]:
        return np.nan

    if "분기" in s or "quarter" in s:
        return 365.0 / 4.0
    if "반기" in s or "semi" in s or "half" in s:
        return 365.0 / 2.0
    if "연" in s or "annual" in s or "year" in s:
        return 365.0

    m = re.search(r"(\d+(\.\d+)?)\s*(day|days|d|month|months|m|year|years|y)", s)
    if m:
        val = float(m.group(1))
        unit = m.group(3)
        if unit in ["day", "days", "d"]:
            return val
        if unit in ["month", "months", "m"]:
            return val * 30.4167
        if unit in ["year", "years", "y"]:
            return val * 365.0

    m2 = re.search(r"(\d+(\.\d+)?)", s)
    if m2:
        return float(m2.group(1))

    return np.nan

def poisson_tail_prob(mu, s):
    mu = float(max(mu, 0.0))
    s = int(max(s, 0))
    if mu < 1e-12:
        return 0.0

    term = math.exp(-mu)
    cdf = term
    for k in range(1, s + 1):
        term *= mu / k
        cdf += term
    tail = 1.0 - cdf
    return min(max(tail, 0.0), 1.0)

def long_dynamic_cap_from_lambda(lam_2y):
    base = int(np.ceil(lam_2y))
    if lam_2y < 1.0:
        buffer_i = 1
        abs_cap_i = ABS_CAP_SMALL
    elif lam_2y < 2.5:
        buffer_i = 1
        abs_cap_i = ABS_CAP_MED
    else:
        buffer_i = 2
        abs_cap_i = ABS_CAP_LARGE
    total_cap_i = min(base + buffer_i, abs_cap_i)
    return max(total_cap_i, 1)

def solution_signature(y_manage, sO, sI, sD):
    return (
        "Y:" + ",".join(map(str, y_manage.astype(int).tolist())) +
        "|O:" + ",".join(map(str, sO.astype(int).tolist())) +
        "|I:" + ",".join(map(str, sI.astype(int).tolist())) +
        "|D:" + ",".join(map(str, sD.astype(int).tolist()))
    )


# ============================================================
# 4) Raw arrays
# ============================================================
n_all = df.shape[0]

part_id_all = df[col_part].astype(str).to_numpy()
parent_id_all = df[col_parent].astype(str).to_numpy()
level_num_all = df[col_level].apply(parse_level_to_int).to_numpy(int)
echelon_cat_all = df[col_echelon].apply(map_echelon).to_numpy()

FR_all = df[col_fr].fillna(0).clip(lower=0).to_numpy(float)

unit_price_all = df[col_price].fillna(0).clip(lower=0).to_numpy(float) if col_price else np.zeros(n_all)
transport_cost_all = df[col_transport_cost].fillna(0).clip(lower=0).to_numpy(float) if col_transport_cost else np.zeros(n_all)
proc_cost_all = unit_price_all + transport_cost_all

lead_raw_all = df[col_lead].to_numpy(float) if col_lead else np.full(n_all, np.nan)
transport_time_all = df[col_transport_time].fillna(0).clip(lower=0).to_numpy(float) if col_transport_time else np.zeros(n_all)
lead_all = (
    pd.Series(lead_raw_all)
    .fillna(pd.Series(transport_time_all))
    .fillna(0)
    .clip(lower=0)
    .to_numpy(float)
)

cm_cost_all = df[col_cm_cost].fillna(0).clip(lower=0).to_numpy(float) if col_cm_cost else np.zeros(n_all)
cm_time_all = df[col_cm_time].fillna(0).clip(lower=0).to_numpy(float) if col_cm_time else np.zeros(n_all)

if col_condemn:
    condemn_all = df[col_condemn].fillna(0).clip(lower=0, upper=100).to_numpy(float) / 100.0
else:
    condemn_all = np.zeros(n_all, dtype=float)

if col_pm:
    pm_days_all = df[col_pm].apply(pm_cycle_to_days).to_numpy(float)
else:
    pm_days_all = np.full(n_all, np.nan)

pm_freq_all = np.where(np.isfinite(pm_days_all) & (pm_days_all > 0), 365.0 / pm_days_all, 0.0)
pm_norm_all = np.clip(pm_freq_all / 4.0, 0.0, 1.0)

gamma_max = 0.10
delta_max = 0.05
gamma_all = gamma_max * pm_norm_all
delta_all = delta_max * pm_norm_all


# ============================================================
# 5) Build BOM structure
# ============================================================
part_to_idx = {pid: i for i, pid in enumerate(part_id_all)}

children_map = {i: [] for i in range(n_all)}
for i in range(n_all):
    p = parent_id_all[i]
    if pd.notna(p):
        p = str(p)
        if p in part_to_idx:
            children_map[part_to_idx[p]].append(i)

is_leaf_all = np.array([len(children_map[i]) == 0 for i in range(n_all)], dtype=bool)

def get_ancestor_chain(idx):
    chain_rev = [idx]
    seen = {idx}
    cur_parent = parent_id_all[idx]
    hop = 0
    while pd.notna(cur_parent) and str(cur_parent) not in ["", "nan", "None", "null"]:
        cur_parent = str(cur_parent)
        if cur_parent not in part_to_idx:
            break
        pidx = part_to_idx[cur_parent]
        if pidx in seen:
            break
        chain_rev.append(pidx)
        seen.add(pidx)
        cur_parent = parent_id_all[pidx]
        hop += 1
        if hop > 30:
            break
    return list(reversed(chain_rev))

all_ancestor_chains = [get_ancestor_chain(i) for i in range(n_all)]
depth_all = np.array([len(ch) for ch in all_ancestor_chains], dtype=int)


# ============================================================
# 6) Real spare-demand part selection
# ============================================================
has_physical_attr = (
    (unit_price_all > 0) |
    (cm_time_all > 0) |
    (lead_all > 0)
)

spare_demand_mask = (
    (level_num_all >= 3) &
    is_leaf_all &
    (FR_all > 0) &
    has_physical_attr
)

if spare_demand_mask.sum() < 20:
    spare_demand_mask = (
        (level_num_all >= 3) &
        (FR_all > 0) &
        has_physical_attr
    )

spare_idx = np.where(spare_demand_mask)[0]
print(f"[SPARE-DEMAND FILTER] count = {len(spare_idx)} / {n_all}")

if len(spare_idx) == 0:
    raise ValueError("No real spare-demand parts found.")


# ============================================================
# 7) Common arrays
# ============================================================
annual_fr_sp = FR_all[spare_idx] * (1.0 - gamma_all[spare_idx])
lam_2y_sp = annual_fr_sp * YEARS

proc_cost_sp = proc_cost_all[spare_idx]
lead_sp = lead_all[spare_idx]
transport_sp = transport_time_all[spare_idx]
cm_cost_sp = cm_cost_all[spare_idx]
cm_time_sp = cm_time_all[spare_idx]
condemn_sp = condemn_all[spare_idx]
delta_sp = delta_all[spare_idx]
level_sp = level_num_all[spare_idx]
depth_sp = depth_all[spare_idx]
echelon_sp = echelon_cat_all[spare_idx]
part_id_sp = part_id_all[spare_idx]
parent_id_sp = parent_id_all[spare_idx]
chains_sp = [all_ancestor_chains[i] for i in spare_idx]

# sibling normalization
parent_group_map = {}
for local_idx, global_idx in enumerate(spare_idx):
    p = parent_id_all[global_idx]
    p = str(p) if pd.notna(p) else f"ROOT_{part_id_all[global_idx]}"
    parent_group_map.setdefault(p, []).append(local_idx)

lambda_eff_sp = annual_fr_sp.copy()
for p, members in parent_group_map.items():
    if len(members) <= 1:
        continue
    fr_sub = annual_fr_sp[members]
    total = fr_sub.sum()
    if total > 1e-12:
        shares = fr_sub / total
        lambda_eff_sp[members] = total * shares / len(members) * 1.2
    else:
        lambda_eff_sp[members] = annual_fr_sp[members]

def node_diag_contrib(level_value):
    if level_value <= 1:
        return 0.10
    if level_value == 2:
        return 0.18
    if level_value == 3:
        return 0.35
    if level_value == 4:
        return 0.55
    if level_value == 5:
        return 0.80
    return 1.00

T_diag_sp = np.zeros(len(spare_idx), dtype=float)
for k, chain in enumerate(chains_sp):
    t = 0.0
    for node_idx in chain:
        lv = level_num_all[node_idx]
        t += node_diag_contrib(lv)
    T_diag_sp[k] = t

T_reminst_sp = 0.35 * np.maximum(cm_time_sp, 1.0)
T_repair_sp = 0.65 * cm_time_sp * (1.0 - delta_sp)

for i, e in enumerate(echelon_sp):
    if e == "O":
        T_reminst_sp[i] *= 0.85
        T_repair_sp[i] *= 0.75
    elif e == "I":
        T_reminst_sp[i] *= 1.00
        T_repair_sp[i] *= 1.00
    elif e == "D":
        T_reminst_sp[i] *= 1.15
        T_repair_sp[i] *= 1.25

T_restore_intrinsic_sp = T_reminst_sp + (1.0 - condemn_sp) * T_repair_sp

T_issue_O_sp = np.full(len(spare_idx), 0.3, dtype=float)
T_issue_I_sp = np.maximum(0.8, np.minimum(4.0, 0.25 * np.maximum(transport_sp, 1.0)))
T_issue_D_sp = np.maximum(1.5, np.minimum(8.0, 0.45 * np.maximum(transport_sp, 1.0)))

baseline_wait_sp = np.zeros(len(spare_idx), dtype=float)
for i, e in enumerate(echelon_sp):
    frac = BASELINE_WAIT_FRACTION_BY_ECHELON.get(e, 0.35)
    floor = MIN_WAIT_FLOOR_H_BY_ECHELON.get(e, 2.0)
    baseline_wait_sp[i] = max(floor, frac * lead_sp[i])

print(
    f"[TIME SUMMARY] "
    f"diag mean={T_diag_sp.mean():.2f}h | "
    f"baseline wait mean={baseline_wait_sp.mean():.2f}h | "
    f"restore mean={T_restore_intrinsic_sp.mean():.2f}h"
)


# ============================================================
# 8) Candidate screening
# ============================================================
p_need_sp = 1.0 - np.exp(-lam_2y_sp)

thr_lead = float(np.nanpercentile(lead_sp, LONG_LEAD_PERCENTILE))
is_long_sp = (lead_sp >= thr_lead)

impact_sp = lambda_eff_sp * np.maximum(T_diag_sp + baseline_wait_sp + T_restore_intrinsic_sp, 1e-9) / HOURS_PER_YEAR
thr_impact = float(np.nanpercentile(impact_sp, AO_IMPACT_PERCENTILE))
is_high_impact_sp = (impact_sp >= thr_impact)

candidate_mask = (p_need_sp >= PMIN) | is_high_impact_sp | is_long_sp
candidate_idx_local = np.where(candidate_mask)[0]

print("[CANDIDATE SCREENING]")
print(f"  PMIN = {PMIN:.2f}")
print(f"  long-lead threshold p{LONG_LEAD_PERCENTILE} = {thr_lead:.2f}h")
print(f"  impact threshold p{AO_IMPACT_PERCENTILE} = {thr_impact:.6f}")
print(f"  candidate spare-demand parts = {len(candidate_idx_local)} / {len(spare_idx)}")

if len(candidate_idx_local) == 0:
    raise ValueError("No candidate spare-demand parts after screening.")

part_id_c = part_id_sp[candidate_idx_local]
parent_id_c = parent_id_sp[candidate_idx_local]
level_c = level_sp[candidate_idx_local]
depth_c = depth_sp[candidate_idx_local]
echelon_c = echelon_sp[candidate_idx_local]

annual_fr_c = annual_fr_sp[candidate_idx_local]
lambda_eff_c = lambda_eff_sp[candidate_idx_local]
lam_2y_c = lam_2y_sp[candidate_idx_local]
proc_cost_c = proc_cost_sp[candidate_idx_local]
lead_c = lead_sp[candidate_idx_local]
cm_cost_c = cm_cost_sp[candidate_idx_local]

T_diag_c = T_diag_sp[candidate_idx_local]
T_reminst_c = T_reminst_sp[candidate_idx_local]
T_repair_c = T_repair_sp[candidate_idx_local]
T_restore_intrinsic_c = T_restore_intrinsic_sp[candidate_idx_local]
T_issue_O_c = T_issue_O_sp[candidate_idx_local]
T_issue_I_c = T_issue_I_sp[candidate_idx_local]
T_issue_D_c = T_issue_D_sp[candidate_idx_local]
baseline_wait_c = baseline_wait_sp[candidate_idx_local]

p_need_c = p_need_sp[candidate_idx_local]
impact_c = impact_sp[candidate_idx_local]
is_long_c = is_long_sp[candidate_idx_local]

m_cand = len(candidate_idx_local)
long_idx_c = np.where(is_long_c)[0]

if len(long_idx_c) > 0:
    long_core_thr = float(np.nanpercentile(impact_c[long_idx_c], LONG_CORE_IMPACT_PERCENTILE))
else:
    long_core_thr = 0.0

prebuy_flag_c = np.zeros(m_cand, dtype=bool)
protection_flag_c = np.zeros(m_cand, dtype=bool)
for j in range(m_cand):
    if is_long_c[j] and ((p_need_c[j] >= PMIN) or (impact_c[j] >= thr_impact)):
        prebuy_flag_c[j] = True
    if is_long_c[j] and (impact_c[j] >= long_core_thr):
        protection_flag_c[j] = True

impact_norm_c = minmax(impact_c)
critical_weight_c = np.where(
    impact_norm_c >= 0.80, 1.00,
    np.where(impact_norm_c >= 0.50, 0.45, 0.15)
)

mu_pipe_nom_c = lambda_eff_c * (baseline_wait_c + T_restore_intrinsic_c) / HOURS_PER_YEAR

stock_cap_c = np.zeros(m_cand, dtype=int)
for i in range(m_cand):
    if is_long_c[i]:
        stock_cap_c[i] = long_dynamic_cap_from_lambda(lam_2y_c[i])
    else:
        stock_cap_c[i] = max(
            1,
            int(np.ceil(mu_pipe_nom_c[i] + 4.0 * np.sqrt(max(mu_pipe_nom_c[i], 1e-9)) + 2.0))
        )

prot_floor_c = np.where(protection_flag_c, 1, 0).astype(int)
BASE_MAINT_SPEND = float(np.sum(annual_fr_c * cm_cost_c * YEARS))

print(f"[BASE_MAINT_SPEND] {BASE_MAINT_SPEND:,.0f} KRW")


# ============================================================
# 9) Evaluate one solution
# ============================================================
def evaluate_one_solution(y_manage, sO, sI, sD):
    y_manage = np.asarray(y_manage, dtype=int)
    sO = np.asarray(sO, dtype=int)
    sI = np.asarray(sI, dtype=int)
    sD = np.asarray(sD, dtype=int)

    sO = y_manage * sO
    sI = y_manage * sI
    sD = y_manage * sD

    for i in range(m_cand):
        if y_manage[i] > 0 and prot_floor_c[i] > 0:
            if sO[i] + sI[i] + sD[i] < 1:
                if echelon_c[i] == "O":
                    sO[i] = 1
                elif echelon_c[i] == "I":
                    sI[i] = 1
                else:
                    sD[i] = 1

    total_stock = sO + sI + sD
    for i in range(m_cand):
        if total_stock[i] > stock_cap_c[i]:
            excess = total_stock[i] - stock_cap_c[i]
            reduc = min(sD[i], excess)
            sD[i] -= reduc
            excess -= reduc
            if excess > 0:
                reduc = min(sI[i], excess)
                sI[i] -= reduc
                excess -= reduc
            if excess > 0:
                reduc = min(sO[i], excess)
                sO[i] -= reduc
                excess -= reduc
        total_stock[i] = sO[i] + sI[i] + sD[i]

    p_short_O = np.zeros(m_cand, dtype=float)
    p_short_I = np.zeros(m_cand, dtype=float)
    p_short_D = np.zeros(m_cand, dtype=float)

    for i in range(m_cand):
        if y_manage[i] == 0:
            p_short_O[i] = 1.0
            p_short_I[i] = 1.0
            p_short_D[i] = 1.0
            continue

        muO = lambda_eff_c[i] * T_issue_O_c[i] / HOURS_PER_YEAR
        muI = lambda_eff_c[i] * T_issue_I_c[i] / HOURS_PER_YEAR
        muD = lambda_eff_c[i] * T_issue_D_c[i] / HOURS_PER_YEAR

        p_short_O[i] = poisson_tail_prob(muO, sO[i])
        p_short_I[i] = poisson_tail_prob(muI, sI[i])
        p_short_D[i] = poisson_tail_prob(muD, sD[i])

    improved_wait = (
        (1.0 - p_short_O) * T_issue_O_c
        + p_short_O * (1.0 - p_short_I) * T_issue_I_c
        + p_short_O * p_short_I * (1.0 - p_short_D) * T_issue_D_c
        + p_short_O * p_short_I * p_short_D * baseline_wait_c
    )

    T_wait_per_failure = np.where(
        y_manage > 0,
        np.minimum(baseline_wait_c, improved_wait),
        baseline_wait_c
    )

    DT_diag = np.sum(lambda_eff_c * T_diag_c * critical_weight_c)
    DT_restore = np.sum(lambda_eff_c * T_restore_intrinsic_c * critical_weight_c)
    DT_wait = np.sum(lambda_eff_c * T_wait_per_failure * critical_weight_c)
    DT_total = DT_diag + DT_wait + DT_restore

    Ao = float(T_OBS_HOURS / (T_OBS_HOURS + DT_total))

    stock_cost = float(np.sum(total_stock * proc_cost_c))
    hold_cost = float(h_pre * np.sum(total_stock * proc_cost_c))
    total_cost = stock_cost + hold_cost + BASE_MAINT_SPEND

    managed_items = int(np.sum((y_manage > 0) & (total_stock > 0)))
    total_stock_units = int(np.sum(total_stock))
    prebuy_selected = int(np.sum((y_manage > 0) & prebuy_flag_c))
    protection_selected = int(np.sum((total_stock > 0) & protection_flag_c))

    return {
        "Ao": Ao,
        "DT_diag_h": float(DT_diag),
        "DT_wait_h": float(DT_wait),
        "DT_restore_h": float(DT_restore),
        "DT_total_h": float(DT_total),
        "T_wait_per_failure": T_wait_per_failure,
        "total_cost": total_cost,
        "stock_cost": stock_cost,
        "hold_cost": hold_cost,
        "sO": sO,
        "sI": sI,
        "sD": sD,
        "total_stock": total_stock,
        "managed_items": managed_items,
        "total_stock_units": total_stock_units,
        "prebuy_selected": prebuy_selected,
        "protection_selected": protection_selected,
    }


# ============================================================
# 10) NSGA evaluation + utilities
# ============================================================
def eval_nsga(pop_mat, ao_target):
    pop = pop_mat.shape[0]

    Y = np.clip(np.rint(pop_mat[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop_mat[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop_mat[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop_mat[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    F = np.zeros((pop, 3), dtype=float)
    Ao = np.zeros(pop, dtype=float)

    for p in range(pop):
        sim = evaluate_one_solution(Y[p], SO[p], SI[p], SD[p])

        Ao[p] = sim["Ao"]
        ao_shortfall = max(0.0, ao_target - sim["Ao"])

        F1 = sim["total_cost"] + AO_COST_PENALTY * (ao_shortfall ** 2)
        F2 = ao_shortfall
        F3 = ITEM_COUNT_WEIGHT * sim["managed_items"] + STOCK_UNIT_WEIGHT * sim["total_stock_units"]

        F[p, 0] = F1
        F[p, 1] = F2
        F[p, 2] = F3

    return F, Ao

def dominates(a, b):
    return np.all(a <= b) and np.any(a < b)

def fast_non_dominated_sort(F):
    n = F.shape[0]
    S = [[] for _ in range(n)]
    n_dom = np.zeros(n, dtype=int)
    fronts = [[]]

    for p in range(n):
        for q in range(n):
            if p == q:
                continue
            if dominates(F[p], F[q]):
                S[p].append(q)
            elif dominates(F[q], F[p]):
                n_dom[p] += 1
        if n_dom[p] == 0:
            fronts[0].append(p)

    i = 0
    while fronts[i]:
        nxt = []
        for p in fronts[i]:
            for q in S[p]:
                n_dom[q] -= 1
                if n_dom[q] == 0:
                    nxt.append(q)
        i += 1
        fronts.append(nxt)

    fronts.pop()
    return fronts

def crowding_distance(F, front):
    mobj = F.shape[1]
    dist = np.zeros(len(front), dtype=float)
    if len(front) == 0:
        return dist

    idx = np.array(front, dtype=int)
    for j in range(mobj):
        vals = F[idx, j]
        order = np.argsort(vals)
        dist[order[0]] = np.inf
        dist[order[-1]] = np.inf

        vmin, vmax = vals[order[0]], vals[order[-1]]
        if vmax - vmin < 1e-12:
            continue

        for k in range(1, len(front) - 1):
            dist[order[k]] += (vals[order[k+1]] - vals[order[k-1]]) / (vmax - vmin)
    return dist

def rank_and_crowd(F):
    fronts = fast_non_dominated_sort(F)
    rank = np.empty(F.shape[0], dtype=int)
    crowd = np.zeros(F.shape[0], dtype=float)

    for rnk, front in enumerate(fronts):
        for i in front:
            rank[i] = rnk
        cd = crowding_distance(F, front)
        for t, i in enumerate(front):
            crowd[i] = cd[t]
    return rank, crowd, fronts

def tournament_select(rank, crowd, rng):
    i, j = rng.integers(0, len(rank), size=2)
    if rank[i] < rank[j]:
        return i
    if rank[j] < rank[i]:
        return j
    return i if crowd[i] > crowd[j] else j

def uniform_crossover(p1, p2, rng):
    mask = rng.random(p1.shape[0]) < 0.5
    c1, c2 = p1.copy(), p2.copy()
    c1[mask] = p2[mask]
    c2[mask] = p1[mask]
    return c1, c2


# ============================================================
# 11) Run NSGA-II (single target)
# ============================================================
def run_nsga_single_target(ao_target, seed=42):
    rng = np.random.default_rng(seed)

    n_vars = m_cand + 3 * m_cand
    mut_p = float(np.clip(20.0 / max(n_vars, 1), 0.01, 0.06))

    pop = np.zeros((POP, n_vars), dtype=float)

    seed_prob = np.clip(
        0.12 + 0.55 * (
            0.45 * minmax(p_need_c) +
            0.35 * minmax(impact_c) +
            0.20 * is_long_c.astype(float)
        ),
        0.08, 0.85
    )

    for k in range(POP):
        for j in range(m_cand):
            pop[k, j] = 1 if rng.random() < seed_prob[j] else 0

        for j in range(m_cand):
            yj = int(pop[k, j])
            ub = stock_cap_c[j]
            if yj == 0:
                pop[k, m_cand + j] = 0
                pop[k, m_cand + m_cand + j] = 0
                pop[k, m_cand + 2*m_cand + j] = 0
            else:
                sO0, sI0, sD0 = 0, 0, 0
                if echelon_c[j] == "O":
                    sO0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                elif echelon_c[j] == "I":
                    sI0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                else:
                    sD0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                pop[k, m_cand + j] = sO0
                pop[k, m_cand + m_cand + j] = sI0
                pop[k, m_cand + 2*m_cand + j] = sD0

    def repair_solution(v):
        y = np.clip(np.rint(v[:m_cand]), 0, 1).astype(int)
        sO = np.clip(np.rint(v[m_cand:m_cand+m_cand]), 0, None).astype(int)
        sI = np.clip(np.rint(v[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
        sD = np.clip(np.rint(v[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

        for j in range(m_cand):
            if y[j] == 0:
                sO[j] = 0
                sI[j] = 0
                sD[j] = 0
            total = sO[j] + sI[j] + sD[j]
            cap = stock_cap_c[j]
            if total > cap:
                excess = total - cap
                reduc = min(sD[j], excess)
                sD[j] -= reduc
                excess -= reduc
                if excess > 0:
                    reduc = min(sI[j], excess)
                    sI[j] -= reduc
                    excess -= reduc
                if excess > 0:
                    reduc = min(sO[j], excess)
                    sO[j] -= reduc
                    excess -= reduc

        return np.concatenate([y, sO, sI, sD]).astype(float)

    def mutate(child):
        y = child.copy()

        msk_y = rng.random(m_cand) < mut_p
        for j in range(m_cand):
            if msk_y[j]:
                y[j] = 1.0 - round(y[j])

        for block in range(3):
            start = m_cand + block * m_cand
            msk_s = rng.random(m_cand) < mut_p
            for j in range(m_cand):
                idx = start + j
                if msk_s[j]:
                    ub = stock_cap_c[j]
                    y[idx] = rng.integers(0, ub + 1)

        y = repair_solution(y)
        return y

    for gen in range(GEN):
        F, Ao = eval_nsga(pop, ao_target)
        rank, crowd, fronts = rank_and_crowd(F)

        off = []
        while len(off) < POP:
            p1 = tournament_select(rank, crowd, rng)
            p2 = tournament_select(rank, crowd, rng)
            c1, c2 = uniform_crossover(pop[p1], pop[p2], rng)
            c1 = mutate(c1)
            c2 = mutate(c2)
            off.append(c1)
            if len(off) < POP:
                off.append(c2)
        off = np.array(off, dtype=float)

        comb = np.vstack([pop, off])
        F_c, Ao_c = eval_nsga(comb, ao_target)
        rank_c, crowd_c, fronts_c = rank_and_crowd(F_c)

        new_idx = []
        for front in fronts_c:
            if len(new_idx) + len(front) <= POP:
                new_idx.extend(front)
            else:
                front = np.array(front, dtype=int)
                order = np.argsort(-crowd_c[front])
                need = POP - len(new_idx)
                new_idx.extend(front[order[:need]].tolist())
                break

        pop = comb[np.array(new_idx, dtype=int)]

        if (gen + 1) % 10 == 0:
            Fp, Aop = eval_nsga(pop, ao_target)
            managed_counts = []
            for row in pop:
                ytmp = np.clip(np.rint(row[:m_cand]), 0, 1).astype(int)
                managed_counts.append(int(np.sum(ytmp)))
            print(
                f"[NSGA | target={ao_target:.2f}] Gen {gen+1}/{GEN} | "
                f"best Ao={float(np.max(Aop)):.4f} | "
                f"share(Ao>={ao_target:.2f})={float(np.mean(Aop >= ao_target)):.2f} | "
                f"mean managed={float(np.mean(managed_counts)):.1f}"
            )

    F, Ao = eval_nsga(pop, ao_target)
    cost = F[:, 0]

    F2d = np.column_stack([cost, -Ao])
    fronts2d = fast_non_dominated_sort(F2d)
    pareto_idx = np.array(fronts2d[0], dtype=int)
    dominated_idx = np.setdiff1d(np.arange(len(cost)), pareto_idx)

    order = np.argsort(cost[pareto_idx])
    p_idx = pareto_idx[order]

    best_idx = int(np.argmax(Ao))
    x = pop[best_idx]

    Y = np.clip(np.rint(x[:m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(x[m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(x[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(x[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    best_sim = evaluate_one_solution(Y, SO, SI, SD)

    return {
        "target_ao": ao_target,
        "pop": pop,
        "F": F,
        "Ao": Ao,
        "cost": cost,
        "pareto_idx": pareto_idx,
        "dominated_idx": dominated_idx,
        "p_cost": cost[p_idx],
        "p_Ao": Ao[p_idx],
        "best_Ao": float(np.max(Ao)),
        "share_ge_target": float(np.mean(Ao >= ao_target)),
        "best_sim": best_sim,
        "best_y": Y,
        "best_sO": SO,
        "best_sI": SI,
        "best_sD": SD,
    }


# ============================================================
# 12) Sweep targets
# ============================================================
def collect_run_dataframe(res_single):
    rows = []

    pop = res_single["pop"]
    target_ao = res_single["target_ao"]

    Y = np.clip(np.rint(pop[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    pareto_set = set(res_single["pareto_idx"].tolist())

    for i in range(pop.shape[0]):
        sim = evaluate_one_solution(Y[i], SO[i], SI[i], SD[i])
        rows.append({
            "target_ao": float(target_ao),
            "solution_id_within_target": int(i),
            "Ao": float(sim["Ao"]),
            "total_cost": float(sim["total_cost"]),
            "stock_cost": float(sim["stock_cost"]),
            "hold_cost": float(sim["hold_cost"]),
            "DT_diag_h": float(sim["DT_diag_h"]),
            "DT_wait_h": float(sim["DT_wait_h"]),
            "DT_restore_h": float(sim["DT_restore_h"]),
            "DT_total_h": float(sim["DT_total_h"]),
            "managed_items": int(sim["managed_items"]),
            "total_stock_units": int(sim["total_stock_units"]),
            "is_pareto_2d": int(i in pareto_set),
            "signature": solution_signature(Y[i], sim["sO"], sim["sI"], sim["sD"]),
        })
    return pd.DataFrame(rows)

def run_target_sweep(target_grid, base_seed=42):
    all_result_map = {}
    all_df = []

    for idx, target in enumerate(target_grid):
        print("\n" + "=" * 70)
        print(f"[TARGET SWEEP] RUN START | target_ao = {target:.2f}")
        print("=" * 70)

        # 타겟별 seed를 조금 다르게 주어 해 다양성 확보
        run_seed = int(base_seed + idx * 17)

        res_t = run_nsga_single_target(ao_target=target, seed=run_seed)
        all_result_map[round(target, 6)] = res_t

        df_t = collect_run_dataframe(res_t)
        all_df.append(df_t)

        print(f"[TARGET SUMMARY] target={target:.2f} | best Ao={res_t['best_Ao']:.4f} | share_ge_target={res_t['share_ge_target']:.2f}")

    if len(all_df) == 0:
        return all_result_map, pd.DataFrame()

    df_all = pd.concat(all_df, ignore_index=True)
    return all_result_map, df_all


# ============================================================
# 13) Deduplicate integrated solutions
# ============================================================
def deduplicate_integrated_df(df_all):
    if df_all.empty:
        return df_all.copy()

    # 같은 정책이 여러 target에서 반복 등장할 수 있으므로 signature 기준 중복 제거
    # cost/Ao가 높은 target에서 재발견되더라도 정책 자체가 같으면 하나만 유지
    df_unique = (
        df_all.sort_values(
            by=["Ao", "total_cost", "target_ao"],
            ascending=[False, True, True]
        )
        .drop_duplicates(subset=["signature"])
        .reset_index(drop=True)
    )
    return df_unique


# ============================================================
# 14) Visualizations
# ============================================================
def plot_representative_pareto(res_single):
    plt.figure(figsize=(9, 6))

    plt.scatter(
        res_single["cost"][res_single["dominated_idx"]],
        res_single["Ao"][res_single["dominated_idx"]],
        s=18,
        alpha=0.35,
        color="gray",
        label="Dominated solutions"
    )

    plt.scatter(
        res_single["p_cost"],
        res_single["p_Ao"],
        s=34,
        alpha=0.95,
        color="#1E88E5",
        label="Pareto solutions"
    )
    plt.plot(
        res_single["p_cost"],
        res_single["p_Ao"],
        linewidth=2.2,
        color="#1E88E5",
        label="Pareto front"
    )

    for ao_line in AO_LINES:
        color = "#2E7D32" if ao_line < res_single["target_ao"] else "#6A1B9A"
        style = "--" if ao_line < res_single["target_ao"] else "-."
        plt.axhline(
            ao_line,
            linestyle=style,
            linewidth=1.1,
            color=color,
            alpha=0.85
        )
        plt.text(
            x=np.nanmin(res_single["cost"]) * 1.001,
            y=ao_line + 0.0008,
            s=f"Ao={ao_line:.2f}",
            fontsize=8,
            color=color
        )

    plt.xlabel("Total Cost (KRW)")
    plt.ylabel("Ao")
    plt.title(f"Representative Pareto-front (target={res_single['target_ao']:.2f})")
    plt.legend(loc="best")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"],
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map_percent(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"] * 100.0,
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line * 100.0,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao (%)")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map (%)")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_targetwise_pareto_overlay(result_map):
    plt.figure(figsize=(10, 6))

    cmap = plt.cm.viridis
    targets_sorted = sorted(result_map.keys())

    for idx, t in enumerate(targets_sorted):
        res_t = result_map[t]
        color = cmap(idx / max(len(targets_sorted) - 1, 1))

        plt.scatter(
            res_t["p_Ao"],
            res_t["p_cost"],
            s=18,
            alpha=0.75,
            color=color,
            label=f"target={t:.2f}"
        )
        plt.plot(
            res_t["p_Ao"],
            res_t["p_cost"],
            linewidth=1.1,
            alpha=0.75,
            color=color
        )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=0.9,
            alpha=0.5
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Overlay of Pareto fronts by target")
    plt.grid(True, alpha=0.25)
    plt.legend(loc="best", fontsize=8)
    plt.tight_layout()
    plt.show()


# ============================================================
# 15) Run sweep
# ============================================================
result_map, df_all_runs = run_target_sweep(AO_TARGET_GRID, base_seed=SEED)

df_integrated = deduplicate_integrated_df(df_all_runs)

print("\n" + "=" * 70)
print("[INTEGRATED SUMMARY]")
print(f"All collected solutions        = {len(df_all_runs)}")
print(f"Unique integrated solutions    = {len(df_integrated)}")
print("=" * 70)

summary_by_target_basic = (
    df_all_runs.groupby("target_ao")
    .agg(
        n_solutions=("Ao", "count"),
        ao_min=("Ao", "min"),
        ao_max=("Ao", "max"),
        cost_min=("total_cost", "min"),
        cost_max=("total_cost", "max"),
        wait_min=("DT_wait_h", "min"),
        wait_max=("DT_wait_h", "max"),
        managed_min=("managed_items", "min"),
        managed_max=("managed_items", "max"),
    )
    .reset_index()
)

share_df = (
    df_all_runs.groupby("target_ao")
    .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
    .reset_index(name="share_ge_target")
)

summary_by_target = (
    summary_by_target_basic
    .merge(share_df, on="target_ao", how="left")
    .sort_values("target_ao")
    .reset_index(drop=True)
)

print("\n[TARGET-WISE SUMMARY]")
print(summary_by_target.to_string(index=False))

rep_key = round(REPRESENTATIVE_TARGET, 6)
if rep_key not in result_map:
    raise ValueError(f"Representative target {REPRESENTATIVE_TARGET:.2f} is not in AO_TARGET_GRID.")

res = result_map[rep_key]


# ============================================================
# 16) Final representative summary
# ============================================================
print("\n==============================")
print("[FINAL SUMMARY | REPRESENTATIVE TARGET]")
print(f"Representative Target = {res['target_ao']:.2f}")
print(f"Best Ao = {res['best_Ao']:.4f}")
print(f"Share(Ao >= {res['target_ao']:.2f}) = {res['share_ge_target']:.2f}")
print(f"Candidate spare-demand parts = {m_cand}")
print("==============================")

b = res["best_sim"]
print("\n[BEST POLICY | REPRESENTATIVE TARGET]")
print(f"Ao                  = {b['Ao']:.4f}")
print(f"DT_diag_h           = {b['DT_diag_h']:.2f}")
print(f"DT_wait_h           = {b['DT_wait_h']:.2f}")
print(f"DT_restore_h        = {b['DT_restore_h']:.2f}")
print(f"DT_total_h          = {b['DT_total_h']:.2f}")
print(f"stock_cost          = {b['stock_cost']:.0f}")
print(f"hold_cost           = {b['hold_cost']:.0f}")
print(f"total_cost          = {b['total_cost']:.0f}")
print(f"managed parts       = {b['managed_items']}")
print(f"total stock units   = {b['total_stock_units']}")
print(f"selected pre-buy    = {b['prebuy_selected']}")
print(f"selected protection = {b['protection_selected']}")


# ============================================================
# 17) Plots
# ============================================================
plot_representative_pareto(res)
plot_integrated_tradeoff_map(df_integrated)
plot_integrated_tradeoff_map_percent(df_integrated)
plot_targetwise_pareto_overlay(result_map)


# ============================================================
# 18) Diagnostics table for representative target
# ============================================================
diag_df = pd.DataFrame({
    "Part_ID": part_id_c,
    "Parent_ID": parent_id_c,
    "Level": level_c,
    "Depth": depth_c,
    "Maint_Echelon": echelon_c,
    "annual_FR": annual_fr_c,
    "lambda_eff_2y": lam_2y_c,
    "p_need_2y": p_need_c,
    "baseline_wait_h": baseline_wait_c,
    "T_diag_h": T_diag_c,
    "T_restore_h": T_restore_intrinsic_c,
    "ao_impact": impact_c,
    "is_long_lead": is_long_c.astype(int),
    "prebuy_flag": prebuy_flag_c.astype(int),
    "protection_flag": protection_flag_c.astype(int),
    "selected_manage": res["best_y"].astype(int),
    "sO_best": res["best_sim"]["sO"].astype(int),
    "sI_best": res["best_sim"]["sI"].astype(int),
    "sD_best": res["best_sim"]["sD"].astype(int),
    "total_stock_best": res["best_sim"]["total_stock"].astype(int),
    "wait_per_failure_best": res["best_sim"]["T_wait_per_failure"],
    "unit_proc_cost": proc_cost_c,
    "critical_weight": critical_weight_c
})

print("\n[TOP selected managed parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 1]
    .sort_values(["wait_per_failure_best", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP unmanaged but high baseline-wait parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 0]
    .sort_values(["baseline_wait_h", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP protection candidates | representative target]")
print(
    diag_df.loc[diag_df["protection_flag"] == 1]
    .sort_values(["ao_impact", "baseline_wait_h"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)
# Out:
# [LOAD] shape = (1000, 31)
# [SPARE-DEMAND FILTER] count = 869 / 1000
# [TIME SUMMARY] diag mean=2.98h | baseline wait mean=2417.42h | restore mean=8.75h
# [CANDIDATE SCREENING]
#   PMIN = 0.15
#   long-lead threshold p90 = 7233.20h
#   impact threshold p70 = 0.004402
#   candidate spare-demand parts = 595 / 869
# [BASE_MAINT_SPEND] 29,803,724 KRW
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.10
# ======================================================================
# [NSGA | target=0.10] Gen 10/200 | best Ao=0.8424 | share(Ao>=0.10)=1.00 | mean managed=116.0
# [NSGA | target=0.10] Gen 20/200 | best Ao=0.8375 | share(Ao>=0.10)=1.00 | mean managed=114.2
# [NSGA | target=0.10] Gen 30/200 | best Ao=0.8428 | share(Ao>=0.10)=1.00 | mean managed=116.6
# [NSGA | target=0.10] Gen 40/200 | best Ao=0.8441 | share(Ao>=0.10)=1.00 | mean managed=116.0
# [NSGA | target=0.10] Gen 50/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.8
# [NSGA | target=0.10] Gen 60/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=114.0
# [NSGA | target=0.10] Gen 70/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.7
# [NSGA | target=0.10] Gen 80/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.8
# [NSGA | target=0.10] Gen 90/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.6
# [NSGA | target=0.10] Gen 100/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=114.8
# [NSGA | target=0.10] Gen 110/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.7
# [NSGA | target=0.10] Gen 120/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.9
# [NSGA | target=0.10] Gen 130/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.8
# [NSGA | target=0.10] Gen 140/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=114.0
# [NSGA | target=0.10] Gen 150/200 | best Ao=0.8393 | share(Ao>=0.10)=1.00 | mean managed=114.1
# [NSGA | target=0.10] Gen 160/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.8
# [NSGA | target=0.10] Gen 170/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=114.0
# [NSGA | target=0.10] Gen 180/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.5
# [NSGA | target=0.10] Gen 190/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.6
# [NSGA | target=0.10] Gen 200/200 | best Ao=0.8365 | share(Ao>=0.10)=1.00 | mean managed=113.8
# [TARGET SUMMARY] target=0.10 | best Ao=0.8365 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.20
# ======================================================================
# [NSGA | target=0.20] Gen 10/200 | best Ao=0.8417 | share(Ao>=0.20)=1.00 | mean managed=120.8
# [NSGA | target=0.20] Gen 20/200 | best Ao=0.8394 | share(Ao>=0.20)=1.00 | mean managed=122.5
# [NSGA | target=0.20] Gen 30/200 | best Ao=0.8413 | share(Ao>=0.20)=1.00 | mean managed=127.2
# [NSGA | target=0.20] Gen 40/200 | best Ao=0.8399 | share(Ao>=0.20)=1.00 | mean managed=125.9
# [NSGA | target=0.20] Gen 50/200 | best Ao=0.8398 | share(Ao>=0.20)=1.00 | mean managed=126.7
# [NSGA | target=0.20] Gen 60/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=127.7
# [NSGA | target=0.20] Gen 70/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=127.8
# [NSGA | target=0.20] Gen 80/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.3
# [NSGA | target=0.20] Gen 90/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.1
# [NSGA | target=0.20] Gen 100/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=127.9
# [NSGA | target=0.20] Gen 110/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.3
# [NSGA | target=0.20] Gen 120/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.0
# [NSGA | target=0.20] Gen 130/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=127.8
# [NSGA | target=0.20] Gen 140/200 | best Ao=0.8414 | share(Ao>=0.20)=1.00 | mean managed=128.5
# [NSGA | target=0.20] Gen 150/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.8
# [NSGA | target=0.20] Gen 160/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.2
# [NSGA | target=0.20] Gen 170/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=127.9
# [NSGA | target=0.20] Gen 180/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.5
# [NSGA | target=0.20] Gen 190/200 | best Ao=0.8406 | share(Ao>=0.20)=1.00 | mean managed=128.8
# [NSGA | target=0.20] Gen 200/200 | best Ao=0.8416 | share(Ao>=0.20)=1.00 | mean managed=128.3
# [TARGET SUMMARY] target=0.20 | best Ao=0.8416 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.30
# ======================================================================
# [NSGA | target=0.30] Gen 10/200 | best Ao=0.8417 | share(Ao>=0.30)=1.00 | mean managed=119.2
# [NSGA | target=0.30] Gen 20/200 | best Ao=0.8391 | share(Ao>=0.30)=1.00 | mean managed=122.1
# [NSGA | target=0.30] Gen 30/200 | best Ao=0.8391 | share(Ao>=0.30)=1.00 | mean managed=125.0
# [NSGA | target=0.30] Gen 40/200 | best Ao=0.8389 | share(Ao>=0.30)=1.00 | mean managed=125.3
# [NSGA | target=0.30] Gen 50/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.1
# [NSGA | target=0.30] Gen 60/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.7
# [NSGA | target=0.30] Gen 70/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.8
# [NSGA | target=0.30] Gen 80/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.2
# [NSGA | target=0.30] Gen 90/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.9
# [NSGA | target=0.30] Gen 100/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.8
# [NSGA | target=0.30] Gen 110/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.7
# [NSGA | target=0.30] Gen 120/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.1
# [NSGA | target=0.30] Gen 130/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.9
# [NSGA | target=0.30] Gen 140/200 | best Ao=0.8434 | share(Ao>=0.30)=1.00 | mean managed=126.2
# [NSGA | target=0.30] Gen 150/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=127.0
# [NSGA | target=0.30] Gen 160/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.1
# [NSGA | target=0.30] Gen 170/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.4
# [NSGA | target=0.30] Gen 180/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.2
# [NSGA | target=0.30] Gen 190/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=125.9
# [NSGA | target=0.30] Gen 200/200 | best Ao=0.8407 | share(Ao>=0.30)=1.00 | mean managed=126.0
# [TARGET SUMMARY] target=0.30 | best Ao=0.8407 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.40
# ======================================================================
# [NSGA | target=0.40] Gen 10/200 | best Ao=0.8417 | share(Ao>=0.40)=1.00 | mean managed=116.4
# [NSGA | target=0.40] Gen 20/200 | best Ao=0.8420 | share(Ao>=0.40)=1.00 | mean managed=116.0
# [NSGA | target=0.40] Gen 30/200 | best Ao=0.8399 | share(Ao>=0.40)=1.00 | mean managed=118.6
# [NSGA | target=0.40] Gen 40/200 | best Ao=0.8404 | share(Ao>=0.40)=1.00 | mean managed=119.7
# [NSGA | target=0.40] Gen 50/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.0
# [NSGA | target=0.40] Gen 60/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.5
# [NSGA | target=0.40] Gen 70/200 | best Ao=0.8399 | share(Ao>=0.40)=1.00 | mean managed=121.3
# [NSGA | target=0.40] Gen 80/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=121.4
# [NSGA | target=0.40] Gen 90/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.9
# [NSGA | target=0.40] Gen 100/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=119.8
# [NSGA | target=0.40] Gen 110/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.8
# [NSGA | target=0.40] Gen 120/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.2
# [NSGA | target=0.40] Gen 130/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.6
# [NSGA | target=0.40] Gen 140/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=121.2
# [NSGA | target=0.40] Gen 150/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.6
# [NSGA | target=0.40] Gen 160/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.8
# [NSGA | target=0.40] Gen 170/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.3
# [NSGA | target=0.40] Gen 180/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=121.0
# [NSGA | target=0.40] Gen 190/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.6
# [NSGA | target=0.40] Gen 200/200 | best Ao=0.8394 | share(Ao>=0.40)=1.00 | mean managed=120.9
# [TARGET SUMMARY] target=0.40 | best Ao=0.8394 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.50
# ======================================================================
# [NSGA | target=0.50] Gen 10/200 | best Ao=0.8412 | share(Ao>=0.50)=1.00 | mean managed=115.8
# [NSGA | target=0.50] Gen 20/200 | best Ao=0.8417 | share(Ao>=0.50)=1.00 | mean managed=121.1
# [NSGA | target=0.50] Gen 30/200 | best Ao=0.8416 | share(Ao>=0.50)=1.00 | mean managed=126.6
# [NSGA | target=0.50] Gen 40/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=129.6
# [NSGA | target=0.50] Gen 50/200 | best Ao=0.8432 | share(Ao>=0.50)=1.00 | mean managed=129.5
# [NSGA | target=0.50] Gen 60/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.7
# [NSGA | target=0.50] Gen 70/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.0
# [NSGA | target=0.50] Gen 80/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.0
# [NSGA | target=0.50] Gen 90/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.7
# [NSGA | target=0.50] Gen 100/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.7
# [NSGA | target=0.50] Gen 110/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.1
# [NSGA | target=0.50] Gen 120/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=129.6
# [NSGA | target=0.50] Gen 130/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.0
# [NSGA | target=0.50] Gen 140/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.0
# [NSGA | target=0.50] Gen 150/200 | best Ao=0.8467 | share(Ao>=0.50)=1.00 | mean managed=130.8
# [NSGA | target=0.50] Gen 160/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=129.9
# [NSGA | target=0.50] Gen 170/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=131.3
# [NSGA | target=0.50] Gen 180/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.3
# [NSGA | target=0.50] Gen 190/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.4
# [NSGA | target=0.50] Gen 200/200 | best Ao=0.8433 | share(Ao>=0.50)=1.00 | mean managed=130.6
# [TARGET SUMMARY] target=0.50 | best Ao=0.8433 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.60
# ======================================================================
# [NSGA | target=0.60] Gen 10/200 | best Ao=0.8385 | share(Ao>=0.60)=1.00 | mean managed=111.4
# [NSGA | target=0.60] Gen 20/200 | best Ao=0.8387 | share(Ao>=0.60)=1.00 | mean managed=114.2
# [NSGA | target=0.60] Gen 30/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.6
# [NSGA | target=0.60] Gen 40/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.7
# [NSGA | target=0.60] Gen 50/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.9
# [NSGA | target=0.60] Gen 60/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.8
# [NSGA | target=0.60] Gen 70/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.7
# [NSGA | target=0.60] Gen 80/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=119.0
# [NSGA | target=0.60] Gen 90/200 | best Ao=0.8401 | share(Ao>=0.60)=1.00 | mean managed=119.7
# [NSGA | target=0.60] Gen 100/200 | best Ao=0.8425 | share(Ao>=0.60)=1.00 | mean managed=119.7
# [NSGA | target=0.60] Gen 110/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=119.6
# [NSGA | target=0.60] Gen 120/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.5
# [NSGA | target=0.60] Gen 130/200 | best Ao=0.8407 | share(Ao>=0.60)=1.00 | mean managed=118.8
# [NSGA | target=0.60] Gen 140/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=117.8
# [NSGA | target=0.60] Gen 150/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.5
# [NSGA | target=0.60] Gen 160/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.8
# [NSGA | target=0.60] Gen 170/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=119.0
# [NSGA | target=0.60] Gen 180/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.5
# [NSGA | target=0.60] Gen 190/200 | best Ao=0.8394 | share(Ao>=0.60)=1.00 | mean managed=118.7
# [NSGA | target=0.60] Gen 200/200 | best Ao=0.8390 | share(Ao>=0.60)=1.00 | mean managed=118.7
# [TARGET SUMMARY] target=0.60 | best Ao=0.8390 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.70
# ======================================================================
# [NSGA | target=0.70] Gen 10/200 | best Ao=0.8447 | share(Ao>=0.70)=1.00 | mean managed=114.9
# [NSGA | target=0.70] Gen 20/200 | best Ao=0.8384 | share(Ao>=0.70)=1.00 | mean managed=114.7
# [NSGA | target=0.70] Gen 30/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=115.6
# [NSGA | target=0.70] Gen 40/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=118.6
# [NSGA | target=0.70] Gen 50/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.0
# [NSGA | target=0.70] Gen 60/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.6
# [NSGA | target=0.70] Gen 70/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.7
# [NSGA | target=0.70] Gen 80/200 | best Ao=0.8381 | share(Ao>=0.70)=1.00 | mean managed=120.3
# [NSGA | target=0.70] Gen 90/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.8
# [NSGA | target=0.70] Gen 100/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.0
# [NSGA | target=0.70] Gen 110/200 | best Ao=0.8380 | share(Ao>=0.70)=1.00 | mean managed=120.4
# [NSGA | target=0.70] Gen 120/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.7
# [NSGA | target=0.70] Gen 130/200 | best Ao=0.8377 | share(Ao>=0.70)=1.00 | mean managed=119.9
# [NSGA | target=0.70] Gen 140/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.4
# [NSGA | target=0.70] Gen 150/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.0
# [NSGA | target=0.70] Gen 160/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.5
# [NSGA | target=0.70] Gen 170/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.0
# [NSGA | target=0.70] Gen 180/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.5
# [NSGA | target=0.70] Gen 190/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=119.9
# [NSGA | target=0.70] Gen 200/200 | best Ao=0.8375 | share(Ao>=0.70)=1.00 | mean managed=120.2
# [TARGET SUMMARY] target=0.70 | best Ao=0.8375 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.80
# ======================================================================
# [NSGA | target=0.80] Gen 10/200 | best Ao=0.8453 | share(Ao>=0.80)=0.69 | mean managed=125.1
# [NSGA | target=0.80] Gen 20/200 | best Ao=0.8424 | share(Ao>=0.80)=0.94 | mean managed=130.5
# [NSGA | target=0.80] Gen 30/200 | best Ao=0.8427 | share(Ao>=0.80)=0.99 | mean managed=131.6
# [NSGA | target=0.80] Gen 40/200 | best Ao=0.8458 | share(Ao>=0.80)=1.00 | mean managed=132.6
# [NSGA | target=0.80] Gen 50/200 | best Ao=0.8427 | share(Ao>=0.80)=1.00 | mean managed=133.7
# [NSGA | target=0.80] Gen 60/200 | best Ao=0.8427 | share(Ao>=0.80)=1.00 | mean managed=134.7
# [NSGA | target=0.80] Gen 70/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.2
# [NSGA | target=0.80] Gen 80/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.3
# [NSGA | target=0.80] Gen 90/200 | best Ao=0.8427 | share(Ao>=0.80)=1.00 | mean managed=134.9
# [NSGA | target=0.80] Gen 100/200 | best Ao=0.8440 | share(Ao>=0.80)=1.00 | mean managed=135.3
# [NSGA | target=0.80] Gen 110/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.0
# [NSGA | target=0.80] Gen 120/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=134.9
# [NSGA | target=0.80] Gen 130/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.2
# [NSGA | target=0.80] Gen 140/200 | best Ao=0.8433 | share(Ao>=0.80)=1.00 | mean managed=135.7
# [NSGA | target=0.80] Gen 150/200 | best Ao=0.8439 | share(Ao>=0.80)=1.00 | mean managed=135.7
# [NSGA | target=0.80] Gen 160/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=134.6
# [NSGA | target=0.80] Gen 170/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.6
# [NSGA | target=0.80] Gen 180/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.1
# [NSGA | target=0.80] Gen 190/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=135.0
# [NSGA | target=0.80] Gen 200/200 | best Ao=0.8424 | share(Ao>=0.80)=1.00 | mean managed=134.8
# [TARGET SUMMARY] target=0.80 | best Ao=0.8424 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.85
# ======================================================================
# [NSGA | target=0.85] Gen 10/200 | best Ao=0.8526 | share(Ao>=0.85)=0.15 | mean managed=147.2
# [NSGA | target=0.85] Gen 20/200 | best Ao=0.8559 | share(Ao>=0.85)=0.19 | mean managed=160.3
# [NSGA | target=0.85] Gen 30/200 | best Ao=0.8569 | share(Ao>=0.85)=0.33 | mean managed=163.3
# [NSGA | target=0.85] Gen 40/200 | best Ao=0.8573 | share(Ao>=0.85)=0.28 | mean managed=163.9
# [NSGA | target=0.85] Gen 50/200 | best Ao=0.8567 | share(Ao>=0.85)=0.28 | mean managed=167.5
# [NSGA | target=0.85] Gen 60/200 | best Ao=0.8560 | share(Ao>=0.85)=0.36 | mean managed=169.6
# [NSGA | target=0.85] Gen 70/200 | best Ao=0.8546 | share(Ao>=0.85)=0.33 | mean managed=169.9
# [NSGA | target=0.85] Gen 80/200 | best Ao=0.8579 | share(Ao>=0.85)=0.41 | mean managed=171.7
# [NSGA | target=0.85] Gen 90/200 | best Ao=0.8584 | share(Ao>=0.85)=0.53 | mean managed=174.4
# [NSGA | target=0.85] Gen 100/200 | best Ao=0.8554 | share(Ao>=0.85)=0.59 | mean managed=175.3
# [NSGA | target=0.85] Gen 110/200 | best Ao=0.8571 | share(Ao>=0.85)=0.60 | mean managed=175.8
# [NSGA | target=0.85] Gen 120/200 | best Ao=0.8574 | share(Ao>=0.85)=0.69 | mean managed=177.0
# [NSGA | target=0.85] Gen 130/200 | best Ao=0.8571 | share(Ao>=0.85)=0.78 | mean managed=179.8
# [NSGA | target=0.85] Gen 140/200 | best Ao=0.8609 | share(Ao>=0.85)=0.80 | mean managed=180.1
# [NSGA | target=0.85] Gen 150/200 | best Ao=0.8609 | share(Ao>=0.85)=0.84 | mean managed=179.9
# [NSGA | target=0.85] Gen 160/200 | best Ao=0.8567 | share(Ao>=0.85)=0.91 | mean managed=180.5
# [NSGA | target=0.85] Gen 170/200 | best Ao=0.8578 | share(Ao>=0.85)=0.95 | mean managed=180.7
# [NSGA | target=0.85] Gen 180/200 | best Ao=0.8578 | share(Ao>=0.85)=0.95 | mean managed=181.0
# [NSGA | target=0.85] Gen 190/200 | best Ao=0.8580 | share(Ao>=0.85)=1.00 | mean managed=181.2
# [NSGA | target=0.85] Gen 200/200 | best Ao=0.8580 | share(Ao>=0.85)=1.00 | mean managed=181.3
# [TARGET SUMMARY] target=0.85 | best Ao=0.8580 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.90
# ======================================================================
# [NSGA | target=0.90] Gen 10/200 | best Ao=0.8654 | share(Ao>=0.90)=0.00 | mean managed=152.2
# [NSGA | target=0.90] Gen 20/200 | best Ao=0.8810 | share(Ao>=0.90)=0.00 | mean managed=192.0
# [NSGA | target=0.90] Gen 30/200 | best Ao=0.8885 | share(Ao>=0.90)=0.00 | mean managed=202.7
# [NSGA | target=0.90] Gen 40/200 | best Ao=0.8935 | share(Ao>=0.90)=0.00 | mean managed=216.4
# [NSGA | target=0.90] Gen 50/200 | best Ao=0.9038 | share(Ao>=0.90)=0.01 | mean managed=227.7
# [NSGA | target=0.90] Gen 60/200 | best Ao=0.9010 | share(Ao>=0.90)=0.03 | mean managed=234.5
# [NSGA | target=0.90] Gen 70/200 | best Ao=0.9040 | share(Ao>=0.90)=0.09 | mean managed=242.2
# [NSGA | target=0.90] Gen 80/200 | best Ao=0.9042 | share(Ao>=0.90)=0.07 | mean managed=246.4
# [NSGA | target=0.90] Gen 90/200 | best Ao=0.9037 | share(Ao>=0.90)=0.10 | mean managed=255.0
# [NSGA | target=0.90] Gen 100/200 | best Ao=0.9029 | share(Ao>=0.90)=0.06 | mean managed=249.0
# [NSGA | target=0.90] Gen 110/200 | best Ao=0.9026 | share(Ao>=0.90)=0.05 | mean managed=252.3
# [NSGA | target=0.90] Gen 120/200 | best Ao=0.9026 | share(Ao>=0.90)=0.06 | mean managed=253.1
# [NSGA | target=0.90] Gen 130/200 | best Ao=0.9020 | share(Ao>=0.90)=0.06 | mean managed=254.1
# [NSGA | target=0.90] Gen 140/200 | best Ao=0.9017 | share(Ao>=0.90)=0.07 | mean managed=257.7
# [NSGA | target=0.90] Gen 150/200 | best Ao=0.9030 | share(Ao>=0.90)=0.06 | mean managed=255.0
# [NSGA | target=0.90] Gen 160/200 | best Ao=0.9011 | share(Ao>=0.90)=0.06 | mean managed=255.6
# [NSGA | target=0.90] Gen 170/200 | best Ao=0.9011 | share(Ao>=0.90)=0.04 | mean managed=258.8
# [NSGA | target=0.90] Gen 180/200 | best Ao=0.9011 | share(Ao>=0.90)=0.06 | mean managed=263.4
# [NSGA | target=0.90] Gen 190/200 | best Ao=0.9036 | share(Ao>=0.90)=0.09 | mean managed=268.5
# [NSGA | target=0.90] Gen 200/200 | best Ao=0.9036 | share(Ao>=0.90)=0.10 | mean managed=274.1
# [TARGET SUMMARY] target=0.90 | best Ao=0.9036 | share_ge_target=0.10
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.92
# ======================================================================
# [NSGA | target=0.92] Gen 10/200 | best Ao=0.8658 | share(Ao>=0.92)=0.00 | mean managed=161.6
# [NSGA | target=0.92] Gen 20/200 | best Ao=0.8816 | share(Ao>=0.92)=0.00 | mean managed=185.3
# [NSGA | target=0.92] Gen 30/200 | best Ao=0.8890 | share(Ao>=0.92)=0.00 | mean managed=210.7
# [NSGA | target=0.92] Gen 40/200 | best Ao=0.8963 | share(Ao>=0.92)=0.00 | mean managed=222.8
# [NSGA | target=0.92] Gen 50/200 | best Ao=0.9022 | share(Ao>=0.92)=0.00 | mean managed=238.2
# [NSGA | target=0.92] Gen 60/200 | best Ao=0.9125 | share(Ao>=0.92)=0.00 | mean managed=253.0
# [NSGA | target=0.92] Gen 70/200 | best Ao=0.9135 | share(Ao>=0.92)=0.00 | mean managed=262.4
# [NSGA | target=0.92] Gen 80/200 | best Ao=0.9188 | share(Ao>=0.92)=0.00 | mean managed=269.1
# [NSGA | target=0.92] Gen 90/200 | best Ao=0.9206 | share(Ao>=0.92)=0.03 | mean managed=278.8
# [NSGA | target=0.92] Gen 100/200 | best Ao=0.9216 | share(Ao>=0.92)=0.05 | mean managed=276.7
# [NSGA | target=0.92] Gen 110/200 | best Ao=0.9220 | share(Ao>=0.92)=0.05 | mean managed=282.4
# [NSGA | target=0.92] Gen 120/200 | best Ao=0.9212 | share(Ao>=0.92)=0.04 | mean managed=287.4
# [NSGA | target=0.92] Gen 130/200 | best Ao=0.9213 | share(Ao>=0.92)=0.06 | mean managed=280.6
# [NSGA | target=0.92] Gen 140/200 | best Ao=0.9213 | share(Ao>=0.92)=0.06 | mean managed=287.7
# [NSGA | target=0.92] Gen 150/200 | best Ao=0.9241 | share(Ao>=0.92)=0.09 | mean managed=291.5
# [NSGA | target=0.92] Gen 160/200 | best Ao=0.9251 | share(Ao>=0.92)=0.09 | mean managed=289.6
# [NSGA | target=0.92] Gen 170/200 | best Ao=0.9251 | share(Ao>=0.92)=0.10 | mean managed=293.2
# [NSGA | target=0.92] Gen 180/200 | best Ao=0.9222 | share(Ao>=0.92)=0.07 | mean managed=298.0
# [NSGA | target=0.92] Gen 190/200 | best Ao=0.9217 | share(Ao>=0.92)=0.06 | mean managed=297.1
# [NSGA | target=0.92] Gen 200/200 | best Ao=0.9234 | share(Ao>=0.92)=0.06 | mean managed=297.6
# [TARGET SUMMARY] target=0.92 | best Ao=0.9234 | share_ge_target=0.06
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.94
# ======================================================================
# [NSGA | target=0.94] Gen 10/200 | best Ao=0.8681 | share(Ao>=0.94)=0.00 | mean managed=156.9
# [NSGA | target=0.94] Gen 20/200 | best Ao=0.8815 | share(Ao>=0.94)=0.00 | mean managed=194.2
# [NSGA | target=0.94] Gen 30/200 | best Ao=0.8927 | share(Ao>=0.94)=0.00 | mean managed=213.1
# [NSGA | target=0.94] Gen 40/200 | best Ao=0.9028 | share(Ao>=0.94)=0.00 | mean managed=232.1
# [NSGA | target=0.94] Gen 50/200 | best Ao=0.9116 | share(Ao>=0.94)=0.00 | mean managed=238.1
# [NSGA | target=0.94] Gen 60/200 | best Ao=0.9140 | share(Ao>=0.94)=0.00 | mean managed=252.6
# [NSGA | target=0.94] Gen 70/200 | best Ao=0.9168 | share(Ao>=0.94)=0.00 | mean managed=254.8
# [NSGA | target=0.94] Gen 80/200 | best Ao=0.9228 | share(Ao>=0.94)=0.00 | mean managed=263.3
# [NSGA | target=0.94] Gen 90/200 | best Ao=0.9258 | share(Ao>=0.94)=0.00 | mean managed=270.1
# [NSGA | target=0.94] Gen 100/200 | best Ao=0.9258 | share(Ao>=0.94)=0.00 | mean managed=277.0
# [NSGA | target=0.94] Gen 110/200 | best Ao=0.9292 | share(Ao>=0.94)=0.00 | mean managed=276.5
# [NSGA | target=0.94] Gen 120/200 | best Ao=0.9318 | share(Ao>=0.94)=0.00 | mean managed=280.1
# [NSGA | target=0.94] Gen 130/200 | best Ao=0.9329 | share(Ao>=0.94)=0.00 | mean managed=282.9
# [NSGA | target=0.94] Gen 140/200 | best Ao=0.9346 | share(Ao>=0.94)=0.00 | mean managed=291.0
# [NSGA | target=0.94] Gen 150/200 | best Ao=0.9369 | share(Ao>=0.94)=0.00 | mean managed=297.0
# [NSGA | target=0.94] Gen 160/200 | best Ao=0.9397 | share(Ao>=0.94)=0.00 | mean managed=297.6
# [NSGA | target=0.94] Gen 170/200 | best Ao=0.9419 | share(Ao>=0.94)=0.04 | mean managed=304.3
# [NSGA | target=0.94] Gen 180/200 | best Ao=0.9403 | share(Ao>=0.94)=0.04 | mean managed=303.9
# [NSGA | target=0.94] Gen 190/200 | best Ao=0.9418 | share(Ao>=0.94)=0.04 | mean managed=303.7
# [NSGA | target=0.94] Gen 200/200 | best Ao=0.9414 | share(Ao>=0.94)=0.04 | mean managed=310.8
# [TARGET SUMMARY] target=0.94 | best Ao=0.9414 | share_ge_target=0.04
#
# ======================================================================
# [INTEGRATED SUMMARY]
# All collected solutions        = 960
# Unique integrated solutions    = 960
# ======================================================================
#
# [TARGET-WISE SUMMARY]
#  target_ao  n_solutions   ao_min   ao_max     cost_min     cost_max    wait_min    wait_max  managed_min  managed_max  share_ge_target
#       0.10           80 0.755090 0.836474 2.980372e+07 2.980372e+07 3401.543701 5659.029209            0            0           1.0000
#       0.20           80 0.756882 0.841630 2.980372e+07 2.980372e+07 3273.235308 5604.084134            0            0           1.0000
#       0.30           80 0.759764 0.840736 2.980372e+07 2.980372e+07 3295.363001 5516.289138            0            0           1.0000
#       0.40           80 0.759234 0.839432 2.980372e+07 2.980372e+07 3327.736378 5532.371468            0            0           1.0000
#       0.50           80 0.760712 0.843256 2.980372e+07 2.980372e+07 3233.101025 5487.541800            0            0           1.0000
#       0.60           80 0.757575 0.839035 2.980372e+07 2.980372e+07 3337.622397 5582.926582            0            0           1.0000
#       0.70           80 0.758316 0.837536 2.980372e+07 2.980372e+07 3375.001998 5560.324771            0            0           1.0000
#       0.80           80 0.831246 0.842372 2.980372e+07 2.980372e+07 3254.911636 3533.293043            0            0           1.0000
#       0.85           80 0.850294 0.858037 2.980372e+07 2.980372e+07 2875.200152 3061.122362            0            0           1.0000
#       0.90           80 0.870994 0.903575 2.980372e+07 3.411142e+07 1846.130114 2571.446656            0           11           0.1000
#       0.92           80 0.862151 0.923432 3.068987e+07 3.600210e+07 1429.183618 2777.764357            3           19           0.0625
#       0.94           80 0.868557 0.941401 2.996285e+07 4.589733e+07 1067.041114 2627.880605            1           45           0.0375
#
# ==============================
# [FINAL SUMMARY | REPRESENTATIVE TARGET]
# Representative Target = 0.94
# Best Ao = 0.9414
# Share(Ao >= 0.94) = 0.04
# Candidate spare-demand parts = 595
# ==============================
#
# [BEST POLICY | REPRESENTATIVE TARGET]
# Ao                  = 0.9414
# DT_diag_h           = 6.23
# DT_wait_h           = 1067.04
# DT_restore_h        = 17.28
# DT_total_h          = 1090.55
# stock_cost          = 14702303
# hold_cost           = 735115
# total_cost          = 45241142
# managed parts       = 43
# total stock units   = 68
# selected pre-buy    = 59
# selected protection = 20
# /tmp/ipykernel_12822/149846492.py:1229: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
# [TOP selected managed parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0216 RAD-L5-0214      6      6             O   2.559677       5.119354   0.994020          4994.25      2.98     6.215917   0.219301             0            0                0                1        0        0        0                 0               0.300049        228594.0             1.00
# RAD-L6-0996 RAD-L5-0995      6      6             O   0.166569       0.333138   0.283329          3955.50      2.98     2.324133   0.018075             0            0                0                1        0        0        0                 0               0.300005        238210.0             0.15
# RAD-L6-0999 RAD-L5-0995      6      6             O   0.147725       0.295450   0.255803          3273.00      2.98     4.824516   0.013278             0            0                0                1        0        0        0                 0               0.300004        303245.0             0.15
# RAD-L6-1000 RAD-L5-0995      6      6             O   0.134608       0.269217   0.236023          3270.75      2.98    10.756224   0.012113             0            0                0                1        0        0        0                 0               0.300004        179607.0             0.15
# RAD-L6-0656 RAD-L5-0654      6      6             O   0.194902       0.389805   0.322811          3919.50      2.98    13.935244   0.013137             0            0                0                1        0        0        0                 0               0.300004        299799.0             0.15
# RAD-L6-0253 RAD-L5-0251      6      6             O   0.193381       0.386763   0.320748          1317.00      2.98     9.173565   0.004401             0            0                0                1        0        0        0                 0               0.300004        372420.0             0.15
# RAD-L6-0153 RAD-L5-0151      6      6             O   0.192523       0.385047   0.319581          6088.50      2.98    12.714627   0.020123             1            1                1                1        0        0        2                 2               0.300004        326534.0             0.15
# RAD-L6-0827 RAD-L5-0819      6      6             O   0.192319       0.384638   0.319303          1127.25      2.98     8.734874   0.003751             0            0                0                1        0        0        0                 0               0.300004        252021.0             0.15
# RAD-L6-0634 RAD-L5-0627      6      6             O   0.192143       0.384286   0.319064          1435.50      2.98     5.849800   0.004752             0            0                0                1        0        0        0                 0               0.300004        153292.0             0.15
# RAD-L6-0696 RAD-L5-0691      6      6             O   0.191919       0.383838   0.318758          5382.75      2.98     5.984102   0.017719             0            0                0                1        0        0        0                 0               0.300004        256847.0             0.15
# RAD-L6-0318 RAD-L5-0316      6      6             O   0.191022       0.382044   0.317535          5424.75      2.98    12.309771   0.017794             0            0                0                1        0        0        0                 0               0.300004        297965.0             0.15
# RAD-L6-0925 RAD-L5-0922      6      6             O   0.191002       0.382005   0.317508          1280.25      2.98    10.867919   0.004232             0            0                0                1        0        0        0                 0               0.300004        284275.0             0.15
# RAD-L6-0046 RAD-L5-0041      6      6             O   0.190232       0.380464   0.316456           879.75      2.98    11.584429   0.002913             0            0                0                1        0        0        0                 0               0.300004        212301.0             0.15
# RAD-L6-0896 RAD-L5-0895      6      6             O   0.189043       0.378086   0.314828          1043.25      2.98     8.060549   0.003413             0            0                0                1        0        0        0                 0               0.300004        177830.0             0.15
# RAD-L6-0027 RAD-L5-0023      6      6             O   0.188819       0.377637   0.314521           711.00      2.98    11.346130   0.002345             0            0                0                1        0        0        0                 0               0.300004        105219.0             0.15
#
# [TOP unmanaged but high baseline-wait parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0870 RAD-L5-0864      6      6             O   0.033267       0.066534   0.064369          6502.50      2.98     5.539189   0.003709             1            0                0                0        0        0        0                 0                6502.50        289784.0             0.15
# RAD-L6-0159 RAD-L5-0151      6      6             O   0.068513       0.137026   0.128053          6440.25      2.98     6.091496   0.007566             1            1                0                0        0        0        0                 0                6440.25        848118.0             0.15
# RAD-L6-0047 RAD-L5-0041      6      6             O   0.026289       0.052578   0.051220          6376.50      2.98     7.161622   0.002875             1            0                0                0        0        0        0                 0                6376.50        299034.0             0.15
# RAD-L6-0545 RAD-L5-0544      6      6             O   0.030125       0.060249   0.058470          6375.75      2.98     6.747154   0.003294             1            0                0                0        0        0        0                 0                6375.75        308816.0             0.15
# RAD-L6-0785 RAD-L5-0782      6      6             O   0.027875       0.055751   0.054225          6289.50      2.98     3.171694   0.003005             1            0                0                0        0        0        0                 0                6289.50        482305.0             0.15
# RAD-L6-0229 RAD-L5-0224      6      6             O   0.161235       0.322470   0.275642          6276.75      2.98     4.825222   0.017351             1            1                1                0        0        0        0                 0                6276.75        424589.0             0.15
# RAD-L6-0125 RAD-L5-0123      6      6             O   0.039526       0.079053   0.076009          6270.75      2.98     7.295179   0.004251             1            0                0                0        0        0        0                 0                6270.75        271207.0             0.15
# RAD-L6-0486 RAD-L5-0480      6      6             O   0.066515       0.133029   0.124560          6132.75      2.98     7.726341   0.006997             1            1                0                0        0        0        0                 0                6132.75        398997.0             0.15
# RAD-L6-0750 RAD-L5-0746      6      6             O   0.072789       0.145578   0.135478          6050.25      2.98     5.136255   0.007551             1            1                0                0        0        0        0                 0                6050.25        150909.0             0.15
# RAD-L6-0044 RAD-L5-0041      6      6             O   0.171143       0.342285   0.289854          5939.25      2.98    11.439542   0.017447             1            1                1                0        0        0        0                 0                5939.25        301230.0             0.15
# RAD-L6-0744 RAD-L5-0737      6      6             O   0.152200       0.304399   0.262433          5873.25      2.98     5.396455   0.015328             1            1                1                0        0        0        0                 0                5873.25        134558.0             0.15
# RAD-L6-0143 RAD-L5-0141      6      6             O   0.139318       0.278635   0.243184          5820.75      2.98     9.166326   0.013915             1            1                1                0        0        0        0                 0                5820.75        175974.0             0.15
# RAD-L6-0429 RAD-L5-0425      6      6             O   0.138274       0.276549   0.241604          5813.25      2.98    12.822137   0.013802             1            1                1                0        0        0        0                 0                5813.25        181040.0             0.15
# RAD-L6-0572 RAD-L5-0571      6      6             O   0.080418       0.160835   0.148567          5756.25      2.98     5.773979   0.007938             1            1                0                0        0        0        0                 0                5756.25        254854.0             0.15
# RAD-L6-0763 RAD-L5-0755      6      6             O   0.025018       0.050037   0.048806          5715.00      2.98     9.051302   0.002453             1            0                0                0        0        0        0                 0                5715.00        182508.0             0.15
#
# [TOP protection candidates | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0217 RAD-L5-0214      6      6             O   0.188214       0.376428   0.313691          6463.50      2.98     5.322994   0.020858             1            1                1                1        0        1        0                 1               0.300004        132367.0             0.15
# RAD-L6-0153 RAD-L5-0151      6      6             O   0.192523       0.385047   0.319581          6088.50      2.98    12.714627   0.020123             1            1                1                1        0        0        2                 2               0.300004        326534.0             0.15
# RAD-L6-0811 RAD-L5-0810      6      6             O   0.186001       0.372001   0.310647          6186.75      2.98     4.101014   0.019727             1            1                1                1        1        0        0                 1               0.300000        285020.0             0.15
# RAD-L6-0631 RAD-L5-0627      6      6             O   0.179575       0.359151   0.301731          6352.50      2.98     8.756889   0.019570             1            1                1                1        1        0        0                 1               0.300000        253682.0             0.15
# RAD-L6-0994 RAD-L5-0986      6      6             O   0.182920       0.365839   0.306386          5922.00      2.98     8.084757   0.018583             1            1                1                1        1        0        0                 1               0.300000        183052.0             0.15
# RAD-L6-0640 RAD-L5-0636      6      6             O   0.174564       0.349128   0.294697          5965.50      2.98     8.470013   0.017866             1            1                1                1        1        0        0                 1               0.300000        167349.0             0.15
# RAD-L6-0863 RAD-L5-0855      6      6             O   0.171216       0.342432   0.289959          5985.00      2.98     3.890924   0.017567             1            1                1                1        1        0        0                 1               0.300000        145640.0             0.15
# RAD-L6-0642 RAD-L5-0636      6      6             O   0.177070       0.354139   0.298223          5774.25      2.98     5.395830   0.017533             1            1                1                1        1        0        0                 1               0.300000        333830.0             0.15
# RAD-L6-0044 RAD-L5-0041      6      6             O   0.171143       0.342285   0.289854          5939.25      2.98    11.439542   0.017447             1            1                1                0        0        0        0                 0            5939.250000        301230.0             0.15
# RAD-L6-0229 RAD-L5-0224      6      6             O   0.161235       0.322470   0.275642          6276.75      2.98     4.825222   0.017351             1            1                1                0        0        0        0                 0            6276.750000        424589.0             0.15
# RAD-L6-0431 RAD-L5-0425      6      6             O   0.173901       0.347802   0.293761          5805.75      2.98     9.274780   0.017325             1            1                1                1        1        0        0                 1               0.300000        144321.0             0.15
# RAD-L6-0167 RAD-L5-0160      6      6             O   0.161509       0.323017   0.276039          6114.75      2.98     6.415834   0.016937             1            1                1                1        1        0        0                 1               0.300000        390037.0             0.15
# RAD-L6-0747 RAD-L5-0746      6      6             O   0.163127       0.326254   0.278378          5968.50      2.98     8.753844   0.016704             1            1                1                1        1        0        0                 1               0.300000        398886.0             0.15
# RAD-L6-0970 RAD-L5-0968      6      6             O   0.164569       0.329137   0.280456          5659.50      2.98     4.070173   0.015968             1            1                1                0        0        0        0                 0            5659.500000        189355.0             0.15
# RAD-L6-0406 RAD-L5-0398      6      6             O   0.170199       0.340398   0.288513          5430.75      2.98    11.832508   0.015870             1            1                1                1        1        0        0                 1               0.300000        110820.0             0.15

# %%
# ============================================================
# COLAB ONE-CHUNK CODE
# NSGA-II baseline model
# + target sweep integration (without changing objective/constraint structure)
# + Pareto front visualization with dominated solutions
# + integrated trade-off map across multiple Ao targets
# ------------------------------------------------------------
# 핵심
#   - 목적함수/제약식 구조는 그대로 유지
#   - AO_TARGET 하나만 고정하지 않고 AO_TARGET_GRID를 순회
#   - 각 target에서 NSGA-II를 반복 수행
#   - 결과를 합쳐 cost-Ao 통합 시각화
#   - 대표 target(기본 0.94)에 대해서 상세 진단표 출력
#
# [PM EFFECT REBALANCING PATCH]
#   - PM의 고장률 완화 효과는 약하게 반영
#   - PM의 복원시간(정비시간) 단축 효과는 더 크게 반영
#   - 구조는 유지하고 계수만 현실적으로 조정
# ============================================================

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ============================================================
# 0) File load
# ============================================================
USE_COLAB_UPLOAD = False

if USE_COLAB_UPLOAD:
    from google.colab import files
    uploaded = files.upload()
    XLSX_PATH = list(uploaded.keys())[0]
else:
    XLSX_PATH = "radar_1000_parts_bom.xlsx"

df = pd.read_excel(XLSX_PATH, sheet_name=0)
print(f"[LOAD] shape = {df.shape}")


# ============================================================
# 1) Column helpers
# ============================================================
def find_col(df, candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

col_part = find_col(df, ["Part_ID"])
col_parent = find_col(df, ["Parent_ID"])
col_level = find_col(df, ["Level"])
col_echelon = find_col(df, ["Maint_Echelon"])
col_fr = find_col(df, ["Failure_Rate"])
col_price = find_col(df, ["Unit_Price_KRW"])
col_transport_cost = find_col(df, ["Transport_Cost_KRW"])
col_lead = find_col(df, ["Total_Lead_Time_H"])
col_transport_time = find_col(df, ["Transport_Time_H"])
col_cm_cost = find_col(df, ["CM_Cost_KRW"])
col_cm_time = find_col(df, ["CM_Time_Hours"])
col_condemn = find_col(df, ["Condemnation_Rate_Pct"])
col_pm = find_col(df, ["PM_Cycle"])

required = [col_part, col_parent, col_level, col_echelon, col_fr]
if any(x is None for x in required):
    raise ValueError({
        "Part_ID": col_part,
        "Parent_ID": col_parent,
        "Level": col_level,
        "Maint_Echelon": col_echelon,
        "Failure_Rate": col_fr
    })

for c in [col_price, col_transport_cost, col_lead, col_transport_time, col_fr, col_cm_cost, col_cm_time, col_condemn]:
    if c is not None:
        df[c] = pd.to_numeric(df[c], errors="coerce")


# ============================================================
# 2) Settings
# ============================================================
YEARS = 2.0
T_OBS_HOURS = YEARS * 365.0 * 24.0
HOURS_PER_YEAR = 365.0 * 24.0

# ------------------------------------------------------------
# target sweep
# ------------------------------------------------------------
AO_TARGET_GRID = [
    0.10, 0.20, 0.30, 0.40, 0.50,
    0.60, 0.70, 0.80, 0.85, 0.90,
    0.92, 0.94
]
REPRESENTATIVE_TARGET = 0.94   # 상세 진단표/대표 Pareto plot 기준
AO_LINES = [0.90, 0.91, 0.92, 0.93, 0.94]

PMIN = 0.15
LONG_LEAD_PERCENTILE = 90
AO_IMPACT_PERCENTILE = 70
LONG_CORE_IMPACT_PERCENTILE = 70

POP = 80
GEN = 200
SEED = 42

AO_COST_PENALTY = 8.0e8
ITEM_COUNT_WEIGHT = 1.0
STOCK_UNIT_WEIGHT = 0.05
h_pre = 0.05

ABS_CAP_SMALL = 3
ABS_CAP_MED = 4
ABS_CAP_LARGE = 6

# ------------------------------------------------------------
# tuned baseline support parameters
# ------------------------------------------------------------
BASELINE_WAIT_FRACTION_BY_ECHELON = {
    "O": 0.75,
    "I": 0.90,
    "D": 1.00,
}
MIN_WAIT_FLOOR_H_BY_ECHELON = {
    "O": 1.0,
    "I": 6.0,
    "D": 24.0,
}

TOPK_PRINT = 15

# ------------------------------------------------------------
# PM effect rebalancing parameters
# ------------------------------------------------------------
# 현실 반영:
# - PM은 비계획 고장률 자체를 크게 낮춘다기보다
#   조기 발견/정비 준비도 향상/작업 표준화로 복원시간을 더 줄인다고 해석
PM_EFFECT_ON_FAILURE = 0.03   # 기존 0.10 수준보다 약하게
PM_EFFECT_ON_RESTORE = 0.18   # 기존 0.05 수준보다 더 크게


# ============================================================
# 3) Helpers
# ============================================================
def minmax(x):
    x = np.asarray(x, dtype=float)
    lo, hi = np.nanmin(x), np.nanmax(x)
    if hi - lo < 1e-12:
        return np.zeros_like(x, dtype=float)
    return (x - lo) / (hi - lo)

def parse_level_to_int(v):
    if pd.isna(v):
        return 0
    s = str(v)
    m = re.search(r"(\d+)", s)
    return int(m.group(1)) if m else 0

def map_echelon(v):
    if pd.isna(v):
        return "X"
    s = str(v).strip().lower()

    if any(k in s for k in ["organizational", "operational", "operator", "field", "unit", "line", "o-level", "o level"]):
        return "O"
    if any(k in s for k in ["현장", "운용", "부대", "일선"]):
        return "O"

    if any(k in s for k in ["intermediate", "support", "shop", "base", "i-level", "i level", "direct support"]):
        return "I"
    if any(k in s for k in ["중간", "야전정비", "지원", "정비대"]):
        return "I"

    if any(k in s for k in ["depot", "factory", "overhaul", "sustainment", "d-level", "d level"]):
        return "D"
    if any(k in s for k in ["창정비", "공창", "후방"]):
        return "D"

    if s in ["o", "org", "op"]:
        return "O"
    if s in ["i", "int"]:
        return "I"
    if s in ["d", "dep"]:
        return "D"

    return "X"

def pm_cycle_to_days(v):
    if pd.isna(v):
        return np.nan

    if isinstance(v, (int, float, np.integer, np.floating)):
        x = float(v)
        if x <= 0:
            return np.nan
        return x if x <= 400 else np.nan

    s = str(v).strip().lower()
    if s in ["", "nan", "none", "null"]:
        return np.nan

    if "분기" in s or "quarter" in s:
        return 365.0 / 4.0
    if "반기" in s or "semi" in s or "half" in s:
        return 365.0 / 2.0
    if "연" in s or "annual" in s or "year" in s:
        return 365.0

    m = re.search(r"(\d+(\.\d+)?)\s*(day|days|d|month|months|m|year|years|y)", s)
    if m:
        val = float(m.group(1))
        unit = m.group(3)
        if unit in ["day", "days", "d"]:
            return val
        if unit in ["month", "months", "m"]:
            return val * 30.4167
        if unit in ["year", "years", "y"]:
            return val * 365.0

    m2 = re.search(r"(\d+(\.\d+)?)", s)
    if m2:
        return float(m2.group(1))

    return np.nan

def poisson_tail_prob(mu, s):
    mu = float(max(mu, 0.0))
    s = int(max(s, 0))
    if mu < 1e-12:
        return 0.0

    term = math.exp(-mu)
    cdf = term
    for k in range(1, s + 1):
        term *= mu / k
        cdf += term
    tail = 1.0 - cdf
    return min(max(tail, 0.0), 1.0)

def long_dynamic_cap_from_lambda(lam_2y):
    base = int(np.ceil(lam_2y))
    if lam_2y < 1.0:
        buffer_i = 1
        abs_cap_i = ABS_CAP_SMALL
    elif lam_2y < 2.5:
        buffer_i = 1
        abs_cap_i = ABS_CAP_MED
    else:
        buffer_i = 2
        abs_cap_i = ABS_CAP_LARGE
    total_cap_i = min(base + buffer_i, abs_cap_i)
    return max(total_cap_i, 1)

def solution_signature(y_manage, sO, sI, sD):
    return (
        "Y:" + ",".join(map(str, y_manage.astype(int).tolist())) +
        "|O:" + ",".join(map(str, sO.astype(int).tolist())) +
        "|I:" + ",".join(map(str, sI.astype(int).tolist())) +
        "|D:" + ",".join(map(str, sD.astype(int).tolist()))
    )


# ============================================================
# 4) Raw arrays
# ============================================================
n_all = df.shape[0]

part_id_all = df[col_part].astype(str).to_numpy()
parent_id_all = df[col_parent].astype(str).to_numpy()
level_num_all = df[col_level].apply(parse_level_to_int).to_numpy(int)
echelon_cat_all = df[col_echelon].apply(map_echelon).to_numpy()

FR_all = df[col_fr].fillna(0).clip(lower=0).to_numpy(float)

unit_price_all = df[col_price].fillna(0).clip(lower=0).to_numpy(float) if col_price else np.zeros(n_all)
transport_cost_all = df[col_transport_cost].fillna(0).clip(lower=0).to_numpy(float) if col_transport_cost else np.zeros(n_all)
proc_cost_all = unit_price_all + transport_cost_all

lead_raw_all = df[col_lead].to_numpy(float) if col_lead else np.full(n_all, np.nan)
transport_time_all = df[col_transport_time].fillna(0).clip(lower=0).to_numpy(float) if col_transport_time else np.zeros(n_all)
lead_all = (
    pd.Series(lead_raw_all)
    .fillna(pd.Series(transport_time_all))
    .fillna(0)
    .clip(lower=0)
    .to_numpy(float)
)

cm_cost_all = df[col_cm_cost].fillna(0).clip(lower=0).to_numpy(float) if col_cm_cost else np.zeros(n_all)
cm_time_all = df[col_cm_time].fillna(0).clip(lower=0).to_numpy(float) if col_cm_time else np.zeros(n_all)

if col_condemn:
    condemn_all = df[col_condemn].fillna(0).clip(lower=0, upper=100).to_numpy(float) / 100.0
else:
    condemn_all = np.zeros(n_all, dtype=float)

if col_pm:
    pm_days_all = df[col_pm].apply(pm_cycle_to_days).to_numpy(float)
else:
    pm_days_all = np.full(n_all, np.nan)

pm_freq_all = np.where(np.isfinite(pm_days_all) & (pm_days_all > 0), 365.0 / pm_days_all, 0.0)
pm_norm_all = np.clip(pm_freq_all / 4.0, 0.0, 1.0)

# ============================================================
# [MODIFIED] PM effect coefficients
# - gamma_all : PM의 고장률 완화 효과(약하게)
# - delta_all : PM의 복원시간 단축 효과(강하게)
# ============================================================
gamma_all = PM_EFFECT_ON_FAILURE * pm_norm_all
delta_all = PM_EFFECT_ON_RESTORE * pm_norm_all

print(
    f"[PM EFFECT] failure reduction max={PM_EFFECT_ON_FAILURE:.2f} | "
    f"restore reduction max={PM_EFFECT_ON_RESTORE:.2f}"
)


# ============================================================
# 5) Build BOM structure
# ============================================================
part_to_idx = {pid: i for i, pid in enumerate(part_id_all)}

children_map = {i: [] for i in range(n_all)}
for i in range(n_all):
    p = parent_id_all[i]
    if pd.notna(p):
        p = str(p)
        if p in part_to_idx:
            children_map[part_to_idx[p]].append(i)

is_leaf_all = np.array([len(children_map[i]) == 0 for i in range(n_all)], dtype=bool)

def get_ancestor_chain(idx):
    chain_rev = [idx]
    seen = {idx}
    cur_parent = parent_id_all[idx]
    hop = 0
    while pd.notna(cur_parent) and str(cur_parent) not in ["", "nan", "None", "null"]:
        cur_parent = str(cur_parent)
        if cur_parent not in part_to_idx:
            break
        pidx = part_to_idx[cur_parent]
        if pidx in seen:
            break
        chain_rev.append(pidx)
        seen.add(pidx)
        cur_parent = parent_id_all[pidx]
        hop += 1
        if hop > 30:
            break
    return list(reversed(chain_rev))

all_ancestor_chains = [get_ancestor_chain(i) for i in range(n_all)]
depth_all = np.array([len(ch) for ch in all_ancestor_chains], dtype=int)


# ============================================================
# 6) Real spare-demand part selection
# ============================================================
has_physical_attr = (
    (unit_price_all > 0) |
    (cm_time_all > 0) |
    (lead_all > 0)
)

spare_demand_mask = (
    (level_num_all >= 3) &
    is_leaf_all &
    (FR_all > 0) &
    has_physical_attr
)

if spare_demand_mask.sum() < 20:
    spare_demand_mask = (
        (level_num_all >= 3) &
        (FR_all > 0) &
        has_physical_attr
    )

spare_idx = np.where(spare_demand_mask)[0]
print(f"[SPARE-DEMAND FILTER] count = {len(spare_idx)} / {n_all}")

if len(spare_idx) == 0:
    raise ValueError("No real spare-demand parts found.")


# ============================================================
# 7) Common arrays
# ============================================================
# [MODIFIED] PM이 failure rate에 미치는 영향은 약하게 유지
annual_fr_sp = FR_all[spare_idx] * (1.0 - gamma_all[spare_idx])
lam_2y_sp = annual_fr_sp * YEARS

proc_cost_sp = proc_cost_all[spare_idx]
lead_sp = lead_all[spare_idx]
transport_sp = transport_time_all[spare_idx]
cm_cost_sp = cm_cost_all[spare_idx]
cm_time_sp = cm_time_all[spare_idx]
condemn_sp = condemn_all[spare_idx]
delta_sp = delta_all[spare_idx]
level_sp = level_num_all[spare_idx]
depth_sp = depth_all[spare_idx]
echelon_sp = echelon_cat_all[spare_idx]
part_id_sp = part_id_all[spare_idx]
parent_id_sp = parent_id_all[spare_idx]
chains_sp = [all_ancestor_chains[i] for i in spare_idx]

# sibling normalization
parent_group_map = {}
for local_idx, global_idx in enumerate(spare_idx):
    p = parent_id_all[global_idx]
    p = str(p) if pd.notna(p) else f"ROOT_{part_id_all[global_idx]}"
    parent_group_map.setdefault(p, []).append(local_idx)

lambda_eff_sp = annual_fr_sp.copy()
for p, members in parent_group_map.items():
    if len(members) <= 1:
        continue
    fr_sub = annual_fr_sp[members]
    total = fr_sub.sum()
    if total > 1e-12:
        shares = fr_sub / total
        lambda_eff_sp[members] = total * shares / len(members) * 1.2
    else:
        lambda_eff_sp[members] = annual_fr_sp[members]

def node_diag_contrib(level_value):
    if level_value <= 1:
        return 0.10
    if level_value == 2:
        return 0.18
    if level_value == 3:
        return 0.35
    if level_value == 4:
        return 0.55
    if level_value == 5:
        return 0.80
    return 1.00

T_diag_sp = np.zeros(len(spare_idx), dtype=float)
for k, chain in enumerate(chains_sp):
    t = 0.0
    for node_idx in chain:
        lv = level_num_all[node_idx]
        t += node_diag_contrib(lv)
    T_diag_sp[k] = t

T_reminst_sp = 0.35 * np.maximum(cm_time_sp, 1.0)

# [MODIFIED] PM이 복원시간/정비시간 단축에 더 강하게 반영
T_repair_base_sp = 0.65 * cm_time_sp
T_repair_sp = T_repair_base_sp * (1.0 - delta_sp)

for i, e in enumerate(echelon_sp):
    if e == "O":
        T_reminst_sp[i] *= 0.85
        T_repair_sp[i] *= 0.75
    elif e == "I":
        T_reminst_sp[i] *= 1.00
        T_repair_sp[i] *= 1.00
    elif e == "D":
        T_reminst_sp[i] *= 1.15
        T_repair_sp[i] *= 1.25

T_restore_intrinsic_sp = T_reminst_sp + (1.0 - condemn_sp) * T_repair_sp

T_issue_O_sp = np.full(len(spare_idx), 0.3, dtype=float)
T_issue_I_sp = np.maximum(0.8, np.minimum(4.0, 0.25 * np.maximum(transport_sp, 1.0)))
T_issue_D_sp = np.maximum(1.5, np.minimum(8.0, 0.45 * np.maximum(transport_sp, 1.0)))

baseline_wait_sp = np.zeros(len(spare_idx), dtype=float)
for i, e in enumerate(echelon_sp):
    frac = BASELINE_WAIT_FRACTION_BY_ECHELON.get(e, 0.35)
    floor = MIN_WAIT_FLOOR_H_BY_ECHELON.get(e, 2.0)
    baseline_wait_sp[i] = max(floor, frac * lead_sp[i])

print(
    f"[TIME SUMMARY] "
    f"diag mean={T_diag_sp.mean():.2f}h | "
    f"baseline wait mean={baseline_wait_sp.mean():.2f}h | "
    f"restore mean={T_restore_intrinsic_sp.mean():.2f}h"
)


# ============================================================
# 8) Candidate screening
# ============================================================
p_need_sp = 1.0 - np.exp(-lam_2y_sp)

thr_lead = float(np.nanpercentile(lead_sp, LONG_LEAD_PERCENTILE))
is_long_sp = (lead_sp >= thr_lead)

impact_sp = lambda_eff_sp * np.maximum(T_diag_sp + baseline_wait_sp + T_restore_intrinsic_sp, 1e-9) / HOURS_PER_YEAR
thr_impact = float(np.nanpercentile(impact_sp, AO_IMPACT_PERCENTILE))
is_high_impact_sp = (impact_sp >= thr_impact)

candidate_mask = (p_need_sp >= PMIN) | is_high_impact_sp | is_long_sp
candidate_idx_local = np.where(candidate_mask)[0]

print("[CANDIDATE SCREENING]")
print(f"  PMIN = {PMIN:.2f}")
print(f"  long-lead threshold p{LONG_LEAD_PERCENTILE} = {thr_lead:.2f}h")
print(f"  impact threshold p{AO_IMPACT_PERCENTILE} = {thr_impact:.6f}")
print(f"  candidate spare-demand parts = {len(candidate_idx_local)} / {len(spare_idx)}")

if len(candidate_idx_local) == 0:
    raise ValueError("No candidate spare-demand parts after screening.")

part_id_c = part_id_sp[candidate_idx_local]
parent_id_c = parent_id_sp[candidate_idx_local]
level_c = level_sp[candidate_idx_local]
depth_c = depth_sp[candidate_idx_local]
echelon_c = echelon_sp[candidate_idx_local]

annual_fr_c = annual_fr_sp[candidate_idx_local]
lambda_eff_c = lambda_eff_sp[candidate_idx_local]
lam_2y_c = lam_2y_sp[candidate_idx_local]
proc_cost_c = proc_cost_sp[candidate_idx_local]
lead_c = lead_sp[candidate_idx_local]
cm_cost_c = cm_cost_sp[candidate_idx_local]

T_diag_c = T_diag_sp[candidate_idx_local]
T_reminst_c = T_reminst_sp[candidate_idx_local]
T_repair_c = T_repair_sp[candidate_idx_local]
T_restore_intrinsic_c = T_restore_intrinsic_sp[candidate_idx_local]
T_issue_O_c = T_issue_O_sp[candidate_idx_local]
T_issue_I_c = T_issue_I_sp[candidate_idx_local]
T_issue_D_c = T_issue_D_sp[candidate_idx_local]
baseline_wait_c = baseline_wait_sp[candidate_idx_local]

p_need_c = p_need_sp[candidate_idx_local]
impact_c = impact_sp[candidate_idx_local]
is_long_c = is_long_sp[candidate_idx_local]

m_cand = len(candidate_idx_local)
long_idx_c = np.where(is_long_c)[0]

if len(long_idx_c) > 0:
    long_core_thr = float(np.nanpercentile(impact_c[long_idx_c], LONG_CORE_IMPACT_PERCENTILE))
else:
    long_core_thr = 0.0

prebuy_flag_c = np.zeros(m_cand, dtype=bool)
protection_flag_c = np.zeros(m_cand, dtype=bool)
for j in range(m_cand):
    if is_long_c[j] and ((p_need_c[j] >= PMIN) or (impact_c[j] >= thr_impact)):
        prebuy_flag_c[j] = True
    if is_long_c[j] and (impact_c[j] >= long_core_thr):
        protection_flag_c[j] = True

impact_norm_c = minmax(impact_c)
critical_weight_c = np.where(
    impact_norm_c >= 0.80, 1.00,
    np.where(impact_norm_c >= 0.50, 0.45, 0.15)
)

mu_pipe_nom_c = lambda_eff_c * (baseline_wait_c + T_restore_intrinsic_c) / HOURS_PER_YEAR

stock_cap_c = np.zeros(m_cand, dtype=int)
for i in range(m_cand):
    if is_long_c[i]:
        stock_cap_c[i] = long_dynamic_cap_from_lambda(lam_2y_c[i])
    else:
        stock_cap_c[i] = max(
            1,
            int(np.ceil(mu_pipe_nom_c[i] + 4.0 * np.sqrt(max(mu_pipe_nom_c[i], 1e-9)) + 2.0))
        )

prot_floor_c = np.where(protection_flag_c, 1, 0).astype(int)
BASE_MAINT_SPEND = float(np.sum(annual_fr_c * cm_cost_c * YEARS))

print(f"[BASE_MAINT_SPEND] {BASE_MAINT_SPEND:,.0f} KRW")


# ============================================================
# 9) Evaluate one solution
# ============================================================
def evaluate_one_solution(y_manage, sO, sI, sD):
    y_manage = np.asarray(y_manage, dtype=int)
    sO = np.asarray(sO, dtype=int)
    sI = np.asarray(sI, dtype=int)
    sD = np.asarray(sD, dtype=int)

    sO = y_manage * sO
    sI = y_manage * sI
    sD = y_manage * sD

    for i in range(m_cand):
        if y_manage[i] > 0 and prot_floor_c[i] > 0:
            if sO[i] + sI[i] + sD[i] < 1:
                if echelon_c[i] == "O":
                    sO[i] = 1
                elif echelon_c[i] == "I":
                    sI[i] = 1
                else:
                    sD[i] = 1

    total_stock = sO + sI + sD
    for i in range(m_cand):
        if total_stock[i] > stock_cap_c[i]:
            excess = total_stock[i] - stock_cap_c[i]
            reduc = min(sD[i], excess)
            sD[i] -= reduc
            excess -= reduc
            if excess > 0:
                reduc = min(sI[i], excess)
                sI[i] -= reduc
                excess -= reduc
            if excess > 0:
                reduc = min(sO[i], excess)
                sO[i] -= reduc
                excess -= reduc
        total_stock[i] = sO[i] + sI[i] + sD[i]

    p_short_O = np.zeros(m_cand, dtype=float)
    p_short_I = np.zeros(m_cand, dtype=float)
    p_short_D = np.zeros(m_cand, dtype=float)

    for i in range(m_cand):
        if y_manage[i] == 0:
            p_short_O[i] = 1.0
            p_short_I[i] = 1.0
            p_short_D[i] = 1.0
            continue

        muO = lambda_eff_c[i] * T_issue_O_c[i] / HOURS_PER_YEAR
        muI = lambda_eff_c[i] * T_issue_I_c[i] / HOURS_PER_YEAR
        muD = lambda_eff_c[i] * T_issue_D_c[i] / HOURS_PER_YEAR

        p_short_O[i] = poisson_tail_prob(muO, sO[i])
        p_short_I[i] = poisson_tail_prob(muI, sI[i])
        p_short_D[i] = poisson_tail_prob(muD, sD[i])

    improved_wait = (
        (1.0 - p_short_O) * T_issue_O_c
        + p_short_O * (1.0 - p_short_I) * T_issue_I_c
        + p_short_O * p_short_I * (1.0 - p_short_D) * T_issue_D_c
        + p_short_O * p_short_I * p_short_D * baseline_wait_c
    )

    T_wait_per_failure = np.where(
        y_manage > 0,
        np.minimum(baseline_wait_c, improved_wait),
        baseline_wait_c
    )

    DT_diag = np.sum(lambda_eff_c * T_diag_c * critical_weight_c)
    DT_restore = np.sum(lambda_eff_c * T_restore_intrinsic_c * critical_weight_c)
    DT_wait = np.sum(lambda_eff_c * T_wait_per_failure * critical_weight_c)
    DT_total = DT_diag + DT_wait + DT_restore

    Ao = float(T_OBS_HOURS / (T_OBS_HOURS + DT_total))

    stock_cost = float(np.sum(total_stock * proc_cost_c))
    hold_cost = float(h_pre * np.sum(total_stock * proc_cost_c))
    total_cost = stock_cost + hold_cost + BASE_MAINT_SPEND

    managed_items = int(np.sum((y_manage > 0) & (total_stock > 0)))
    total_stock_units = int(np.sum(total_stock))
    prebuy_selected = int(np.sum((y_manage > 0) & prebuy_flag_c))
    protection_selected = int(np.sum((total_stock > 0) & protection_flag_c))

    return {
        "Ao": Ao,
        "DT_diag_h": float(DT_diag),
        "DT_wait_h": float(DT_wait),
        "DT_restore_h": float(DT_restore),
        "DT_total_h": float(DT_total),
        "T_wait_per_failure": T_wait_per_failure,
        "total_cost": total_cost,
        "stock_cost": stock_cost,
        "hold_cost": hold_cost,
        "sO": sO,
        "sI": sI,
        "sD": sD,
        "total_stock": total_stock,
        "managed_items": managed_items,
        "total_stock_units": total_stock_units,
        "prebuy_selected": prebuy_selected,
        "protection_selected": protection_selected,
    }


# ============================================================
# 10) NSGA evaluation + utilities
# ============================================================
def eval_nsga(pop_mat, ao_target):
    pop = pop_mat.shape[0]

    Y = np.clip(np.rint(pop_mat[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop_mat[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop_mat[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop_mat[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    F = np.zeros((pop, 3), dtype=float)
    Ao = np.zeros(pop, dtype=float)

    for p in range(pop):
        sim = evaluate_one_solution(Y[p], SO[p], SI[p], SD[p])

        Ao[p] = sim["Ao"]
        ao_shortfall = max(0.0, ao_target - sim["Ao"])

        F1 = sim["total_cost"] + AO_COST_PENALTY * (ao_shortfall ** 2)
        F2 = ao_shortfall
        F3 = ITEM_COUNT_WEIGHT * sim["managed_items"] + STOCK_UNIT_WEIGHT * sim["total_stock_units"]

        F[p, 0] = F1
        F[p, 1] = F2
        F[p, 2] = F3

    return F, Ao

def dominates(a, b):
    return np.all(a <= b) and np.any(a < b)

def fast_non_dominated_sort(F):
    n = F.shape[0]
    S = [[] for _ in range(n)]
    n_dom = np.zeros(n, dtype=int)
    fronts = [[]]

    for p in range(n):
        for q in range(n):
            if p == q:
                continue
            if dominates(F[p], F[q]):
                S[p].append(q)
            elif dominates(F[q], F[p]):
                n_dom[p] += 1
        if n_dom[p] == 0:
            fronts[0].append(p)

    i = 0
    while fronts[i]:
        nxt = []
        for p in fronts[i]:
            for q in S[p]:
                n_dom[q] -= 1
                if n_dom[q] == 0:
                    nxt.append(q)
        i += 1
        fronts.append(nxt)

    fronts.pop()
    return fronts

def crowding_distance(F, front):
    mobj = F.shape[1]
    dist = np.zeros(len(front), dtype=float)
    if len(front) == 0:
        return dist

    idx = np.array(front, dtype=int)
    for j in range(mobj):
        vals = F[idx, j]
        order = np.argsort(vals)
        dist[order[0]] = np.inf
        dist[order[-1]] = np.inf

        vmin, vmax = vals[order[0]], vals[order[-1]]
        if vmax - vmin < 1e-12:
            continue

        for k in range(1, len(front) - 1):
            dist[order[k]] += (vals[order[k+1]] - vals[order[k-1]]) / (vmax - vmin)
    return dist

def rank_and_crowd(F):
    fronts = fast_non_dominated_sort(F)
    rank = np.empty(F.shape[0], dtype=int)
    crowd = np.zeros(F.shape[0], dtype=float)

    for rnk, front in enumerate(fronts):
        for i in front:
            rank[i] = rnk
        cd = crowding_distance(F, front)
        for t, i in enumerate(front):
            crowd[i] = cd[t]
    return rank, crowd, fronts

def tournament_select(rank, crowd, rng):
    i, j = rng.integers(0, len(rank), size=2)
    if rank[i] < rank[j]:
        return i
    if rank[j] < rank[i]:
        return j
    return i if crowd[i] > crowd[j] else j

def uniform_crossover(p1, p2, rng):
    mask = rng.random(p1.shape[0]) < 0.5
    c1, c2 = p1.copy(), p2.copy()
    c1[mask] = p2[mask]
    c2[mask] = p1[mask]
    return c1, c2


# ============================================================
# 11) Run NSGA-II (single target)
# ============================================================
def run_nsga_single_target(ao_target, seed=42):
    rng = np.random.default_rng(seed)

    n_vars = m_cand + 3 * m_cand
    mut_p = float(np.clip(20.0 / max(n_vars, 1), 0.01, 0.06))

    pop = np.zeros((POP, n_vars), dtype=float)

    seed_prob = np.clip(
        0.12 + 0.55 * (
            0.45 * minmax(p_need_c) +
            0.35 * minmax(impact_c) +
            0.20 * is_long_c.astype(float)
        ),
        0.08, 0.85
    )

    for k in range(POP):
        for j in range(m_cand):
            pop[k, j] = 1 if rng.random() < seed_prob[j] else 0

        for j in range(m_cand):
            yj = int(pop[k, j])
            ub = stock_cap_c[j]
            if yj == 0:
                pop[k, m_cand + j] = 0
                pop[k, m_cand + m_cand + j] = 0
                pop[k, m_cand + 2*m_cand + j] = 0
            else:
                sO0, sI0, sD0 = 0, 0, 0
                if echelon_c[j] == "O":
                    sO0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                elif echelon_c[j] == "I":
                    sI0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                else:
                    sD0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                pop[k, m_cand + j] = sO0
                pop[k, m_cand + m_cand + j] = sI0
                pop[k, m_cand + 2*m_cand + j] = sD0

    def repair_solution(v):
        y = np.clip(np.rint(v[:m_cand]), 0, 1).astype(int)
        sO = np.clip(np.rint(v[m_cand:m_cand+m_cand]), 0, None).astype(int)
        sI = np.clip(np.rint(v[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
        sD = np.clip(np.rint(v[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

        for j in range(m_cand):
            if y[j] == 0:
                sO[j] = 0
                sI[j] = 0
                sD[j] = 0
            total = sO[j] + sI[j] + sD[j]
            cap = stock_cap_c[j]
            if total > cap:
                excess = total - cap
                reduc = min(sD[j], excess)
                sD[j] -= reduc
                excess -= reduc
                if excess > 0:
                    reduc = min(sI[j], excess)
                    sI[j] -= reduc
                    excess -= reduc
                if excess > 0:
                    reduc = min(sO[j], excess)
                    sO[j] -= reduc
                    excess -= reduc

        return np.concatenate([y, sO, sI, sD]).astype(float)

    def mutate(child):
        y = child.copy()

        msk_y = rng.random(m_cand) < mut_p
        for j in range(m_cand):
            if msk_y[j]:
                y[j] = 1.0 - round(y[j])

        for block in range(3):
            start = m_cand + block * m_cand
            msk_s = rng.random(m_cand) < mut_p
            for j in range(m_cand):
                idx = start + j
                if msk_s[j]:
                    ub = stock_cap_c[j]
                    y[idx] = rng.integers(0, ub + 1)

        y = repair_solution(y)
        return y

    for gen in range(GEN):
        F, Ao = eval_nsga(pop, ao_target)
        rank, crowd, fronts = rank_and_crowd(F)

        off = []
        while len(off) < POP:
            p1 = tournament_select(rank, crowd, rng)
            p2 = tournament_select(rank, crowd, rng)
            c1, c2 = uniform_crossover(pop[p1], pop[p2], rng)
            c1 = mutate(c1)
            c2 = mutate(c2)
            off.append(c1)
            if len(off) < POP:
                off.append(c2)
        off = np.array(off, dtype=float)

        comb = np.vstack([pop, off])
        F_c, Ao_c = eval_nsga(comb, ao_target)
        rank_c, crowd_c, fronts_c = rank_and_crowd(F_c)

        new_idx = []
        for front in fronts_c:
            if len(new_idx) + len(front) <= POP:
                new_idx.extend(front)
            else:
                front = np.array(front, dtype=int)
                order = np.argsort(-crowd_c[front])
                need = POP - len(new_idx)
                new_idx.extend(front[order[:need]].tolist())
                break

        pop = comb[np.array(new_idx, dtype=int)]

        if (gen + 1) % 10 == 0:
            Fp, Aop = eval_nsga(pop, ao_target)
            managed_counts = []
            for row in pop:
                ytmp = np.clip(np.rint(row[:m_cand]), 0, 1).astype(int)
                managed_counts.append(int(np.sum(ytmp)))
            print(
                f"[NSGA | target={ao_target:.2f}] Gen {gen+1}/{GEN} | "
                f"best Ao={float(np.max(Aop)):.4f} | "
                f"share(Ao>={ao_target:.2f})={float(np.mean(Aop >= ao_target)):.2f} | "
                f"mean managed={float(np.mean(managed_counts)):.1f}"
            )

    F, Ao = eval_nsga(pop, ao_target)
    cost = F[:, 0]

    F2d = np.column_stack([cost, -Ao])
    fronts2d = fast_non_dominated_sort(F2d)
    pareto_idx = np.array(fronts2d[0], dtype=int)
    dominated_idx = np.setdiff1d(np.arange(len(cost)), pareto_idx)

    order = np.argsort(cost[pareto_idx])
    p_idx = pareto_idx[order]

    best_idx = int(np.argmax(Ao))
    x = pop[best_idx]

    Y = np.clip(np.rint(x[:m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(x[m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(x[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(x[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    best_sim = evaluate_one_solution(Y, SO, SI, SD)

    return {
        "target_ao": ao_target,
        "pop": pop,
        "F": F,
        "Ao": Ao,
        "cost": cost,
        "pareto_idx": pareto_idx,
        "dominated_idx": dominated_idx,
        "p_cost": cost[p_idx],
        "p_Ao": Ao[p_idx],
        "best_Ao": float(np.max(Ao)),
        "share_ge_target": float(np.mean(Ao >= ao_target)),
        "best_sim": best_sim,
        "best_y": Y,
        "best_sO": SO,
        "best_sI": SI,
        "best_sD": SD,
    }


# ============================================================
# 12) Sweep targets
# ============================================================
def collect_run_dataframe(res_single):
    rows = []

    pop = res_single["pop"]
    target_ao = res_single["target_ao"]

    Y = np.clip(np.rint(pop[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    pareto_set = set(res_single["pareto_idx"].tolist())

    for i in range(pop.shape[0]):
        sim = evaluate_one_solution(Y[i], SO[i], SI[i], SD[i])
        rows.append({
            "target_ao": float(target_ao),
            "solution_id_within_target": int(i),
            "Ao": float(sim["Ao"]),
            "total_cost": float(sim["total_cost"]),
            "stock_cost": float(sim["stock_cost"]),
            "hold_cost": float(sim["hold_cost"]),
            "DT_diag_h": float(sim["DT_diag_h"]),
            "DT_wait_h": float(sim["DT_wait_h"]),
            "DT_restore_h": float(sim["DT_restore_h"]),
            "DT_total_h": float(sim["DT_total_h"]),
            "managed_items": int(sim["managed_items"]),
            "total_stock_units": int(sim["total_stock_units"]),
            "is_pareto_2d": int(i in pareto_set),
            "signature": solution_signature(Y[i], sim["sO"], sim["sI"], sim["sD"]),
        })
    return pd.DataFrame(rows)

def run_target_sweep(target_grid, base_seed=42):
    all_result_map = {}
    all_df = []

    for idx, target in enumerate(target_grid):
        print("\n" + "=" * 70)
        print(f"[TARGET SWEEP] RUN START | target_ao = {target:.2f}")
        print("=" * 70)

        run_seed = int(base_seed + idx * 17)

        res_t = run_nsga_single_target(ao_target=target, seed=run_seed)
        all_result_map[round(target, 6)] = res_t

        df_t = collect_run_dataframe(res_t)
        all_df.append(df_t)

        print(f"[TARGET SUMMARY] target={target:.2f} | best Ao={res_t['best_Ao']:.4f} | share_ge_target={res_t['share_ge_target']:.2f}")

    if len(all_df) == 0:
        return all_result_map, pd.DataFrame()

    df_all = pd.concat(all_df, ignore_index=True)
    return all_result_map, df_all


# ============================================================
# 13) Deduplicate integrated solutions
# ============================================================
def deduplicate_integrated_df(df_all):
    if df_all.empty:
        return df_all.copy()

    df_unique = (
        df_all.sort_values(
            by=["Ao", "total_cost", "target_ao"],
            ascending=[False, True, True]
        )
        .drop_duplicates(subset=["signature"])
        .reset_index(drop=True)
    )
    return df_unique


# ============================================================
# 14) Visualizations
# ============================================================
def plot_representative_pareto(res_single):
    plt.figure(figsize=(9, 6))

    plt.scatter(
        res_single["cost"][res_single["dominated_idx"]],
        res_single["Ao"][res_single["dominated_idx"]],
        s=18,
        alpha=0.35,
        color="gray",
        label="Dominated solutions"
    )

    plt.scatter(
        res_single["p_cost"],
        res_single["p_Ao"],
        s=34,
        alpha=0.95,
        color="#1E88E5",
        label="Pareto solutions"
    )
    plt.plot(
        res_single["p_cost"],
        res_single["p_Ao"],
        linewidth=2.2,
        color="#1E88E5",
        label="Pareto front"
    )

    for ao_line in AO_LINES:
        color = "#2E7D32" if ao_line < res_single["target_ao"] else "#6A1B9A"
        style = "--" if ao_line < res_single["target_ao"] else "-."
        plt.axhline(
            ao_line,
            linestyle=style,
            linewidth=1.1,
            color=color,
            alpha=0.85
        )
        plt.text(
            x=np.nanmin(res_single["cost"]) * 1.001,
            y=ao_line + 0.0008,
            s=f"Ao={ao_line:.2f}",
            fontsize=8,
            color=color
        )

    plt.xlabel("Total Cost (KRW)")
    plt.ylabel("Ao")
    plt.title(f"Representative Pareto-front (target={res_single['target_ao']:.2f})")
    plt.legend(loc="best")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"],
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map_percent(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"] * 100.0,
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line * 100.0,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao (%)")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map (%)")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_targetwise_pareto_overlay(result_map):
    plt.figure(figsize=(10, 6))

    cmap = plt.cm.viridis
    targets_sorted = sorted(result_map.keys())

    for idx, t in enumerate(targets_sorted):
        res_t = result_map[t]
        color = cmap(idx / max(len(targets_sorted) - 1, 1))

        plt.scatter(
            res_t["p_Ao"],
            res_t["p_cost"],
            s=18,
            alpha=0.75,
            color=color,
            label=f"target={t:.2f}"
        )
        plt.plot(
            res_t["p_Ao"],
            res_t["p_cost"],
            linewidth=1.1,
            alpha=0.75,
            color=color
        )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=0.9,
            alpha=0.5
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Overlay of Pareto fronts by target")
    plt.grid(True, alpha=0.25)
    plt.legend(loc="best", fontsize=8)
    plt.tight_layout()
    plt.show()


# ============================================================
# 15) Run sweep
# ============================================================
result_map, df_all_runs = run_target_sweep(AO_TARGET_GRID, base_seed=SEED)

df_integrated = deduplicate_integrated_df(df_all_runs)

print("\n" + "=" * 70)
print("[INTEGRATED SUMMARY]")
print(f"All collected solutions        = {len(df_all_runs)}")
print(f"Unique integrated solutions    = {len(df_integrated)}")
print("=" * 70)

summary_by_target_basic = (
    df_all_runs.groupby("target_ao")
    .agg(
        n_solutions=("Ao", "count"),
        ao_min=("Ao", "min"),
        ao_max=("Ao", "max"),
        cost_min=("total_cost", "min"),
        cost_max=("total_cost", "max"),
        wait_min=("DT_wait_h", "min"),
        wait_max=("DT_wait_h", "max"),
        managed_min=("managed_items", "min"),
        managed_max=("managed_items", "max"),
    )
    .reset_index()
)

share_df = (
    df_all_runs.groupby("target_ao")
    .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
    .reset_index(name="share_ge_target")
)

summary_by_target = (
    summary_by_target_basic
    .merge(share_df, on="target_ao", how="left")
    .sort_values("target_ao")
    .reset_index(drop=True)
)

print("\n[TARGET-WISE SUMMARY]")
print(summary_by_target.to_string(index=False))

rep_key = round(REPRESENTATIVE_TARGET, 6)
if rep_key not in result_map:
    raise ValueError(f"Representative target {REPRESENTATIVE_TARGET:.2f} is not in AO_TARGET_GRID.")

res = result_map[rep_key]


# ============================================================
# 16) Final representative summary
# ============================================================
print("\n==============================")
print("[FINAL SUMMARY | REPRESENTATIVE TARGET]")
print(f"Representative Target = {res['target_ao']:.2f}")
print(f"Best Ao = {res['best_Ao']:.4f}")
print(f"Share(Ao >= {res['target_ao']:.2f}) = {res['share_ge_target']:.2f}")
print(f"Candidate spare-demand parts = {m_cand}")
print("==============================")

b = res["best_sim"]
print("\n[BEST POLICY | REPRESENTATIVE TARGET]")
print(f"Ao                  = {b['Ao']:.4f}")
print(f"DT_diag_h           = {b['DT_diag_h']:.2f}")
print(f"DT_wait_h           = {b['DT_wait_h']:.2f}")
print(f"DT_restore_h        = {b['DT_restore_h']:.2f}")
print(f"DT_total_h          = {b['DT_total_h']:.2f}")
print(f"stock_cost          = {b['stock_cost']:.0f}")
print(f"hold_cost           = {b['hold_cost']:.0f}")
print(f"total_cost          = {b['total_cost']:.0f}")
print(f"managed parts       = {b['managed_items']}")
print(f"total stock units   = {b['total_stock_units']}")
print(f"selected pre-buy    = {b['prebuy_selected']}")
print(f"selected protection = {b['protection_selected']}")


# ============================================================
# 17) Plots
# ============================================================
plot_representative_pareto(res)
plot_integrated_tradeoff_map(df_integrated)
plot_integrated_tradeoff_map_percent(df_integrated)
plot_targetwise_pareto_overlay(result_map)


# ============================================================
# 18) Diagnostics table for representative target
# ============================================================
diag_df = pd.DataFrame({
    "Part_ID": part_id_c,
    "Parent_ID": parent_id_c,
    "Level": level_c,
    "Depth": depth_c,
    "Maint_Echelon": echelon_c,
    "annual_FR": annual_fr_c,
    "lambda_eff_2y": lam_2y_c,
    "p_need_2y": p_need_c,
    "baseline_wait_h": baseline_wait_c,
    "T_diag_h": T_diag_c,
    "T_repair_h": T_repair_c,
    "T_restore_h": T_restore_intrinsic_c,
    "ao_impact": impact_c,
    "is_long_lead": is_long_c.astype(int),
    "prebuy_flag": prebuy_flag_c.astype(int),
    "protection_flag": protection_flag_c.astype(int),
    "selected_manage": res["best_y"].astype(int),
    "sO_best": res["best_sim"]["sO"].astype(int),
    "sI_best": res["best_sim"]["sI"].astype(int),
    "sD_best": res["best_sim"]["sD"].astype(int),
    "total_stock_best": res["best_sim"]["total_stock"].astype(int),
    "wait_per_failure_best": res["best_sim"]["T_wait_per_failure"],
    "unit_proc_cost": proc_cost_c,
    "critical_weight": critical_weight_c
})

print("\n[TOP selected managed parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 1]
    .sort_values(["wait_per_failure_best", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP unmanaged but high baseline-wait parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 0]
    .sort_values(["baseline_wait_h", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP protection candidates | representative target]")
print(
    diag_df.loc[diag_df["protection_flag"] == 1]
    .sort_values(["ao_impact", "baseline_wait_h"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)
# Out:
# [LOAD] shape = (1000, 31)
# [PM EFFECT] failure reduction max=0.03 | restore reduction max=0.18
# [SPARE-DEMAND FILTER] count = 869 / 1000
# [TIME SUMMARY] diag mean=2.98h | baseline wait mean=2417.42h | restore mean=8.65h
# [CANDIDATE SCREENING]
#   PMIN = 0.15
#   long-lead threshold p90 = 7233.20h
#   impact threshold p70 = 0.004494
#   candidate spare-demand parts = 606 / 869
# [BASE_MAINT_SPEND] 31,094,513 KRW
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.10
# ======================================================================
# [NSGA | target=0.10] Gen 10/200 | best Ao=0.8354 | share(Ao>=0.10)=1.00 | mean managed=120.8
# [NSGA | target=0.10] Gen 20/200 | best Ao=0.8346 | share(Ao>=0.10)=1.00 | mean managed=118.7
# [NSGA | target=0.10] Gen 30/200 | best Ao=0.8331 | share(Ao>=0.10)=1.00 | mean managed=119.2
# [NSGA | target=0.10] Gen 40/200 | best Ao=0.8353 | share(Ao>=0.10)=1.00 | mean managed=122.2
# [NSGA | target=0.10] Gen 50/200 | best Ao=0.8331 | share(Ao>=0.10)=1.00 | mean managed=124.5
# [NSGA | target=0.10] Gen 60/200 | best Ao=0.8331 | share(Ao>=0.10)=1.00 | mean managed=125.0
# [NSGA | target=0.10] Gen 70/200 | best Ao=0.8337 | share(Ao>=0.10)=1.00 | mean managed=125.2
# [NSGA | target=0.10] Gen 80/200 | best Ao=0.8337 | share(Ao>=0.10)=1.00 | mean managed=125.2
# [NSGA | target=0.10] Gen 90/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.2
# [NSGA | target=0.10] Gen 100/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=124.0
# [NSGA | target=0.10] Gen 110/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=124.7
# [NSGA | target=0.10] Gen 120/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.0
# [NSGA | target=0.10] Gen 130/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=124.6
# [NSGA | target=0.10] Gen 140/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.3
# [NSGA | target=0.10] Gen 150/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.1
# [NSGA | target=0.10] Gen 160/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.0
# [NSGA | target=0.10] Gen 170/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.1
# [NSGA | target=0.10] Gen 180/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=124.6
# [NSGA | target=0.10] Gen 190/200 | best Ao=0.8354 | share(Ao>=0.10)=1.00 | mean managed=126.0
# [NSGA | target=0.10] Gen 200/200 | best Ao=0.8322 | share(Ao>=0.10)=1.00 | mean managed=125.3
# [TARGET SUMMARY] target=0.10 | best Ao=0.8322 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.20
# ======================================================================
# [NSGA | target=0.20] Gen 10/200 | best Ao=0.8375 | share(Ao>=0.20)=1.00 | mean managed=125.8
# [NSGA | target=0.20] Gen 20/200 | best Ao=0.8346 | share(Ao>=0.20)=1.00 | mean managed=132.0
# [NSGA | target=0.20] Gen 30/200 | best Ao=0.8346 | share(Ao>=0.20)=1.00 | mean managed=134.7
# [NSGA | target=0.20] Gen 40/200 | best Ao=0.8306 | share(Ao>=0.20)=1.00 | mean managed=133.1
# [NSGA | target=0.20] Gen 50/200 | best Ao=0.8306 | share(Ao>=0.20)=1.00 | mean managed=134.4
# [NSGA | target=0.20] Gen 60/200 | best Ao=0.8306 | share(Ao>=0.20)=1.00 | mean managed=134.4
# [NSGA | target=0.20] Gen 70/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=134.3
# [NSGA | target=0.20] Gen 80/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=135.1
# [NSGA | target=0.20] Gen 90/200 | best Ao=0.7665 | share(Ao>=0.20)=1.00 | mean managed=135.1
# [NSGA | target=0.20] Gen 100/200 | best Ao=0.8324 | share(Ao>=0.20)=1.00 | mean managed=134.6
# [NSGA | target=0.20] Gen 110/200 | best Ao=0.8324 | share(Ao>=0.20)=1.00 | mean managed=134.5
# [NSGA | target=0.20] Gen 120/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=134.0
# [NSGA | target=0.20] Gen 130/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=134.4
# [NSGA | target=0.20] Gen 140/200 | best Ao=0.7662 | share(Ao>=0.20)=1.00 | mean managed=134.4
# [NSGA | target=0.20] Gen 150/200 | best Ao=0.7662 | share(Ao>=0.20)=1.00 | mean managed=134.8
# [NSGA | target=0.20] Gen 160/200 | best Ao=0.7667 | share(Ao>=0.20)=1.00 | mean managed=134.6
# [NSGA | target=0.20] Gen 170/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=134.6
# [NSGA | target=0.20] Gen 180/200 | best Ao=0.8331 | share(Ao>=0.20)=1.00 | mean managed=134.8
# [NSGA | target=0.20] Gen 190/200 | best Ao=0.7654 | share(Ao>=0.20)=1.00 | mean managed=135.4
# [NSGA | target=0.20] Gen 200/200 | best Ao=0.7649 | share(Ao>=0.20)=1.00 | mean managed=134.9
# [TARGET SUMMARY] target=0.20 | best Ao=0.7649 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.30
# ======================================================================
# [NSGA | target=0.30] Gen 10/200 | best Ao=0.8358 | share(Ao>=0.30)=1.00 | mean managed=121.8
# [NSGA | target=0.30] Gen 20/200 | best Ao=0.8336 | share(Ao>=0.30)=1.00 | mean managed=121.0
# [NSGA | target=0.30] Gen 30/200 | best Ao=0.8326 | share(Ao>=0.30)=1.00 | mean managed=121.9
# [NSGA | target=0.30] Gen 40/200 | best Ao=0.8327 | share(Ao>=0.30)=1.00 | mean managed=122.6
# [NSGA | target=0.30] Gen 50/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=122.7
# [NSGA | target=0.30] Gen 60/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.5
# [NSGA | target=0.30] Gen 70/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.9
# [NSGA | target=0.30] Gen 80/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.4
# [NSGA | target=0.30] Gen 90/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.5
# [NSGA | target=0.30] Gen 100/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.6
# [NSGA | target=0.30] Gen 110/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.4
# [NSGA | target=0.30] Gen 120/200 | best Ao=0.8381 | share(Ao>=0.30)=1.00 | mean managed=124.0
# [NSGA | target=0.30] Gen 130/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.6
# [NSGA | target=0.30] Gen 140/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=122.8
# [NSGA | target=0.30] Gen 150/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.2
# [NSGA | target=0.30] Gen 160/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.7
# [NSGA | target=0.30] Gen 170/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=122.8
# [NSGA | target=0.30] Gen 180/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.2
# [NSGA | target=0.30] Gen 190/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.9
# [NSGA | target=0.30] Gen 200/200 | best Ao=0.8353 | share(Ao>=0.30)=1.00 | mean managed=123.7
# [TARGET SUMMARY] target=0.30 | best Ao=0.8353 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.40
# ======================================================================
# [NSGA | target=0.40] Gen 10/200 | best Ao=0.8346 | share(Ao>=0.40)=1.00 | mean managed=120.5
# [NSGA | target=0.40] Gen 20/200 | best Ao=0.8307 | share(Ao>=0.40)=1.00 | mean managed=123.4
# [NSGA | target=0.40] Gen 30/200 | best Ao=0.8344 | share(Ao>=0.40)=1.00 | mean managed=127.0
# [NSGA | target=0.40] Gen 40/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=128.3
# [NSGA | target=0.40] Gen 50/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=127.5
# [NSGA | target=0.40] Gen 60/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=128.4
# [NSGA | target=0.40] Gen 70/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=128.2
# [NSGA | target=0.40] Gen 80/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.6
# [NSGA | target=0.40] Gen 90/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.3
# [NSGA | target=0.40] Gen 100/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.0
# [NSGA | target=0.40] Gen 110/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.0
# [NSGA | target=0.40] Gen 120/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.4
# [NSGA | target=0.40] Gen 130/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.4
# [NSGA | target=0.40] Gen 140/200 | best Ao=0.8370 | share(Ao>=0.40)=1.00 | mean managed=129.5
# [NSGA | target=0.40] Gen 150/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.2
# [NSGA | target=0.40] Gen 160/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=128.8
# [NSGA | target=0.40] Gen 170/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.4
# [NSGA | target=0.40] Gen 180/200 | best Ao=0.8359 | share(Ao>=0.40)=1.00 | mean managed=129.4
# [NSGA | target=0.40] Gen 190/200 | best Ao=0.8362 | share(Ao>=0.40)=1.00 | mean managed=129.4
# [NSGA | target=0.40] Gen 200/200 | best Ao=0.8362 | share(Ao>=0.40)=1.00 | mean managed=128.9
# [TARGET SUMMARY] target=0.40 | best Ao=0.8362 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.50
# ======================================================================
# [NSGA | target=0.50] Gen 10/200 | best Ao=0.8419 | share(Ao>=0.50)=1.00 | mean managed=123.0
# [NSGA | target=0.50] Gen 20/200 | best Ao=0.7635 | share(Ao>=0.50)=1.00 | mean managed=121.8
# [NSGA | target=0.50] Gen 30/200 | best Ao=0.8282 | share(Ao>=0.50)=1.00 | mean managed=122.5
# [NSGA | target=0.50] Gen 40/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=123.4
# [NSGA | target=0.50] Gen 50/200 | best Ao=0.8294 | share(Ao>=0.50)=1.00 | mean managed=121.8
# [NSGA | target=0.50] Gen 60/200 | best Ao=0.8293 | share(Ao>=0.50)=1.00 | mean managed=121.9
# [NSGA | target=0.50] Gen 70/200 | best Ao=0.8326 | share(Ao>=0.50)=1.00 | mean managed=122.9
# [NSGA | target=0.50] Gen 80/200 | best Ao=0.8311 | share(Ao>=0.50)=1.00 | mean managed=122.3
# [NSGA | target=0.50] Gen 90/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=122.3
# [NSGA | target=0.50] Gen 100/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=122.5
# [NSGA | target=0.50] Gen 110/200 | best Ao=0.8323 | share(Ao>=0.50)=1.00 | mean managed=122.1
# [NSGA | target=0.50] Gen 120/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=121.7
# [NSGA | target=0.50] Gen 130/200 | best Ao=0.8309 | share(Ao>=0.50)=1.00 | mean managed=122.4
# [NSGA | target=0.50] Gen 140/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=122.2
# [NSGA | target=0.50] Gen 150/200 | best Ao=0.8293 | share(Ao>=0.50)=1.00 | mean managed=122.3
# [NSGA | target=0.50] Gen 160/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=122.4
# [NSGA | target=0.50] Gen 170/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=121.8
# [NSGA | target=0.50] Gen 180/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=122.0
# [NSGA | target=0.50] Gen 190/200 | best Ao=0.8291 | share(Ao>=0.50)=1.00 | mean managed=121.8
# [NSGA | target=0.50] Gen 200/200 | best Ao=0.8297 | share(Ao>=0.50)=1.00 | mean managed=121.7
# [TARGET SUMMARY] target=0.50 | best Ao=0.8297 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.60
# ======================================================================
# [NSGA | target=0.60] Gen 10/200 | best Ao=0.8328 | share(Ao>=0.60)=1.00 | mean managed=115.8
# [NSGA | target=0.60] Gen 20/200 | best Ao=0.8318 | share(Ao>=0.60)=1.00 | mean managed=118.1
# [NSGA | target=0.60] Gen 30/200 | best Ao=0.8333 | share(Ao>=0.60)=1.00 | mean managed=121.9
# [NSGA | target=0.60] Gen 40/200 | best Ao=0.8326 | share(Ao>=0.60)=1.00 | mean managed=122.5
# [NSGA | target=0.60] Gen 50/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.7
# [NSGA | target=0.60] Gen 60/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.8
# [NSGA | target=0.60] Gen 70/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.5
# [NSGA | target=0.60] Gen 80/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.2
# [NSGA | target=0.60] Gen 90/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.4
# [NSGA | target=0.60] Gen 100/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.2
# [NSGA | target=0.60] Gen 110/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.4
# [NSGA | target=0.60] Gen 120/200 | best Ao=0.8359 | share(Ao>=0.60)=1.00 | mean managed=125.5
# [NSGA | target=0.60] Gen 130/200 | best Ao=0.8359 | share(Ao>=0.60)=1.00 | mean managed=125.1
# [NSGA | target=0.60] Gen 140/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.6
# [NSGA | target=0.60] Gen 150/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.4
# [NSGA | target=0.60] Gen 160/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.2
# [NSGA | target=0.60] Gen 170/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.8
# [NSGA | target=0.60] Gen 180/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.7
# [NSGA | target=0.60] Gen 190/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.8
# [NSGA | target=0.60] Gen 200/200 | best Ao=0.8335 | share(Ao>=0.60)=1.00 | mean managed=124.8
# [TARGET SUMMARY] target=0.60 | best Ao=0.8335 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.70
# ======================================================================
# [NSGA | target=0.70] Gen 10/200 | best Ao=0.8374 | share(Ao>=0.70)=1.00 | mean managed=123.5
# [NSGA | target=0.70] Gen 20/200 | best Ao=0.8337 | share(Ao>=0.70)=1.00 | mean managed=128.2
# [NSGA | target=0.70] Gen 30/200 | best Ao=0.8367 | share(Ao>=0.70)=1.00 | mean managed=131.4
# [NSGA | target=0.70] Gen 40/200 | best Ao=0.8367 | share(Ao>=0.70)=1.00 | mean managed=132.9
# [NSGA | target=0.70] Gen 50/200 | best Ao=0.8360 | share(Ao>=0.70)=1.00 | mean managed=133.4
# [NSGA | target=0.70] Gen 60/200 | best Ao=0.8360 | share(Ao>=0.70)=1.00 | mean managed=134.0
# [NSGA | target=0.70] Gen 70/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.5
# [NSGA | target=0.70] Gen 80/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.4
# [NSGA | target=0.70] Gen 90/200 | best Ao=0.8350 | share(Ao>=0.70)=1.00 | mean managed=133.4
# [NSGA | target=0.70] Gen 100/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.7
# [NSGA | target=0.70] Gen 110/200 | best Ao=0.8356 | share(Ao>=0.70)=1.00 | mean managed=133.2
# [NSGA | target=0.70] Gen 120/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.4
# [NSGA | target=0.70] Gen 130/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.0
# [NSGA | target=0.70] Gen 140/200 | best Ao=0.8402 | share(Ao>=0.70)=1.00 | mean managed=134.4
# [NSGA | target=0.70] Gen 150/200 | best Ao=0.8402 | share(Ao>=0.70)=1.00 | mean managed=134.2
# [NSGA | target=0.70] Gen 160/200 | best Ao=0.8349 | share(Ao>=0.70)=1.00 | mean managed=134.2
# [NSGA | target=0.70] Gen 170/200 | best Ao=0.8359 | share(Ao>=0.70)=1.00 | mean managed=134.3
# [NSGA | target=0.70] Gen 180/200 | best Ao=0.8359 | share(Ao>=0.70)=1.00 | mean managed=134.4
# [NSGA | target=0.70] Gen 190/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.7
# [NSGA | target=0.70] Gen 200/200 | best Ao=0.8348 | share(Ao>=0.70)=1.00 | mean managed=133.6
# [TARGET SUMMARY] target=0.70 | best Ao=0.8348 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.80
# ======================================================================
# [NSGA | target=0.80] Gen 10/200 | best Ao=0.8341 | share(Ao>=0.80)=0.71 | mean managed=119.5
# [NSGA | target=0.80] Gen 20/200 | best Ao=0.8323 | share(Ao>=0.80)=0.80 | mean managed=123.8
# [NSGA | target=0.80] Gen 30/200 | best Ao=0.8338 | share(Ao>=0.80)=0.88 | mean managed=128.1
# [NSGA | target=0.80] Gen 40/200 | best Ao=0.8376 | share(Ao>=0.80)=0.96 | mean managed=130.7
# [NSGA | target=0.80] Gen 50/200 | best Ao=0.8376 | share(Ao>=0.80)=0.91 | mean managed=131.5
# [NSGA | target=0.80] Gen 60/200 | best Ao=0.8376 | share(Ao>=0.80)=0.99 | mean managed=130.3
# [NSGA | target=0.80] Gen 70/200 | best Ao=0.8377 | share(Ao>=0.80)=1.00 | mean managed=130.3
# [NSGA | target=0.80] Gen 80/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.5
# [NSGA | target=0.80] Gen 90/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.5
# [NSGA | target=0.80] Gen 100/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.2
# [NSGA | target=0.80] Gen 110/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.0
# [NSGA | target=0.80] Gen 120/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=129.8
# [NSGA | target=0.80] Gen 130/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.1
# [NSGA | target=0.80] Gen 140/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=129.8
# [NSGA | target=0.80] Gen 150/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.5
# [NSGA | target=0.80] Gen 160/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=129.7
# [NSGA | target=0.80] Gen 170/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=129.4
# [NSGA | target=0.80] Gen 180/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=129.9
# [NSGA | target=0.80] Gen 190/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.8
# [NSGA | target=0.80] Gen 200/200 | best Ao=0.8376 | share(Ao>=0.80)=1.00 | mean managed=130.0
# [TARGET SUMMARY] target=0.80 | best Ao=0.8376 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.85
# ======================================================================
# [NSGA | target=0.85] Gen 10/200 | best Ao=0.8572 | share(Ao>=0.85)=0.17 | mean managed=151.2
# [NSGA | target=0.85] Gen 20/200 | best Ao=0.8562 | share(Ao>=0.85)=0.16 | mean managed=159.2
# [NSGA | target=0.85] Gen 30/200 | best Ao=0.8553 | share(Ao>=0.85)=0.21 | mean managed=165.6
# [NSGA | target=0.85] Gen 40/200 | best Ao=0.8540 | share(Ao>=0.85)=0.20 | mean managed=168.6
# [NSGA | target=0.85] Gen 50/200 | best Ao=0.8557 | share(Ao>=0.85)=0.34 | mean managed=169.9
# [NSGA | target=0.85] Gen 60/200 | best Ao=0.8548 | share(Ao>=0.85)=0.38 | mean managed=170.7
# [NSGA | target=0.85] Gen 70/200 | best Ao=0.8548 | share(Ao>=0.85)=0.41 | mean managed=171.5
# [NSGA | target=0.85] Gen 80/200 | best Ao=0.8556 | share(Ao>=0.85)=0.41 | mean managed=172.3
# [NSGA | target=0.85] Gen 90/200 | best Ao=0.8566 | share(Ao>=0.85)=0.45 | mean managed=173.1
# [NSGA | target=0.85] Gen 100/200 | best Ao=0.8570 | share(Ao>=0.85)=0.51 | mean managed=174.2
# [NSGA | target=0.85] Gen 110/200 | best Ao=0.8570 | share(Ao>=0.85)=0.64 | mean managed=175.2
# [NSGA | target=0.85] Gen 120/200 | best Ao=0.8568 | share(Ao>=0.85)=0.65 | mean managed=175.6
# [NSGA | target=0.85] Gen 130/200 | best Ao=0.8568 | share(Ao>=0.85)=0.75 | mean managed=176.9
# [NSGA | target=0.85] Gen 140/200 | best Ao=0.8568 | share(Ao>=0.85)=0.82 | mean managed=177.1
# [NSGA | target=0.85] Gen 150/200 | best Ao=0.8577 | share(Ao>=0.85)=0.89 | mean managed=177.9
# [NSGA | target=0.85] Gen 160/200 | best Ao=0.8577 | share(Ao>=0.85)=0.91 | mean managed=178.7
# [NSGA | target=0.85] Gen 170/200 | best Ao=0.8577 | share(Ao>=0.85)=0.97 | mean managed=178.8
# [NSGA | target=0.85] Gen 180/200 | best Ao=0.8577 | share(Ao>=0.85)=1.00 | mean managed=178.8
# [NSGA | target=0.85] Gen 190/200 | best Ao=0.8602 | share(Ao>=0.85)=1.00 | mean managed=179.1
# [NSGA | target=0.85] Gen 200/200 | best Ao=0.8602 | share(Ao>=0.85)=1.00 | mean managed=179.6
# [TARGET SUMMARY] target=0.85 | best Ao=0.8602 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.90
# ======================================================================
# [NSGA | target=0.90] Gen 10/200 | best Ao=0.8611 | share(Ao>=0.90)=0.00 | mean managed=157.7
# [NSGA | target=0.90] Gen 20/200 | best Ao=0.8762 | share(Ao>=0.90)=0.00 | mean managed=186.8
# [NSGA | target=0.90] Gen 30/200 | best Ao=0.8854 | share(Ao>=0.90)=0.00 | mean managed=208.2
# [NSGA | target=0.90] Gen 40/200 | best Ao=0.8940 | share(Ao>=0.90)=0.00 | mean managed=225.4
# [NSGA | target=0.90] Gen 50/200 | best Ao=0.9024 | share(Ao>=0.90)=0.04 | mean managed=239.2
# [NSGA | target=0.90] Gen 60/200 | best Ao=0.9015 | share(Ao>=0.90)=0.06 | mean managed=246.5
# [NSGA | target=0.90] Gen 70/200 | best Ao=0.9031 | share(Ao>=0.90)=0.05 | mean managed=252.6
# [NSGA | target=0.90] Gen 80/200 | best Ao=0.9021 | share(Ao>=0.90)=0.07 | mean managed=260.1
# [NSGA | target=0.90] Gen 90/200 | best Ao=0.9010 | share(Ao>=0.90)=0.05 | mean managed=260.9
# [NSGA | target=0.90] Gen 100/200 | best Ao=0.9007 | share(Ao>=0.90)=0.06 | mean managed=258.6
# [NSGA | target=0.90] Gen 110/200 | best Ao=0.9012 | share(Ao>=0.90)=0.07 | mean managed=257.1
# [NSGA | target=0.90] Gen 120/200 | best Ao=0.9054 | share(Ao>=0.90)=0.12 | mean managed=261.2
# [NSGA | target=0.90] Gen 130/200 | best Ao=0.9010 | share(Ao>=0.90)=0.12 | mean managed=264.1
# [NSGA | target=0.90] Gen 140/200 | best Ao=0.9018 | share(Ao>=0.90)=0.05 | mean managed=263.1
# [NSGA | target=0.90] Gen 150/200 | best Ao=0.9018 | share(Ao>=0.90)=0.06 | mean managed=261.9
# [NSGA | target=0.90] Gen 160/200 | best Ao=0.9029 | share(Ao>=0.90)=0.05 | mean managed=261.0
# [NSGA | target=0.90] Gen 170/200 | best Ao=0.9029 | share(Ao>=0.90)=0.04 | mean managed=266.4
# [NSGA | target=0.90] Gen 180/200 | best Ao=0.9049 | share(Ao>=0.90)=0.06 | mean managed=267.9
# [NSGA | target=0.90] Gen 190/200 | best Ao=0.9049 | share(Ao>=0.90)=0.05 | mean managed=268.4
# [NSGA | target=0.90] Gen 200/200 | best Ao=0.9029 | share(Ao>=0.90)=0.04 | mean managed=266.4
# [TARGET SUMMARY] target=0.90 | best Ao=0.9029 | share_ge_target=0.04
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.92
# ======================================================================
# [NSGA | target=0.92] Gen 10/200 | best Ao=0.8600 | share(Ao>=0.92)=0.00 | mean managed=166.9
# [NSGA | target=0.92] Gen 20/200 | best Ao=0.8780 | share(Ao>=0.92)=0.00 | mean managed=189.4
# [NSGA | target=0.92] Gen 30/200 | best Ao=0.8894 | share(Ao>=0.92)=0.00 | mean managed=210.6
# [NSGA | target=0.92] Gen 40/200 | best Ao=0.8928 | share(Ao>=0.92)=0.00 | mean managed=218.5
# [NSGA | target=0.92] Gen 50/200 | best Ao=0.9052 | share(Ao>=0.92)=0.00 | mean managed=242.4
# [NSGA | target=0.92] Gen 60/200 | best Ao=0.9128 | share(Ao>=0.92)=0.00 | mean managed=256.2
# [NSGA | target=0.92] Gen 70/200 | best Ao=0.9146 | share(Ao>=0.92)=0.00 | mean managed=262.0
# [NSGA | target=0.92] Gen 80/200 | best Ao=0.9171 | share(Ao>=0.92)=0.00 | mean managed=268.0
# [NSGA | target=0.92] Gen 90/200 | best Ao=0.9210 | share(Ao>=0.92)=0.03 | mean managed=271.3
# [NSGA | target=0.92] Gen 100/200 | best Ao=0.9210 | share(Ao>=0.92)=0.05 | mean managed=273.1
# [NSGA | target=0.92] Gen 110/200 | best Ao=0.9208 | share(Ao>=0.92)=0.05 | mean managed=270.7
# [NSGA | target=0.92] Gen 120/200 | best Ao=0.9226 | share(Ao>=0.92)=0.04 | mean managed=279.6
# [NSGA | target=0.92] Gen 130/200 | best Ao=0.9222 | share(Ao>=0.92)=0.03 | mean managed=281.4
# [NSGA | target=0.92] Gen 140/200 | best Ao=0.9222 | share(Ao>=0.92)=0.05 | mean managed=283.9
# [NSGA | target=0.92] Gen 150/200 | best Ao=0.9207 | share(Ao>=0.92)=0.03 | mean managed=282.0
# [NSGA | target=0.92] Gen 160/200 | best Ao=0.9207 | share(Ao>=0.92)=0.03 | mean managed=286.8
# [NSGA | target=0.92] Gen 170/200 | best Ao=0.9229 | share(Ao>=0.92)=0.05 | mean managed=288.2
# [NSGA | target=0.92] Gen 180/200 | best Ao=0.9229 | share(Ao>=0.92)=0.05 | mean managed=289.5
# [NSGA | target=0.92] Gen 190/200 | best Ao=0.9229 | share(Ao>=0.92)=0.06 | mean managed=295.0
# [NSGA | target=0.92] Gen 200/200 | best Ao=0.9228 | share(Ao>=0.92)=0.05 | mean managed=297.1
# [TARGET SUMMARY] target=0.92 | best Ao=0.9228 | share_ge_target=0.05
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.94
# ======================================================================
# [NSGA | target=0.94] Gen 10/200 | best Ao=0.8643 | share(Ao>=0.94)=0.00 | mean managed=165.3
# [NSGA | target=0.94] Gen 20/200 | best Ao=0.8767 | share(Ao>=0.94)=0.00 | mean managed=192.1
# [NSGA | target=0.94] Gen 30/200 | best Ao=0.8901 | share(Ao>=0.94)=0.00 | mean managed=216.0
# [NSGA | target=0.94] Gen 40/200 | best Ao=0.8997 | share(Ao>=0.94)=0.00 | mean managed=239.6
# [NSGA | target=0.94] Gen 50/200 | best Ao=0.9073 | share(Ao>=0.94)=0.00 | mean managed=249.3
# [NSGA | target=0.94] Gen 60/200 | best Ao=0.9149 | share(Ao>=0.94)=0.00 | mean managed=264.7
# [NSGA | target=0.94] Gen 70/200 | best Ao=0.9233 | share(Ao>=0.94)=0.00 | mean managed=265.5
# [NSGA | target=0.94] Gen 80/200 | best Ao=0.9255 | share(Ao>=0.94)=0.00 | mean managed=281.3
# [NSGA | target=0.94] Gen 90/200 | best Ao=0.9283 | share(Ao>=0.94)=0.00 | mean managed=285.4
# [NSGA | target=0.94] Gen 100/200 | best Ao=0.9302 | share(Ao>=0.94)=0.00 | mean managed=297.2
# [NSGA | target=0.94] Gen 110/200 | best Ao=0.9329 | share(Ao>=0.94)=0.00 | mean managed=297.0
# [NSGA | target=0.94] Gen 120/200 | best Ao=0.9373 | share(Ao>=0.94)=0.00 | mean managed=302.6
# [NSGA | target=0.94] Gen 130/200 | best Ao=0.9375 | share(Ao>=0.94)=0.00 | mean managed=314.5
# [NSGA | target=0.94] Gen 140/200 | best Ao=0.9401 | share(Ao>=0.94)=0.01 | mean managed=314.2
# [NSGA | target=0.94] Gen 150/200 | best Ao=0.9401 | share(Ao>=0.94)=0.01 | mean managed=314.1
# [NSGA | target=0.94] Gen 160/200 | best Ao=0.9407 | share(Ao>=0.94)=0.04 | mean managed=321.0
# [NSGA | target=0.94] Gen 170/200 | best Ao=0.9422 | share(Ao>=0.94)=0.04 | mean managed=319.9
# [NSGA | target=0.94] Gen 180/200 | best Ao=0.9421 | share(Ao>=0.94)=0.03 | mean managed=315.9
# [NSGA | target=0.94] Gen 190/200 | best Ao=0.9414 | share(Ao>=0.94)=0.05 | mean managed=314.6
# [NSGA | target=0.94] Gen 200/200 | best Ao=0.9418 | share(Ao>=0.94)=0.06 | mean managed=318.0
# [TARGET SUMMARY] target=0.94 | best Ao=0.9418 | share_ge_target=0.06
#
# ======================================================================
# [INTEGRATED SUMMARY]
# All collected solutions        = 960
# Unique integrated solutions    = 960
# ======================================================================
#
# [TARGET-WISE SUMMARY]
#  target_ao  n_solutions   ao_min   ao_max     cost_min     cost_max    wait_min    wait_max  managed_min  managed_max  share_ge_target
#       0.10           80 0.752401 0.832156 3.109451e+07 3.109451e+07 3509.473710 5741.176117            0            0           1.0000
#       0.20           80 0.754786 0.764910 3.109451e+07 3.109451e+07 5360.372623 5667.617391            0            0           1.0000
#       0.30           80 0.753431 0.835321 3.109451e+07 3.109451e+07 3429.693167 5709.362117            0            0           1.0000
#       0.40           80 0.754990 0.836193 3.109451e+07 3.109451e+07 3407.828081 5661.327974            0            0           1.0000
#       0.50           80 0.752691 0.829690 3.109451e+07 3.109451e+07 3572.054334 5732.214672            0            0           1.0000
#       0.60           80 0.751797 0.833513 3.109451e+07 3.109451e+07 3475.194562 5759.889938            0            0           1.0000
#       0.70           80 0.755633 0.834794 3.109451e+07 3.109451e+07 3442.932380 5641.581145            0            0           1.0000
#       0.80           80 0.821203 0.837570 3.109451e+07 3.109451e+07 3373.382359 3790.281011            0            0           1.0000
#       0.85           80 0.850101 0.860218 3.109451e+07 3.109451e+07 2822.666745 3065.052736            0            0           1.0000
#       0.90           80 0.855241 0.902899 3.129334e+07 3.511771e+07 1859.893840 2941.183690            1           12           0.0375
#       0.92           80 0.874112 0.922767 3.172218e+07 4.020467e+07 1442.093967 2498.935825            3           26           0.0500
#       0.94           80 0.847504 0.941835 3.141679e+07 4.949895e+07 1057.716156 3128.204975            1           49           0.0625
#
# ==============================
# [FINAL SUMMARY | REPRESENTATIVE TARGET]
# Representative Target = 0.94
# Best Ao = 0.9418
# Share(Ao >= 0.94) = 0.06
# Candidate spare-demand parts = 606
# ==============================
#
# [BEST POLICY | REPRESENTATIVE TARGET]
# Ao                  = 0.9418
# DT_diag_h           = 6.48
# DT_wait_h           = 1057.72
# DT_restore_h        = 17.79
# DT_total_h          = 1081.99
# stock_cost          = 17528036
# hold_cost           = 876402
# total_cost          = 49498951
# managed parts       = 45
# total stock units   = 71
# selected pre-buy    = 59
# selected protection = 20
# /tmp/ipykernel_12822/3351770406.py:1252: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
# [TOP selected managed parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0216 RAD-L5-0214      6      6             O   2.605620       5.211240   0.994545          4994.25      2.98    8.706019     6.194436   0.223237             0            0                0                1        0        0        0                 0               0.300050        228594.0             1.00
# RAD-L6-0996 RAD-L5-0995      6      6             O   0.169559       0.339117   0.287601          3955.50      2.98    3.212381     2.315202   0.018400             0            0                0                1        0        0        0                 0               0.300005        238210.0             0.15
# RAD-L6-0999 RAD-L5-0995      6      6             O   0.153168       0.306335   0.263860          3273.00      2.98    6.343838     4.786498   0.013767             0            0                0                1        0        0        0                 0               0.300005        303245.0             0.15
# RAD-L6-0997 RAD-L5-0995      6      6             O   0.142411       0.284823   0.247852          1031.25      2.98    9.404851     6.608896   0.004061             0            0                0                1        0        0        0                 0               0.300004        143076.0             0.15
# RAD-L6-1000 RAD-L5-0995      6      6             O   0.137025       0.274049   0.239705          3270.75      2.98   16.294688    10.744912   0.012330             0            0                0                1        0        0        0                 0               0.300004        179607.0             0.15
# RAD-L6-0656 RAD-L5-0654      6      6             O   0.198401       0.396802   0.327533          3919.50      2.98   16.015350    13.813431   0.013373             0            0                0                1        0        0        0                 0               0.300004        299799.0             0.15
# RAD-L6-0067 RAD-L5-0059      6      6             O   0.195910       0.391819   0.324174           837.75      2.98   15.317006    11.745263   0.002860             0            0                0                1        0        0        0                 0               0.300004        226797.0             0.15
# RAD-L6-0827 RAD-L5-0819      6      6             O   0.195771       0.391541   0.323986          1127.25      2.98   11.452838     8.688259   0.003818             0            0                0                1        0        0        0                 0               0.300004        252021.0             0.15
# RAD-L6-0634 RAD-L5-0627      6      6             O   0.195592       0.391184   0.323744          1435.50      2.98    7.355887     5.811975   0.004837             0            0                0                1        0        0        0                 0               0.300004        153292.0             0.15
# RAD-L6-0696 RAD-L5-0691      6      6             O   0.195364       0.390727   0.323435          5382.75      2.98    8.380125     5.963397   0.018037             0            0                0                1        0        0        0                 0               0.300004        256847.0             0.15
# RAD-L6-0510 RAD-L5-0507      6      6             O   0.194912       0.389824   0.322824          1455.00      2.98   16.769027    12.419332   0.004908             0            0                0                1        0        0        0                 0               0.300004        143251.0             0.15
# RAD-L6-0318 RAD-L5-0316      6      6             O   0.194451       0.388901   0.322199          5424.75      2.98   15.503231    12.230684   0.018113             0            0                0                1        0        0        0                 0               0.300004        297965.0             0.15
# RAD-L6-0836 RAD-L5-0828      6      6             O   0.194449       0.388898   0.322196          2881.50      2.98   10.292101     8.866762   0.009634             0            0                0                1        0        0        0                 0               0.300004        240674.0             0.15
# RAD-L6-0925 RAD-L5-0922      6      6             O   0.194431       0.388862   0.322172          1280.25      2.98   15.829125    10.843140   0.004308             0            0                0                1        0        0        0                 0               0.300004        284275.0             0.15
# RAD-L6-0056 RAD-L5-0050      6      6             O   0.194242       0.388484   0.321916          5382.75      2.98   11.711701     8.523909   0.017942             0            0                0                1        0        0        0                 0               0.300004        265461.0             0.15
#
# [TOP unmanaged but high baseline-wait parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0639 RAD-L5-0636      6      6             O   0.086576       0.173152   0.158990          6459.00      2.98   12.151181     9.848678   0.009594             1            1                0                0        0        0        0                 0                6459.00        268293.0             0.15
# RAD-L6-0751 RAD-L5-0746      6      6             O   0.046042       0.092084   0.087972          6453.75      2.98   12.011512     8.207610   0.005097             1            1                0                0        0        0        0                 0                6453.75        279090.0             0.15
# RAD-L6-0647 RAD-L5-0645      6      6             O   0.119097       0.238193   0.211950          6442.50      2.98    9.274202     8.253251   0.013161             1            1                0                0        0        0        0                 0                6442.50        244145.0             0.15
# RAD-L6-0728 RAD-L5-0727      6      6             O   0.030535       0.061070   0.059243          6409.50      2.98   14.240364    10.687555   0.003358             1            0                0                0        0        0        0                 0                6409.50        288265.0             0.15
# RAD-L6-0047 RAD-L5-0041      6      6             O   0.028334       0.056667   0.055092          6376.50      2.98    8.994377     7.097598   0.003099             1            0                0                0        0        0        0                 0                6376.50        299034.0             0.15
# RAD-L6-0785 RAD-L5-0782      6      6             O   0.028376       0.056751   0.055171          6289.50      2.98    4.096950     3.153471   0.003059             1            0                0                0        0        0        0                 0                6289.50        482305.0             0.15
# RAD-L6-0533 RAD-L5-0526      6      6             O   0.142214       0.284429   0.247556          6171.00      2.98    9.138676     8.411341   0.015055             1            1                1                0        0        0        0                 0                6171.00        247417.0             0.15
# RAD-L6-0826 RAD-L5-0819      6      6             O   0.016105       0.032210   0.031696          6130.50      2.98   11.711701    10.633187   0.001694             1            0                0                0        0        0        0                 0                6130.50        127471.0             0.15
# RAD-L6-0167 RAD-L5-0160      6      6             O   0.164408       0.328815   0.280224          6114.75      2.98    7.495556     6.362318   0.017241             1            1                1                0        0        0        0                 0                6114.75        390037.0             0.15
# RAD-L6-0723 RAD-L5-0718      6      6             O   0.114260       0.228520   0.204290          6091.50      2.98    5.323501     4.683676   0.011933             1            1                0                0        0        0        0                 0                6091.50        376812.0             0.15
# RAD-L6-0153 RAD-L5-0151      6      6             O   0.195979       0.391958   0.324268          6088.50      2.98   19.088062    12.697607   0.020484             1            1                1                0        0        0        0                 0                6088.50        326534.0             0.15
# RAD-L6-0313 RAD-L5-0307      6      6             O   0.134960       0.269920   0.236560          6008.25      2.98   13.920319     9.506352   0.013914             1            1                1                0        0        0        0                 0                6008.25        285625.0             0.15
# RAD-L6-0579 RAD-L5-0571      6      6             O   0.075559       0.151118   0.140254          5898.00      2.98   12.802969    10.909563   0.007649             1            1                0                0        0        0        0                 0                5898.00        314920.0             0.15
# RAD-L6-0744 RAD-L5-0737      6      6             O   0.157807       0.315614   0.270659          5873.25      2.98    7.497263     5.371874   0.015893             1            1                1                0        0        0        0                 0                5873.25        134558.0             0.15
# RAD-L6-0541 RAD-L5-0535      6      6             O   0.108783       0.217567   0.195526          5865.00      2.98   11.534251     9.935735   0.010949             1            1                0                0        0        0        0                 0                5865.00        230199.0             0.15
#
# [TOP protection candidates | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0217 RAD-L5-0214      6      6             O   0.191592       0.383184   0.318313          6463.50      2.98    7.495556     5.305444   0.021232             1            1                1                1        1        0        0                 1                   0.30        132367.0             0.15
# RAD-L6-0153 RAD-L5-0151      6      6             O   0.195979       0.391958   0.324268          6088.50      2.98   19.088062    12.697607   0.020484             1            1                1                0        0        0        0                 0                6088.50        326534.0             0.15
# RAD-L6-0811 RAD-L5-0810      6      6             O   0.189339       0.378678   0.315234          6186.75      2.98    5.400525     4.079621   0.020081             1            1                1                1        1        0        0                 1                   0.30        285020.0             0.15
# RAD-L6-0631 RAD-L5-0627      6      6             O   0.182799       0.365597   0.306218          6352.50      2.98   11.220056     8.704654   0.019921             1            1                1                1        1        0        0                 1                   0.30        253682.0             0.15
# RAD-L6-0640 RAD-L5-0636      6      6             O   0.188141       0.376282   0.313592          5965.50      2.98    9.074327     8.235088   0.019255             1            1                1                1        1        0        0                 1                   0.30        167349.0             0.15
# RAD-L6-0863 RAD-L5-0855      6      6             O   0.184533       0.369066   0.308620          5985.00      2.98    4.117426     3.777800   0.018933             1            1                1                1        1        0        0                 1                   0.30        145640.0             0.15
# RAD-L6-0994 RAD-L5-0986      6      6             O   0.186203       0.372406   0.310925          5922.00      2.98   10.801050     8.045831   0.018917             1            1                1                1        1        0        0                 1                   0.30        183052.0             0.15
# RAD-L6-0229 RAD-L5-0224      6      6             O   0.173776       0.347551   0.293584          6276.75      2.98    5.916301     4.767444   0.018700             1            1                1                1        1        0        0                 1                   0.30        424589.0             0.15
# RAD-L6-0044 RAD-L5-0041      6      6             O   0.177448       0.354896   0.298753          5939.25      2.98   13.441839    11.277856   0.018090             1            1                1                1        1        0        0                 1                   0.30        301230.0             0.15
# RAD-L6-0642 RAD-L5-0636      6      6             O   0.180248       0.360496   0.302670          5774.25      2.98    7.542112     5.376862   0.017848             1            1                1                1        1        0        0                 1                   0.30        333830.0             0.15
# RAD-L6-0431 RAD-L5-0425      6      6             O   0.177022       0.354045   0.298156          5805.75      2.98   12.477075     9.231937   0.017635             1            1                1                1        1        0        0                 1                   0.30        144321.0             0.15
# RAD-L6-0167 RAD-L5-0160      6      6             O   0.164408       0.328815   0.280224          6114.75      2.98    7.495556     6.362318   0.017241             1            1                1                0        0        0        0                 0                6114.75        390037.0             0.15
# RAD-L6-0406 RAD-L5-0398      6      6             O   0.183437       0.366873   0.307103          5430.75      2.98   11.672703    11.402071   0.017103             1            1                1                1        1        0        0                 1                   0.30        110820.0             0.15
# RAD-L6-0747 RAD-L5-0746      6      6             O   0.166055       0.332110   0.282592          5968.50      2.98   12.058069     8.719334   0.017004             1            1                1                1        1        0        0                 1                   0.30        398886.0             0.15
# RAD-L6-0970 RAD-L5-0968      6      6             O   0.170632       0.341263   0.289128          5659.50      2.98    5.767126     4.056662   0.016556             1            1                1                1        1        0        0                 1                   0.30        189355.0             0.15

# %%
# ============================================================
# COLAB ONE-CHUNK CODE
# NSGA-II baseline model
# + target sweep integration (without changing objective/constraint structure)
# + Pareto front visualization with dominated solutions
# + integrated trade-off map across multiple Ao targets
# ------------------------------------------------------------
# 핵심
#   - 목적함수/제약식 구조는 그대로 유지
#   - AO_TARGET 하나만 고정하지 않고 AO_TARGET_GRID를 순회
#   - 각 target에서 NSGA-II를 반복 수행
#   - 결과를 합쳐 cost-Ao 통합 시각화
#   - 대표 target(기본 0.94)에 대해서 상세 진단표 출력
#
# [PM EFFECT REBALANCING PATCH]
#   - PM의 고장률 완화 효과는 약하게 반영
#   - PM의 복원시간(정비시간) 단축 효과는 더 크게 반영
#   - 구조는 유지하고 계수만 현실적으로 조정
#
# [AGING PATCH]
#   - 부품 노화도(RAD_DEGRADATION_INDEX, ANNUAL_RAD_HOURS, ENV_RESISTANCE)를
#     하나의 Aging Index로 통합
#   - Aging Index는 고장률(Failure Rate)에만 추가 반영
#   - 기존 objective / constraint / NSGA 구조는 변경하지 않음
# ============================================================

import os
import re
import math
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt


# ============================================================
# 0) File load
# ============================================================
USE_COLAB_UPLOAD = False

if USE_COLAB_UPLOAD:
    from google.colab import files
    uploaded = files.upload()
    XLSX_PATH = list(uploaded.keys())[0]
else:
    XLSX_PATH = "radar_1000_parts_bom.xlsx"

df = pd.read_excel(XLSX_PATH, sheet_name=0)
print(f"[LOAD] shape = {df.shape}")


# ============================================================
# 1) Column helpers
# ============================================================
def find_col(df, candidates):
    lower_map = {c.lower(): c for c in df.columns}
    for cand in candidates:
        if cand.lower() in lower_map:
            return lower_map[cand.lower()]
    return None

col_part = find_col(df, ["Part_ID"])
col_parent = find_col(df, ["Parent_ID"])
col_level = find_col(df, ["Level"])
col_echelon = find_col(df, ["Maint_Echelon"])
col_fr = find_col(df, ["Failure_Rate"])
col_price = find_col(df, ["Unit_Price_KRW"])
col_transport_cost = find_col(df, ["Transport_Cost_KRW"])
col_lead = find_col(df, ["Total_Lead_Time_H"])
col_transport_time = find_col(df, ["Transport_Time_H"])
col_cm_cost = find_col(df, ["CM_Cost_KRW"])
col_cm_time = find_col(df, ["CM_Time_Hours"])
col_condemn = find_col(df, ["Condemnation_Rate_Pct"])
col_pm = find_col(df, ["PM_Cycle"])

# ============================================================
# [ADDED] Aging-related columns
# ============================================================
col_rad_idx = find_col(df, ["Rad_Degradation_Index"])
col_ann_rad = find_col(df, ["Annual_Rad_Hours"])
col_env_res = find_col(df, ["Env_Resistance"])

required = [col_part, col_parent, col_level, col_echelon, col_fr]
if any(x is None for x in required):
    raise ValueError({
        "Part_ID": col_part,
        "Parent_ID": col_parent,
        "Level": col_level,
        "Maint_Echelon": col_echelon,
        "Failure_Rate": col_fr
    })

for c in [
    col_price, col_transport_cost, col_lead, col_transport_time, col_fr,
    col_cm_cost, col_cm_time, col_condemn,
    col_rad_idx, col_ann_rad, col_env_res
]:
    if c is not None:
        df[c] = pd.to_numeric(df[c], errors="coerce")


# ============================================================
# 2) Settings
# ============================================================
YEARS = 2.0
T_OBS_HOURS = YEARS * 365.0 * 24.0
HOURS_PER_YEAR = 365.0 * 24.0

# ------------------------------------------------------------
# target sweep
# ------------------------------------------------------------
AO_TARGET_GRID = [
    0.10, 0.20, 0.30, 0.40, 0.50,
    0.60, 0.70, 0.80, 0.85, 0.90,
    0.92, 0.94
]
REPRESENTATIVE_TARGET = 0.94
AO_LINES = [0.90, 0.91, 0.92, 0.93, 0.94]

PMIN = 0.15
LONG_LEAD_PERCENTILE = 90
AO_IMPACT_PERCENTILE = 70
LONG_CORE_IMPACT_PERCENTILE = 70

POP = 80
GEN = 200
SEED = 42

AO_COST_PENALTY = 8.0e8
ITEM_COUNT_WEIGHT = 1.0
STOCK_UNIT_WEIGHT = 0.05
h_pre = 0.05

ABS_CAP_SMALL = 3
ABS_CAP_MED = 4
ABS_CAP_LARGE = 6

# ------------------------------------------------------------
# tuned baseline support parameters
# ------------------------------------------------------------
BASELINE_WAIT_FRACTION_BY_ECHELON = {
    "O": 0.75,
    "I": 0.90,
    "D": 1.00,
}
MIN_WAIT_FLOOR_H_BY_ECHELON = {
    "O": 1.0,
    "I": 6.0,
    "D": 24.0,
}

TOPK_PRINT = 15

# ------------------------------------------------------------
# PM effect rebalancing parameters
# ------------------------------------------------------------
PM_EFFECT_ON_FAILURE = 0.03
PM_EFFECT_ON_RESTORE = 0.18

# ============================================================
# [ADDED] Aging effect parameters
# ------------------------------------------------------------
# 해석:
# - RAD_DEGRADATION_INDEX : 방사 민감도 / 열화 주지표
# - ANNUAL_RAD_HOURS      : 연간 빔 방사 노출량(약한 보정)
# - ENV_RESISTANCE        : 환경 완화항 (1=심함, 5=완화)
# ============================================================
AGING_ALPHA_HOURS = 0.35      # annual_rad_hours 보정 강도
AGING_GAMMA_ENV = 0.40        # env_resistance 완화 강도
AGING_BETA_FR = 0.60          # aging index -> failure rate 반영 강도
AGING_MULTIPLIER_CAP = 2.50   # 과도한 증폭 방지 상한
AGING_USE_EXP = True          # True: exp(beta*AI), False: 1+beta*AI


# ============================================================
# 3) Helpers
# ============================================================
def minmax(x):
    x = np.asarray(x, dtype=float)
    lo, hi = np.nanmin(x), np.nanmax(x)
    if hi - lo < 1e-12:
        return np.zeros_like(x, dtype=float)
    return (x - lo) / (hi - lo)

def parse_level_to_int(v):
    if pd.isna(v):
        return 0
    s = str(v)
    m = re.search(r"(\d+)", s)
    return int(m.group(1)) if m else 0

def map_echelon(v):
    if pd.isna(v):
        return "X"
    s = str(v).strip().lower()

    if any(k in s for k in ["organizational", "operational", "operator", "field", "unit", "line", "o-level", "o level"]):
        return "O"
    if any(k in s for k in ["현장", "운용", "부대", "일선"]):
        return "O"

    if any(k in s for k in ["intermediate", "support", "shop", "base", "i-level", "i level", "direct support"]):
        return "I"
    if any(k in s for k in ["중간", "야전정비", "지원", "정비대"]):
        return "I"

    if any(k in s for k in ["depot", "factory", "overhaul", "sustainment", "d-level", "d level"]):
        return "D"
    if any(k in s for k in ["창정비", "공창", "후방"]):
        return "D"

    if s in ["o", "org", "op"]:
        return "O"
    if s in ["i", "int"]:
        return "I"
    if s in ["d", "dep"]:
        return "D"

    return "X"

def pm_cycle_to_days(v):
    if pd.isna(v):
        return np.nan

    if isinstance(v, (int, float, np.integer, np.floating)):
        x = float(v)
        if x <= 0:
            return np.nan
        return x if x <= 400 else np.nan

    s = str(v).strip().lower()
    if s in ["", "nan", "none", "null"]:
        return np.nan

    if "분기" in s or "quarter" in s:
        return 365.0 / 4.0
    if "반기" in s or "semi" in s or "half" in s:
        return 365.0 / 2.0
    if "연" in s or "annual" in s or "year" in s:
        return 365.0

    m = re.search(r"(\d+(\.\d+)?)\s*(day|days|d|month|months|m|year|years|y)", s)
    if m:
        val = float(m.group(1))
        unit = m.group(3)
        if unit in ["day", "days", "d"]:
            return val
        if unit in ["month", "months", "m"]:
            return val * 30.4167
        if unit in ["year", "years", "y"]:
            return val * 365.0

    m2 = re.search(r"(\d+(\.\d+)?)", s)
    if m2:
        return float(m2.group(1))

    return np.nan

def poisson_tail_prob(mu, s):
    mu = float(max(mu, 0.0))
    s = int(max(s, 0))
    if mu < 1e-12:
        return 0.0

    term = math.exp(-mu)
    cdf = term
    for k in range(1, s + 1):
        term *= mu / k
        cdf += term
    tail = 1.0 - cdf
    return min(max(tail, 0.0), 1.0)

def long_dynamic_cap_from_lambda(lam_2y):
    base = int(np.ceil(lam_2y))
    if lam_2y < 1.0:
        buffer_i = 1
        abs_cap_i = ABS_CAP_SMALL
    elif lam_2y < 2.5:
        buffer_i = 1
        abs_cap_i = ABS_CAP_MED
    else:
        buffer_i = 2
        abs_cap_i = ABS_CAP_LARGE
    total_cap_i = min(base + buffer_i, abs_cap_i)
    return max(total_cap_i, 1)

def solution_signature(y_manage, sO, sI, sD):
    return (
        "Y:" + ",".join(map(str, y_manage.astype(int).tolist())) +
        "|O:" + ",".join(map(str, sO.astype(int).tolist())) +
        "|I:" + ",".join(map(str, sI.astype(int).tolist())) +
        "|D:" + ",".join(map(str, sD.astype(int).tolist()))
    )


# ============================================================
# 4) Raw arrays
# ============================================================
n_all = df.shape[0]

part_id_all = df[col_part].astype(str).to_numpy()
parent_id_all = df[col_parent].astype(str).to_numpy()
level_num_all = df[col_level].apply(parse_level_to_int).to_numpy(int)
echelon_cat_all = df[col_echelon].apply(map_echelon).to_numpy()

FR_all = df[col_fr].fillna(0).clip(lower=0).to_numpy(float)

unit_price_all = df[col_price].fillna(0).clip(lower=0).to_numpy(float) if col_price else np.zeros(n_all)
transport_cost_all = df[col_transport_cost].fillna(0).clip(lower=0).to_numpy(float) if col_transport_cost else np.zeros(n_all)
proc_cost_all = unit_price_all + transport_cost_all

lead_raw_all = df[col_lead].to_numpy(float) if col_lead else np.full(n_all, np.nan)
transport_time_all = df[col_transport_time].fillna(0).clip(lower=0).to_numpy(float) if col_transport_time else np.zeros(n_all)
lead_all = (
    pd.Series(lead_raw_all)
    .fillna(pd.Series(transport_time_all))
    .fillna(0)
    .clip(lower=0)
    .to_numpy(float)
)

cm_cost_all = df[col_cm_cost].fillna(0).clip(lower=0).to_numpy(float) if col_cm_cost else np.zeros(n_all)
cm_time_all = df[col_cm_time].fillna(0).clip(lower=0).to_numpy(float) if col_cm_time else np.zeros(n_all)

if col_condemn:
    condemn_all = df[col_condemn].fillna(0).clip(lower=0, upper=100).to_numpy(float) / 100.0
else:
    condemn_all = np.zeros(n_all, dtype=float)

if col_pm:
    pm_days_all = df[col_pm].apply(pm_cycle_to_days).to_numpy(float)
else:
    pm_days_all = np.full(n_all, np.nan)

pm_freq_all = np.where(np.isfinite(pm_days_all) & (pm_days_all > 0), 365.0 / pm_days_all, 0.0)
pm_norm_all = np.clip(pm_freq_all / 4.0, 0.0, 1.0)

# ============================================================
# [ADDED] Aging raw arrays
# ============================================================
if col_rad_idx is not None:
    rad_idx_all = df[col_rad_idx].fillna(0).clip(lower=0).to_numpy(float)
else:
    rad_idx_all = np.zeros(n_all, dtype=float)

if col_ann_rad is not None:
    annual_rad_hours_all = df[col_ann_rad].fillna(0).clip(lower=0).to_numpy(float)
else:
    annual_rad_hours_all = np.zeros(n_all, dtype=float)

if col_env_res is not None:
    env_res_all = df[col_env_res].fillna(3).clip(lower=1, upper=5).to_numpy(float)
else:
    env_res_all = np.full(n_all, 3.0, dtype=float)

# ------------------------------------------------------------
# Aging index construction
#   AI_i = R_norm * (1 + alpha * H_norm) * (1 - gamma*(E-1)/4)
#   lambda_adj = lambda * exp(beta * AI_i)
# ------------------------------------------------------------
rad_norm_all = minmax(rad_idx_all)

positive_rad_hours = annual_rad_hours_all[annual_rad_hours_all > 0]
if len(positive_rad_hours) > 0:
    rad_hours_ref = float(np.nanpercentile(positive_rad_hours, 95))
    if rad_hours_ref <= 0:
        rad_hours_ref = float(np.nanmax(annual_rad_hours_all)) if np.nanmax(annual_rad_hours_all) > 0 else 1.0
else:
    rad_hours_ref = 1.0

hours_norm_all = np.clip(annual_rad_hours_all / rad_hours_ref, 0.0, 1.5)

env_mitigation_all = 1.0 - AGING_GAMMA_ENV * ((env_res_all - 1.0) / 4.0)
env_mitigation_all = np.clip(env_mitigation_all, 0.55, 1.00)

aging_index_all = rad_norm_all * (1.0 + AGING_ALPHA_HOURS * hours_norm_all) * env_mitigation_all
aging_index_all = np.clip(aging_index_all, 0.0, None)

if AGING_USE_EXP:
    aging_multiplier_all = np.exp(AGING_BETA_FR * aging_index_all)
else:
    aging_multiplier_all = 1.0 + AGING_BETA_FR * aging_index_all

aging_multiplier_all = np.clip(aging_multiplier_all, 1.0, AGING_MULTIPLIER_CAP)

# ============================================================
# [MODIFIED] PM effect coefficients
# - gamma_all : PM의 고장률 완화 효과(약하게)
# - delta_all : PM의 복원시간 단축 효과(강하게)
# ============================================================
gamma_all = PM_EFFECT_ON_FAILURE * pm_norm_all
delta_all = PM_EFFECT_ON_RESTORE * pm_norm_all

print(
    f"[PM EFFECT] failure reduction max={PM_EFFECT_ON_FAILURE:.2f} | "
    f"restore reduction max={PM_EFFECT_ON_RESTORE:.2f}"
)
print(
    f"[AGING EFFECT] "
    f"hours_ref={rad_hours_ref:.2f}h | "
    f"AI mean={aging_index_all.mean():.4f} | "
    f"AI max={aging_index_all.max():.4f} | "
    f"FR multiplier mean={aging_multiplier_all.mean():.4f} | "
    f"FR multiplier max={aging_multiplier_all.max():.4f}"
)


# ============================================================
# 5) Build BOM structure
# ============================================================
part_to_idx = {pid: i for i, pid in enumerate(part_id_all)}

children_map = {i: [] for i in range(n_all)}
for i in range(n_all):
    p = parent_id_all[i]
    if pd.notna(p):
        p = str(p)
        if p in part_to_idx:
            children_map[part_to_idx[p]].append(i)

is_leaf_all = np.array([len(children_map[i]) == 0 for i in range(n_all)], dtype=bool)

def get_ancestor_chain(idx):
    chain_rev = [idx]
    seen = {idx}
    cur_parent = parent_id_all[idx]
    hop = 0
    while pd.notna(cur_parent) and str(cur_parent) not in ["", "nan", "None", "null"]:
        cur_parent = str(cur_parent)
        if cur_parent not in part_to_idx:
            break
        pidx = part_to_idx[cur_parent]
        if pidx in seen:
            break
        chain_rev.append(pidx)
        seen.add(pidx)
        cur_parent = parent_id_all[pidx]
        hop += 1
        if hop > 30:
            break
    return list(reversed(chain_rev))

all_ancestor_chains = [get_ancestor_chain(i) for i in range(n_all)]
depth_all = np.array([len(ch) for ch in all_ancestor_chains], dtype=int)


# ============================================================
# 6) Real spare-demand part selection
# ============================================================
has_physical_attr = (
    (unit_price_all > 0) |
    (cm_time_all > 0) |
    (lead_all > 0)
)

spare_demand_mask = (
    (level_num_all >= 3) &
    is_leaf_all &
    (FR_all > 0) &
    has_physical_attr
)

if spare_demand_mask.sum() < 20:
    spare_demand_mask = (
        (level_num_all >= 3) &
        (FR_all > 0) &
        has_physical_attr
    )

spare_idx = np.where(spare_demand_mask)[0]
print(f"[SPARE-DEMAND FILTER] count = {len(spare_idx)} / {n_all}")

if len(spare_idx) == 0:
    raise ValueError("No real spare-demand parts found.")


# ============================================================
# 7) Common arrays
# ============================================================
# ============================================================
# [MODIFIED]
# 기존 failure rate에
#   1) 부품 노화도(aging multiplier) 반영
#   2) PM 완화효과 반영
# ============================================================
annual_fr_sp = (
    FR_all[spare_idx]
    * aging_multiplier_all[spare_idx]
    * (1.0 - gamma_all[spare_idx])
)
lam_2y_sp = annual_fr_sp * YEARS

proc_cost_sp = proc_cost_all[spare_idx]
lead_sp = lead_all[spare_idx]
transport_sp = transport_time_all[spare_idx]
cm_cost_sp = cm_cost_all[spare_idx]
cm_time_sp = cm_time_all[spare_idx]
condemn_sp = condemn_all[spare_idx]
delta_sp = delta_all[spare_idx]
level_sp = level_num_all[spare_idx]
depth_sp = depth_all[spare_idx]
echelon_sp = echelon_cat_all[spare_idx]
part_id_sp = part_id_all[spare_idx]
parent_id_sp = parent_id_all[spare_idx]
chains_sp = [all_ancestor_chains[i] for i in spare_idx]

# sibling normalization
parent_group_map = {}
for local_idx, global_idx in enumerate(spare_idx):
    p = parent_id_all[global_idx]
    p = str(p) if pd.notna(p) else f"ROOT_{part_id_all[global_idx]}"
    parent_group_map.setdefault(p, []).append(local_idx)

lambda_eff_sp = annual_fr_sp.copy()
for p, members in parent_group_map.items():
    if len(members) <= 1:
        continue
    fr_sub = annual_fr_sp[members]
    total = fr_sub.sum()
    if total > 1e-12:
        shares = fr_sub / total
        lambda_eff_sp[members] = total * shares / len(members) * 1.2
    else:
        lambda_eff_sp[members] = annual_fr_sp[members]

def node_diag_contrib(level_value):
    if level_value <= 1:
        return 0.10
    if level_value == 2:
        return 0.18
    if level_value == 3:
        return 0.35
    if level_value == 4:
        return 0.55
    if level_value == 5:
        return 0.80
    return 1.00

T_diag_sp = np.zeros(len(spare_idx), dtype=float)
for k, chain in enumerate(chains_sp):
    t = 0.0
    for node_idx in chain:
        lv = level_num_all[node_idx]
        t += node_diag_contrib(lv)
    T_diag_sp[k] = t

T_reminst_sp = 0.35 * np.maximum(cm_time_sp, 1.0)

# [MODIFIED] PM이 복원시간/정비시간 단축에 더 강하게 반영
T_repair_base_sp = 0.65 * cm_time_sp
T_repair_sp = T_repair_base_sp * (1.0 - delta_sp)

for i, e in enumerate(echelon_sp):
    if e == "O":
        T_reminst_sp[i] *= 0.85
        T_repair_sp[i] *= 0.75
    elif e == "I":
        T_reminst_sp[i] *= 1.00
        T_repair_sp[i] *= 1.00
    elif e == "D":
        T_reminst_sp[i] *= 1.15
        T_repair_sp[i] *= 1.25

T_restore_intrinsic_sp = T_reminst_sp + (1.0 - condemn_sp) * T_repair_sp

T_issue_O_sp = np.full(len(spare_idx), 0.3, dtype=float)
T_issue_I_sp = np.maximum(0.8, np.minimum(4.0, 0.25 * np.maximum(transport_sp, 1.0)))
T_issue_D_sp = np.maximum(1.5, np.minimum(8.0, 0.45 * np.maximum(transport_sp, 1.0)))

baseline_wait_sp = np.zeros(len(spare_idx), dtype=float)
for i, e in enumerate(echelon_sp):
    frac = BASELINE_WAIT_FRACTION_BY_ECHELON.get(e, 0.35)
    floor = MIN_WAIT_FLOOR_H_BY_ECHELON.get(e, 2.0)
    baseline_wait_sp[i] = max(floor, frac * lead_sp[i])

print(
    f"[TIME SUMMARY] "
    f"diag mean={T_diag_sp.mean():.2f}h | "
    f"baseline wait mean={baseline_wait_sp.mean():.2f}h | "
    f"restore mean={T_restore_intrinsic_sp.mean():.2f}h"
)


# ============================================================
# 8) Candidate screening
# ============================================================
p_need_sp = 1.0 - np.exp(-lam_2y_sp)

thr_lead = float(np.nanpercentile(lead_sp, LONG_LEAD_PERCENTILE))
is_long_sp = (lead_sp >= thr_lead)

impact_sp = lambda_eff_sp * np.maximum(T_diag_sp + baseline_wait_sp + T_restore_intrinsic_sp, 1e-9) / HOURS_PER_YEAR
thr_impact = float(np.nanpercentile(impact_sp, AO_IMPACT_PERCENTILE))
is_high_impact_sp = (impact_sp >= thr_impact)

candidate_mask = (p_need_sp >= PMIN) | is_high_impact_sp | is_long_sp
candidate_idx_local = np.where(candidate_mask)[0]

print("[CANDIDATE SCREENING]")
print(f"  PMIN = {PMIN:.2f}")
print(f"  long-lead threshold p{LONG_LEAD_PERCENTILE} = {thr_lead:.2f}h")
print(f"  impact threshold p{AO_IMPACT_PERCENTILE} = {thr_impact:.6f}")
print(f"  candidate spare-demand parts = {len(candidate_idx_local)} / {len(spare_idx)}")

if len(candidate_idx_local) == 0:
    raise ValueError("No candidate spare-demand parts after screening.")

part_id_c = part_id_sp[candidate_idx_local]
parent_id_c = parent_id_sp[candidate_idx_local]
level_c = level_sp[candidate_idx_local]
depth_c = depth_sp[candidate_idx_local]
echelon_c = echelon_sp[candidate_idx_local]

annual_fr_c = annual_fr_sp[candidate_idx_local]
lambda_eff_c = lambda_eff_sp[candidate_idx_local]
lam_2y_c = lam_2y_sp[candidate_idx_local]
proc_cost_c = proc_cost_sp[candidate_idx_local]
lead_c = lead_sp[candidate_idx_local]
cm_cost_c = cm_cost_sp[candidate_idx_local]

T_diag_c = T_diag_sp[candidate_idx_local]
T_reminst_c = T_reminst_sp[candidate_idx_local]
T_repair_c = T_repair_sp[candidate_idx_local]
T_restore_intrinsic_c = T_restore_intrinsic_sp[candidate_idx_local]
T_issue_O_c = T_issue_O_sp[candidate_idx_local]
T_issue_I_c = T_issue_I_sp[candidate_idx_local]
T_issue_D_c = T_issue_D_sp[candidate_idx_local]
baseline_wait_c = baseline_wait_sp[candidate_idx_local]

p_need_c = p_need_sp[candidate_idx_local]
impact_c = impact_sp[candidate_idx_local]
is_long_c = is_long_sp[candidate_idx_local]

m_cand = len(candidate_idx_local)
long_idx_c = np.where(is_long_c)[0]

if len(long_idx_c) > 0:
    long_core_thr = float(np.nanpercentile(impact_c[long_idx_c], LONG_CORE_IMPACT_PERCENTILE))
else:
    long_core_thr = 0.0

prebuy_flag_c = np.zeros(m_cand, dtype=bool)
protection_flag_c = np.zeros(m_cand, dtype=bool)
for j in range(m_cand):
    if is_long_c[j] and ((p_need_c[j] >= PMIN) or (impact_c[j] >= thr_impact)):
        prebuy_flag_c[j] = True
    if is_long_c[j] and (impact_c[j] >= long_core_thr):
        protection_flag_c[j] = True

impact_norm_c = minmax(impact_c)
critical_weight_c = np.where(
    impact_norm_c >= 0.80, 1.00,
    np.where(impact_norm_c >= 0.50, 0.45, 0.15)
)

mu_pipe_nom_c = lambda_eff_c * (baseline_wait_c + T_restore_intrinsic_c) / HOURS_PER_YEAR

stock_cap_c = np.zeros(m_cand, dtype=int)
for i in range(m_cand):
    if is_long_c[i]:
        stock_cap_c[i] = long_dynamic_cap_from_lambda(lam_2y_c[i])
    else:
        stock_cap_c[i] = max(
            1,
            int(np.ceil(mu_pipe_nom_c[i] + 4.0 * np.sqrt(max(mu_pipe_nom_c[i], 1e-9)) + 2.0))
        )

prot_floor_c = np.where(protection_flag_c, 1, 0).astype(int)
BASE_MAINT_SPEND = float(np.sum(annual_fr_c * cm_cost_c * YEARS))

print(f"[BASE_MAINT_SPEND] {BASE_MAINT_SPEND:,.0f} KRW")


# ============================================================
# 9) Evaluate one solution
# ============================================================
def evaluate_one_solution(y_manage, sO, sI, sD):
    y_manage = np.asarray(y_manage, dtype=int)
    sO = np.asarray(sO, dtype=int)
    sI = np.asarray(sI, dtype=int)
    sD = np.asarray(sD, dtype=int)

    sO = y_manage * sO
    sI = y_manage * sI
    sD = y_manage * sD

    for i in range(m_cand):
        if y_manage[i] > 0 and prot_floor_c[i] > 0:
            if sO[i] + sI[i] + sD[i] < 1:
                if echelon_c[i] == "O":
                    sO[i] = 1
                elif echelon_c[i] == "I":
                    sI[i] = 1
                else:
                    sD[i] = 1

    total_stock = sO + sI + sD
    for i in range(m_cand):
        if total_stock[i] > stock_cap_c[i]:
            excess = total_stock[i] - stock_cap_c[i]
            reduc = min(sD[i], excess)
            sD[i] -= reduc
            excess -= reduc
            if excess > 0:
                reduc = min(sI[i], excess)
                sI[i] -= reduc
                excess -= reduc
            if excess > 0:
                reduc = min(sO[i], excess)
                sO[i] -= reduc
                excess -= reduc
        total_stock[i] = sO[i] + sI[i] + sD[i]

    p_short_O = np.zeros(m_cand, dtype=float)
    p_short_I = np.zeros(m_cand, dtype=float)
    p_short_D = np.zeros(m_cand, dtype=float)

    for i in range(m_cand):
        if y_manage[i] == 0:
            p_short_O[i] = 1.0
            p_short_I[i] = 1.0
            p_short_D[i] = 1.0
            continue

        muO = lambda_eff_c[i] * T_issue_O_c[i] / HOURS_PER_YEAR
        muI = lambda_eff_c[i] * T_issue_I_c[i] / HOURS_PER_YEAR
        muD = lambda_eff_c[i] * T_issue_D_c[i] / HOURS_PER_YEAR

        p_short_O[i] = poisson_tail_prob(muO, sO[i])
        p_short_I[i] = poisson_tail_prob(muI, sI[i])
        p_short_D[i] = poisson_tail_prob(muD, sD[i])

    improved_wait = (
        (1.0 - p_short_O) * T_issue_O_c
        + p_short_O * (1.0 - p_short_I) * T_issue_I_c
        + p_short_O * p_short_I * (1.0 - p_short_D) * T_issue_D_c
        + p_short_O * p_short_I * p_short_D * baseline_wait_c
    )

    T_wait_per_failure = np.where(
        y_manage > 0,
        np.minimum(baseline_wait_c, improved_wait),
        baseline_wait_c
    )

    DT_diag = np.sum(lambda_eff_c * T_diag_c * critical_weight_c)
    DT_restore = np.sum(lambda_eff_c * T_restore_intrinsic_c * critical_weight_c)
    DT_wait = np.sum(lambda_eff_c * T_wait_per_failure * critical_weight_c)
    DT_total = DT_diag + DT_wait + DT_restore

    Ao = float(T_OBS_HOURS / (T_OBS_HOURS + DT_total))

    stock_cost = float(np.sum(total_stock * proc_cost_c))
    hold_cost = float(h_pre * np.sum(total_stock * proc_cost_c))
    total_cost = stock_cost + hold_cost + BASE_MAINT_SPEND

    managed_items = int(np.sum((y_manage > 0) & (total_stock > 0)))
    total_stock_units = int(np.sum(total_stock))
    prebuy_selected = int(np.sum((y_manage > 0) & prebuy_flag_c))
    protection_selected = int(np.sum((total_stock > 0) & protection_flag_c))

    return {
        "Ao": Ao,
        "DT_diag_h": float(DT_diag),
        "DT_wait_h": float(DT_wait),
        "DT_restore_h": float(DT_restore),
        "DT_total_h": float(DT_total),
        "T_wait_per_failure": T_wait_per_failure,
        "total_cost": total_cost,
        "stock_cost": stock_cost,
        "hold_cost": hold_cost,
        "sO": sO,
        "sI": sI,
        "sD": sD,
        "total_stock": total_stock,
        "managed_items": managed_items,
        "total_stock_units": total_stock_units,
        "prebuy_selected": prebuy_selected,
        "protection_selected": protection_selected,
    }


# ============================================================
# 10) NSGA evaluation + utilities
# ============================================================
def eval_nsga(pop_mat, ao_target):
    pop = pop_mat.shape[0]

    Y = np.clip(np.rint(pop_mat[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop_mat[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop_mat[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop_mat[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    F = np.zeros((pop, 3), dtype=float)
    Ao = np.zeros(pop, dtype=float)

    for p in range(pop):
        sim = evaluate_one_solution(Y[p], SO[p], SI[p], SD[p])

        Ao[p] = sim["Ao"]
        ao_shortfall = max(0.0, ao_target - sim["Ao"])

        F1 = sim["total_cost"] + AO_COST_PENALTY * (ao_shortfall ** 2)
        F2 = ao_shortfall
        F3 = ITEM_COUNT_WEIGHT * sim["managed_items"] + STOCK_UNIT_WEIGHT * sim["total_stock_units"]

        F[p, 0] = F1
        F[p, 1] = F2
        F[p, 2] = F3

    return F, Ao

def dominates(a, b):
    return np.all(a <= b) and np.any(a < b)

def fast_non_dominated_sort(F):
    n = F.shape[0]
    S = [[] for _ in range(n)]
    n_dom = np.zeros(n, dtype=int)
    fronts = [[]]

    for p in range(n):
        for q in range(n):
            if p == q:
                continue
            if dominates(F[p], F[q]):
                S[p].append(q)
            elif dominates(F[q], F[p]):
                n_dom[p] += 1
        if n_dom[p] == 0:
            fronts[0].append(p)

    i = 0
    while fronts[i]:
        nxt = []
        for p in fronts[i]:
            for q in S[p]:
                n_dom[q] -= 1
                if n_dom[q] == 0:
                    nxt.append(q)
        i += 1
        fronts.append(nxt)

    fronts.pop()
    return fronts

def crowding_distance(F, front):
    mobj = F.shape[1]
    dist = np.zeros(len(front), dtype=float)
    if len(front) == 0:
        return dist

    idx = np.array(front, dtype=int)
    for j in range(mobj):
        vals = F[idx, j]
        order = np.argsort(vals)
        dist[order[0]] = np.inf
        dist[order[-1]] = np.inf

        vmin, vmax = vals[order[0]], vals[order[-1]]
        if vmax - vmin < 1e-12:
            continue

        for k in range(1, len(front) - 1):
            dist[order[k]] += (vals[order[k+1]] - vals[order[k-1]]) / (vmax - vmin)
    return dist

def rank_and_crowd(F):
    fronts = fast_non_dominated_sort(F)
    rank = np.empty(F.shape[0], dtype=int)
    crowd = np.zeros(F.shape[0], dtype=float)

    for rnk, front in enumerate(fronts):
        for i in front:
            rank[i] = rnk
        cd = crowding_distance(F, front)
        for t, i in enumerate(front):
            crowd[i] = cd[t]
    return rank, crowd, fronts

def tournament_select(rank, crowd, rng):
    i, j = rng.integers(0, len(rank), size=2)
    if rank[i] < rank[j]:
        return i
    if rank[j] < rank[i]:
        return j
    return i if crowd[i] > crowd[j] else j

def uniform_crossover(p1, p2, rng):
    mask = rng.random(p1.shape[0]) < 0.5
    c1, c2 = p1.copy(), p2.copy()
    c1[mask] = p2[mask]
    c2[mask] = p1[mask]
    return c1, c2


# ============================================================
# 11) Run NSGA-II (single target)
# ============================================================
def run_nsga_single_target(ao_target, seed=42):
    rng = np.random.default_rng(seed)

    n_vars = m_cand + 3 * m_cand
    mut_p = float(np.clip(20.0 / max(n_vars, 1), 0.01, 0.06))

    pop = np.zeros((POP, n_vars), dtype=float)

    seed_prob = np.clip(
        0.12 + 0.55 * (
            0.45 * minmax(p_need_c) +
            0.35 * minmax(impact_c) +
            0.20 * is_long_c.astype(float)
        ),
        0.08, 0.85
    )

    for k in range(POP):
        for j in range(m_cand):
            pop[k, j] = 1 if rng.random() < seed_prob[j] else 0

        for j in range(m_cand):
            yj = int(pop[k, j])
            ub = stock_cap_c[j]
            if yj == 0:
                pop[k, m_cand + j] = 0
                pop[k, m_cand + m_cand + j] = 0
                pop[k, m_cand + 2*m_cand + j] = 0
            else:
                sO0, sI0, sD0 = 0, 0, 0
                if echelon_c[j] == "O":
                    sO0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                elif echelon_c[j] == "I":
                    sI0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                else:
                    sD0 = rng.integers(prot_floor_c[j], min(ub, 1) + 1)
                pop[k, m_cand + j] = sO0
                pop[k, m_cand + m_cand + j] = sI0
                pop[k, m_cand + 2*m_cand + j] = sD0

    def repair_solution(v):
        y = np.clip(np.rint(v[:m_cand]), 0, 1).astype(int)
        sO = np.clip(np.rint(v[m_cand:m_cand+m_cand]), 0, None).astype(int)
        sI = np.clip(np.rint(v[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
        sD = np.clip(np.rint(v[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

        for j in range(m_cand):
            if y[j] == 0:
                sO[j] = 0
                sI[j] = 0
                sD[j] = 0
            total = sO[j] + sI[j] + sD[j]
            cap = stock_cap_c[j]
            if total > cap:
                excess = total - cap
                reduc = min(sD[j], excess)
                sD[j] -= reduc
                excess -= reduc
                if excess > 0:
                    reduc = min(sI[j], excess)
                    sI[j] -= reduc
                    excess -= reduc
                if excess > 0:
                    reduc = min(sO[j], excess)
                    sO[j] -= reduc
                    excess -= reduc

        return np.concatenate([y, sO, sI, sD]).astype(float)

    def mutate(child):
        y = child.copy()

        msk_y = rng.random(m_cand) < mut_p
        for j in range(m_cand):
            if msk_y[j]:
                y[j] = 1.0 - round(y[j])

        for block in range(3):
            start = m_cand + block * m_cand
            msk_s = rng.random(m_cand) < mut_p
            for j in range(m_cand):
                idx = start + j
                if msk_s[j]:
                    ub = stock_cap_c[j]
                    y[idx] = rng.integers(0, ub + 1)

        y = repair_solution(y)
        return y

    for gen in range(GEN):
        F, Ao = eval_nsga(pop, ao_target)
        rank, crowd, fronts = rank_and_crowd(F)

        off = []
        while len(off) < POP:
            p1 = tournament_select(rank, crowd, rng)
            p2 = tournament_select(rank, crowd, rng)
            c1, c2 = uniform_crossover(pop[p1], pop[p2], rng)
            c1 = mutate(c1)
            c2 = mutate(c2)
            off.append(c1)
            if len(off) < POP:
                off.append(c2)
        off = np.array(off, dtype=float)

        comb = np.vstack([pop, off])
        F_c, Ao_c = eval_nsga(comb, ao_target)
        rank_c, crowd_c, fronts_c = rank_and_crowd(F_c)

        new_idx = []
        for front in fronts_c:
            if len(new_idx) + len(front) <= POP:
                new_idx.extend(front)
            else:
                front = np.array(front, dtype=int)
                order = np.argsort(-crowd_c[front])
                need = POP - len(new_idx)
                new_idx.extend(front[order[:need]].tolist())
                break

        pop = comb[np.array(new_idx, dtype=int)]

        if (gen + 1) % 10 == 0:
            Fp, Aop = eval_nsga(pop, ao_target)
            managed_counts = []
            for row in pop:
                ytmp = np.clip(np.rint(row[:m_cand]), 0, 1).astype(int)
                managed_counts.append(int(np.sum(ytmp)))
            print(
                f"[NSGA | target={ao_target:.2f}] Gen {gen+1}/{GEN} | "
                f"best Ao={float(np.max(Aop)):.4f} | "
                f"share(Ao>={ao_target:.2f})={float(np.mean(Aop >= ao_target)):.2f} | "
                f"mean managed={float(np.mean(managed_counts)):.1f}"
            )

    F, Ao = eval_nsga(pop, ao_target)
    cost = F[:, 0]

    F2d = np.column_stack([cost, -Ao])
    fronts2d = fast_non_dominated_sort(F2d)
    pareto_idx = np.array(fronts2d[0], dtype=int)
    dominated_idx = np.setdiff1d(np.arange(len(cost)), pareto_idx)

    order = np.argsort(cost[pareto_idx])
    p_idx = pareto_idx[order]

    best_idx = int(np.argmax(Ao))
    x = pop[best_idx]

    Y = np.clip(np.rint(x[:m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(x[m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(x[m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(x[m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    best_sim = evaluate_one_solution(Y, SO, SI, SD)

    return {
        "target_ao": ao_target,
        "pop": pop,
        "F": F,
        "Ao": Ao,
        "cost": cost,
        "pareto_idx": pareto_idx,
        "dominated_idx": dominated_idx,
        "p_cost": cost[p_idx],
        "p_Ao": Ao[p_idx],
        "best_Ao": float(np.max(Ao)),
        "share_ge_target": float(np.mean(Ao >= ao_target)),
        "best_sim": best_sim,
        "best_y": Y,
        "best_sO": SO,
        "best_sI": SI,
        "best_sD": SD,
    }


# ============================================================
# 12) Sweep targets
# ============================================================
def collect_run_dataframe(res_single):
    rows = []

    pop = res_single["pop"]
    target_ao = res_single["target_ao"]

    Y = np.clip(np.rint(pop[:, :m_cand]), 0, 1).astype(int)
    SO = np.clip(np.rint(pop[:, m_cand:m_cand+m_cand]), 0, None).astype(int)
    SI = np.clip(np.rint(pop[:, m_cand+m_cand:m_cand+2*m_cand]), 0, None).astype(int)
    SD = np.clip(np.rint(pop[:, m_cand+2*m_cand:m_cand+3*m_cand]), 0, None).astype(int)

    pareto_set = set(res_single["pareto_idx"].tolist())

    for i in range(pop.shape[0]):
        sim = evaluate_one_solution(Y[i], SO[i], SI[i], SD[i])
        rows.append({
            "target_ao": float(target_ao),
            "solution_id_within_target": int(i),
            "Ao": float(sim["Ao"]),
            "total_cost": float(sim["total_cost"]),
            "stock_cost": float(sim["stock_cost"]),
            "hold_cost": float(sim["hold_cost"]),
            "DT_diag_h": float(sim["DT_diag_h"]),
            "DT_wait_h": float(sim["DT_wait_h"]),
            "DT_restore_h": float(sim["DT_restore_h"]),
            "DT_total_h": float(sim["DT_total_h"]),
            "managed_items": int(sim["managed_items"]),
            "total_stock_units": int(sim["total_stock_units"]),
            "is_pareto_2d": int(i in pareto_set),
            "signature": solution_signature(Y[i], sim["sO"], sim["sI"], sim["sD"]),
        })
    return pd.DataFrame(rows)

def run_target_sweep(target_grid, base_seed=42):
    all_result_map = {}
    all_df = []

    for idx, target in enumerate(target_grid):
        print("\n" + "=" * 70)
        print(f"[TARGET SWEEP] RUN START | target_ao = {target:.2f}")
        print("=" * 70)

        run_seed = int(base_seed + idx * 17)

        res_t = run_nsga_single_target(ao_target=target, seed=run_seed)
        all_result_map[round(target, 6)] = res_t

        df_t = collect_run_dataframe(res_t)
        all_df.append(df_t)

        print(f"[TARGET SUMMARY] target={target:.2f} | best Ao={res_t['best_Ao']:.4f} | share_ge_target={res_t['share_ge_target']:.2f}")

    if len(all_df) == 0:
        return all_result_map, pd.DataFrame()

    df_all = pd.concat(all_df, ignore_index=True)
    return all_result_map, df_all


# ============================================================
# 13) Deduplicate integrated solutions
# ============================================================
def deduplicate_integrated_df(df_all):
    if df_all.empty:
        return df_all.copy()

    df_unique = (
        df_all.sort_values(
            by=["Ao", "total_cost", "target_ao"],
            ascending=[False, True, True]
        )
        .drop_duplicates(subset=["signature"])
        .reset_index(drop=True)
    )
    return df_unique


# ============================================================
# 14) Visualizations
# ============================================================
def plot_representative_pareto(res_single):
    plt.figure(figsize=(9, 6))

    plt.scatter(
        res_single["cost"][res_single["dominated_idx"]],
        res_single["Ao"][res_single["dominated_idx"]],
        s=18,
        alpha=0.35,
        color="gray",
        label="Dominated solutions"
    )

    plt.scatter(
        res_single["p_cost"],
        res_single["p_Ao"],
        s=34,
        alpha=0.95,
        color="#1E88E5",
        label="Pareto solutions"
    )
    plt.plot(
        res_single["p_cost"],
        res_single["p_Ao"],
        linewidth=2.2,
        color="#1E88E5",
        label="Pareto front"
    )

    for ao_line in AO_LINES:
        color = "#2E7D32" if ao_line < res_single["target_ao"] else "#6A1B9A"
        style = "--" if ao_line < res_single["target_ao"] else "-."
        plt.axhline(
            ao_line,
            linestyle=style,
            linewidth=1.1,
            color=color,
            alpha=0.85
        )
        plt.text(
            x=np.nanmin(res_single["cost"]) * 1.001,
            y=ao_line + 0.0008,
            s=f"Ao={ao_line:.2f}",
            fontsize=8,
            color=color
        )

    plt.xlabel("Total Cost (KRW)")
    plt.ylabel("Ao")
    plt.title(f"Representative Pareto-front (target={res_single['target_ao']:.2f})")
    plt.legend(loc="best")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"],
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_integrated_tradeoff_map_percent(df_unique):
    if df_unique.empty:
        print("No integrated solutions to plot.")
        return

    plt.figure(figsize=(10, 6))
    sc = plt.scatter(
        df_unique["Ao"] * 100.0,
        df_unique["total_cost"],
        c=df_unique["target_ao"],
        s=28,
        alpha=0.75
    )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line * 100.0,
            linestyle="--",
            linewidth=1.0,
            alpha=0.6
        )

    plt.xlabel("Ao (%)")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Integrated Target-Sweep Trade-off Map (%)")
    plt.grid(True, alpha=0.25)
    plt.colorbar(sc, label="Target Ao")
    plt.tight_layout()
    plt.show()

def plot_targetwise_pareto_overlay(result_map):
    plt.figure(figsize=(10, 6))

    cmap = plt.cm.viridis
    targets_sorted = sorted(result_map.keys())

    for idx, t in enumerate(targets_sorted):
        res_t = result_map[t]
        color = cmap(idx / max(len(targets_sorted) - 1, 1))

        plt.scatter(
            res_t["p_Ao"],
            res_t["p_cost"],
            s=18,
            alpha=0.75,
            color=color,
            label=f"target={t:.2f}"
        )
        plt.plot(
            res_t["p_Ao"],
            res_t["p_cost"],
            linewidth=1.1,
            alpha=0.75,
            color=color
        )

    for ao_line in AO_LINES:
        plt.axvline(
            ao_line,
            linestyle="--",
            linewidth=0.9,
            alpha=0.5
        )

    plt.xlabel("Ao")
    plt.ylabel("Total Cost (KRW)")
    plt.title("Overlay of Pareto fronts by target")
    plt.grid(True, alpha=0.25)
    plt.legend(loc="best", fontsize=8)
    plt.tight_layout()
    plt.show()


# ============================================================
# 15) Run sweep
# ============================================================
result_map, df_all_runs = run_target_sweep(AO_TARGET_GRID, base_seed=SEED)

df_integrated = deduplicate_integrated_df(df_all_runs)

print("\n" + "=" * 70)
print("[INTEGRATED SUMMARY]")
print(f"All collected solutions        = {len(df_all_runs)}")
print(f"Unique integrated solutions    = {len(df_integrated)}")
print("=" * 70)

summary_by_target_basic = (
    df_all_runs.groupby("target_ao")
    .agg(
        n_solutions=("Ao", "count"),
        ao_min=("Ao", "min"),
        ao_max=("Ao", "max"),
        cost_min=("total_cost", "min"),
        cost_max=("total_cost", "max"),
        wait_min=("DT_wait_h", "min"),
        wait_max=("DT_wait_h", "max"),
        managed_min=("managed_items", "min"),
        managed_max=("managed_items", "max"),
    )
    .reset_index()
)

share_df = (
    df_all_runs.groupby("target_ao")
    .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
    .reset_index(name="share_ge_target")
)

summary_by_target = (
    summary_by_target_basic
    .merge(share_df, on="target_ao", how="left")
    .sort_values("target_ao")
    .reset_index(drop=True)
)

print("\n[TARGET-WISE SUMMARY]")
print(summary_by_target.to_string(index=False))

rep_key = round(REPRESENTATIVE_TARGET, 6)
if rep_key not in result_map:
    raise ValueError(f"Representative target {REPRESENTATIVE_TARGET:.2f} is not in AO_TARGET_GRID.")

res = result_map[rep_key]


# ============================================================
# 16) Final representative summary
# ============================================================
print("\n==============================")
print("[FINAL SUMMARY | REPRESENTATIVE TARGET]")
print(f"Representative Target = {res['target_ao']:.2f}")
print(f"Best Ao = {res['best_Ao']:.4f}")
print(f"Share(Ao >= {res['target_ao']:.2f}) = {res['share_ge_target']:.2f}")
print(f"Candidate spare-demand parts = {m_cand}")
print("==============================")

b = res["best_sim"]
print("\n[BEST POLICY | REPRESENTATIVE TARGET]")
print(f"Ao                  = {b['Ao']:.4f}")
print(f"DT_diag_h           = {b['DT_diag_h']:.2f}")
print(f"DT_wait_h           = {b['DT_wait_h']:.2f}")
print(f"DT_restore_h        = {b['DT_restore_h']:.2f}")
print(f"DT_total_h          = {b['DT_total_h']:.2f}")
print(f"stock_cost          = {b['stock_cost']:.0f}")
print(f"hold_cost           = {b['hold_cost']:.0f}")
print(f"total_cost          = {b['total_cost']:.0f}")
print(f"managed parts       = {b['managed_items']}")
print(f"total stock units   = {b['total_stock_units']}")
print(f"selected pre-buy    = {b['prebuy_selected']}")
print(f"selected protection = {b['protection_selected']}")


# ============================================================
# 17) Plots
# ============================================================
plot_representative_pareto(res)
plot_integrated_tradeoff_map(df_integrated)
plot_integrated_tradeoff_map_percent(df_integrated)
plot_targetwise_pareto_overlay(result_map)


# ============================================================
# 18) Diagnostics table for representative target
# ============================================================
diag_df = pd.DataFrame({
    "Part_ID": part_id_c,
    "Parent_ID": parent_id_c,
    "Level": level_c,
    "Depth": depth_c,
    "Maint_Echelon": echelon_c,

    # ========================================================
    # [ADDED] Aging diagnostics
    # ========================================================
    "rad_deg_index": rad_idx_all[spare_idx][candidate_idx_local],
    "annual_rad_hours": annual_rad_hours_all[spare_idx][candidate_idx_local],
    "env_resistance": env_res_all[spare_idx][candidate_idx_local],
    "aging_index": aging_index_all[spare_idx][candidate_idx_local],
    "aging_multiplier": aging_multiplier_all[spare_idx][candidate_idx_local],

    "annual_FR": annual_fr_c,
    "lambda_eff_2y": lam_2y_c,
    "p_need_2y": p_need_c,
    "baseline_wait_h": baseline_wait_c,
    "T_diag_h": T_diag_c,
    "T_repair_h": T_repair_c,
    "T_restore_h": T_restore_intrinsic_c,
    "ao_impact": impact_c,
    "is_long_lead": is_long_c.astype(int),
    "prebuy_flag": prebuy_flag_c.astype(int),
    "protection_flag": protection_flag_c.astype(int),
    "selected_manage": res["best_y"].astype(int),
    "sO_best": res["best_sim"]["sO"].astype(int),
    "sI_best": res["best_sim"]["sI"].astype(int),
    "sD_best": res["best_sim"]["sD"].astype(int),
    "total_stock_best": res["best_sim"]["total_stock"].astype(int),
    "wait_per_failure_best": res["best_sim"]["T_wait_per_failure"],
    "unit_proc_cost": proc_cost_c,
    "critical_weight": critical_weight_c
})

print("\n[TOP selected managed parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 1]
    .sort_values(["wait_per_failure_best", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP unmanaged but high baseline-wait parts | representative target]")
print(
    diag_df.loc[diag_df["selected_manage"] == 0]
    .sort_values(["baseline_wait_h", "ao_impact"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)

print("\n[TOP protection candidates | representative target]")
print(
    diag_df.loc[diag_df["protection_flag"] == 1]
    .sort_values(["ao_impact", "baseline_wait_h"], ascending=[False, False])
    .head(TOPK_PRINT)
    .to_string(index=False)
)
# Out:
# [LOAD] shape = (1000, 31)
# [PM EFFECT] failure reduction max=0.03 | restore reduction max=0.18
# [AGING EFFECT] hours_ref=2545.20h | AI mean=0.1877 | AI max=1.2093 | FR multiplier mean=1.1447 | FR multiplier max=2.0659
# [SPARE-DEMAND FILTER] count = 869 / 1000
# [TIME SUMMARY] diag mean=2.98h | baseline wait mean=2417.42h | restore mean=8.65h
# [CANDIDATE SCREENING]
#   PMIN = 0.15
#   long-lead threshold p90 = 7233.20h
#   impact threshold p70 = 0.005366
#   candidate spare-demand parts = 623 / 869
# [BASE_MAINT_SPEND] 36,090,997 KRW
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.10
# ======================================================================
# [NSGA | target=0.10] Gen 10/200 | best Ao=0.8169 | share(Ao>=0.10)=1.00 | mean managed=130.7
# [NSGA | target=0.10] Gen 20/200 | best Ao=0.8109 | share(Ao>=0.10)=1.00 | mean managed=130.0
# [NSGA | target=0.10] Gen 30/200 | best Ao=0.8138 | share(Ao>=0.10)=1.00 | mean managed=132.7
# [NSGA | target=0.10] Gen 40/200 | best Ao=0.8115 | share(Ao>=0.10)=1.00 | mean managed=133.1
# [NSGA | target=0.10] Gen 50/200 | best Ao=0.8109 | share(Ao>=0.10)=1.00 | mean managed=134.5
# [NSGA | target=0.10] Gen 60/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=136.4
# [NSGA | target=0.10] Gen 70/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=136.7
# [NSGA | target=0.10] Gen 80/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.5
# [NSGA | target=0.10] Gen 90/200 | best Ao=0.8131 | share(Ao>=0.10)=1.00 | mean managed=137.9
# [NSGA | target=0.10] Gen 100/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.4
# [NSGA | target=0.10] Gen 110/200 | best Ao=0.8150 | share(Ao>=0.10)=1.00 | mean managed=137.5
# [NSGA | target=0.10] Gen 120/200 | best Ao=0.8150 | share(Ao>=0.10)=1.00 | mean managed=138.3
# [NSGA | target=0.10] Gen 130/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.3
# [NSGA | target=0.10] Gen 140/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.1
# [NSGA | target=0.10] Gen 150/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.5
# [NSGA | target=0.10] Gen 160/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.4
# [NSGA | target=0.10] Gen 170/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.0
# [NSGA | target=0.10] Gen 180/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.7
# [NSGA | target=0.10] Gen 190/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.3
# [NSGA | target=0.10] Gen 200/200 | best Ao=0.8128 | share(Ao>=0.10)=1.00 | mean managed=137.2
# [TARGET SUMMARY] target=0.10 | best Ao=0.8128 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.20
# ======================================================================
# [NSGA | target=0.20] Gen 10/200 | best Ao=0.8158 | share(Ao>=0.20)=1.00 | mean managed=122.6
# [NSGA | target=0.20] Gen 20/200 | best Ao=0.8157 | share(Ao>=0.20)=1.00 | mean managed=121.2
# [NSGA | target=0.20] Gen 30/200 | best Ao=0.8127 | share(Ao>=0.20)=1.00 | mean managed=119.2
# [NSGA | target=0.20] Gen 40/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=121.2
# [NSGA | target=0.20] Gen 50/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.3
# [NSGA | target=0.20] Gen 60/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.6
# [NSGA | target=0.20] Gen 70/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=124.5
# [NSGA | target=0.20] Gen 80/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.7
# [NSGA | target=0.20] Gen 90/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.8
# [NSGA | target=0.20] Gen 100/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.0
# [NSGA | target=0.20] Gen 110/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.5
# [NSGA | target=0.20] Gen 120/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.4
# [NSGA | target=0.20] Gen 130/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=124.1
# [NSGA | target=0.20] Gen 140/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=124.1
# [NSGA | target=0.20] Gen 150/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.8
# [NSGA | target=0.20] Gen 160/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.7
# [NSGA | target=0.20] Gen 170/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=123.5
# [NSGA | target=0.20] Gen 180/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=124.6
# [NSGA | target=0.20] Gen 190/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=125.2
# [NSGA | target=0.20] Gen 200/200 | best Ao=0.8152 | share(Ao>=0.20)=1.00 | mean managed=124.5
# [TARGET SUMMARY] target=0.20 | best Ao=0.8152 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.30
# ======================================================================
# [NSGA | target=0.30] Gen 10/200 | best Ao=0.8188 | share(Ao>=0.30)=1.00 | mean managed=129.2
# [NSGA | target=0.30] Gen 20/200 | best Ao=0.8188 | share(Ao>=0.30)=1.00 | mean managed=133.4
# [NSGA | target=0.30] Gen 30/200 | best Ao=0.8190 | share(Ao>=0.30)=1.00 | mean managed=136.4
# [NSGA | target=0.30] Gen 40/200 | best Ao=0.8190 | share(Ao>=0.30)=1.00 | mean managed=137.9
# [NSGA | target=0.30] Gen 50/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=138.9
# [NSGA | target=0.30] Gen 60/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=138.7
# [NSGA | target=0.30] Gen 70/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=138.9
# [NSGA | target=0.30] Gen 80/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.4
# [NSGA | target=0.30] Gen 90/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=138.8
# [NSGA | target=0.30] Gen 100/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.0
# [NSGA | target=0.30] Gen 110/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.8
# [NSGA | target=0.30] Gen 120/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=140.0
# [NSGA | target=0.30] Gen 130/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.4
# [NSGA | target=0.30] Gen 140/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.8
# [NSGA | target=0.30] Gen 150/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.4
# [NSGA | target=0.30] Gen 160/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=139.4
# [NSGA | target=0.30] Gen 170/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=140.1
# [NSGA | target=0.30] Gen 180/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=140.1
# [NSGA | target=0.30] Gen 190/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=140.7
# [NSGA | target=0.30] Gen 200/200 | best Ao=0.8189 | share(Ao>=0.30)=1.00 | mean managed=140.6
# [TARGET SUMMARY] target=0.30 | best Ao=0.8189 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.40
# ======================================================================
# [NSGA | target=0.40] Gen 10/200 | best Ao=0.8178 | share(Ao>=0.40)=1.00 | mean managed=126.2
# [NSGA | target=0.40] Gen 20/200 | best Ao=0.8186 | share(Ao>=0.40)=1.00 | mean managed=128.6
# [NSGA | target=0.40] Gen 30/200 | best Ao=0.8179 | share(Ao>=0.40)=1.00 | mean managed=128.2
# [NSGA | target=0.40] Gen 40/200 | best Ao=0.8179 | share(Ao>=0.40)=1.00 | mean managed=129.1
# [NSGA | target=0.40] Gen 50/200 | best Ao=0.8179 | share(Ao>=0.40)=1.00 | mean managed=131.8
# [NSGA | target=0.40] Gen 60/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=131.6
# [NSGA | target=0.40] Gen 70/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=132.8
# [NSGA | target=0.40] Gen 80/200 | best Ao=0.8199 | share(Ao>=0.40)=1.00 | mean managed=133.3
# [NSGA | target=0.40] Gen 90/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=133.0
# [NSGA | target=0.40] Gen 100/200 | best Ao=0.8170 | share(Ao>=0.40)=1.00 | mean managed=132.8
# [NSGA | target=0.40] Gen 110/200 | best Ao=0.8170 | share(Ao>=0.40)=1.00 | mean managed=133.2
# [NSGA | target=0.40] Gen 120/200 | best Ao=0.8170 | share(Ao>=0.40)=1.00 | mean managed=133.5
# [NSGA | target=0.40] Gen 130/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=133.2
# [NSGA | target=0.40] Gen 140/200 | best Ao=0.8176 | share(Ao>=0.40)=1.00 | mean managed=133.6
# [NSGA | target=0.40] Gen 150/200 | best Ao=0.8176 | share(Ao>=0.40)=1.00 | mean managed=133.3
# [NSGA | target=0.40] Gen 160/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=132.6
# [NSGA | target=0.40] Gen 170/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=132.5
# [NSGA | target=0.40] Gen 180/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=132.7
# [NSGA | target=0.40] Gen 190/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=133.1
# [NSGA | target=0.40] Gen 200/200 | best Ao=0.8164 | share(Ao>=0.40)=1.00 | mean managed=132.5
# [TARGET SUMMARY] target=0.40 | best Ao=0.8164 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.50
# ======================================================================
# [NSGA | target=0.50] Gen 10/200 | best Ao=0.8197 | share(Ao>=0.50)=1.00 | mean managed=126.5
# [NSGA | target=0.50] Gen 20/200 | best Ao=0.8181 | share(Ao>=0.50)=1.00 | mean managed=130.8
# [NSGA | target=0.50] Gen 30/200 | best Ao=0.8183 | share(Ao>=0.50)=1.00 | mean managed=133.2
# [NSGA | target=0.50] Gen 40/200 | best Ao=0.8178 | share(Ao>=0.50)=1.00 | mean managed=132.7
# [NSGA | target=0.50] Gen 50/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=133.0
# [NSGA | target=0.50] Gen 60/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.5
# [NSGA | target=0.50] Gen 70/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=133.0
# [NSGA | target=0.50] Gen 80/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=133.3
# [NSGA | target=0.50] Gen 90/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.7
# [NSGA | target=0.50] Gen 100/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=133.2
# [NSGA | target=0.50] Gen 110/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.8
# [NSGA | target=0.50] Gen 120/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.7
# [NSGA | target=0.50] Gen 130/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.9
# [NSGA | target=0.50] Gen 140/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.3
# [NSGA | target=0.50] Gen 150/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.2
# [NSGA | target=0.50] Gen 160/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.8
# [NSGA | target=0.50] Gen 170/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.4
# [NSGA | target=0.50] Gen 180/200 | best Ao=0.8167 | share(Ao>=0.50)=1.00 | mean managed=132.8
# [NSGA | target=0.50] Gen 190/200 | best Ao=0.8187 | share(Ao>=0.50)=1.00 | mean managed=132.9
# [NSGA | target=0.50] Gen 200/200 | best Ao=0.8187 | share(Ao>=0.50)=1.00 | mean managed=132.6
# [TARGET SUMMARY] target=0.50 | best Ao=0.8187 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.60
# ======================================================================
# [NSGA | target=0.60] Gen 10/200 | best Ao=0.8156 | share(Ao>=0.60)=1.00 | mean managed=123.1
# [NSGA | target=0.60] Gen 20/200 | best Ao=0.8103 | share(Ao>=0.60)=1.00 | mean managed=120.2
# [NSGA | target=0.60] Gen 30/200 | best Ao=0.8121 | share(Ao>=0.60)=1.00 | mean managed=120.0
# [NSGA | target=0.60] Gen 40/200 | best Ao=0.8080 | share(Ao>=0.60)=1.00 | mean managed=121.4
# [NSGA | target=0.60] Gen 50/200 | best Ao=0.8094 | share(Ao>=0.60)=1.00 | mean managed=120.2
# [NSGA | target=0.60] Gen 60/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.1
# [NSGA | target=0.60] Gen 70/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.6
# [NSGA | target=0.60] Gen 80/200 | best Ao=0.8132 | share(Ao>=0.60)=1.00 | mean managed=120.6
# [NSGA | target=0.60] Gen 90/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.1
# [NSGA | target=0.60] Gen 100/200 | best Ao=0.8092 | share(Ao>=0.60)=1.00 | mean managed=120.7
# [NSGA | target=0.60] Gen 110/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=119.6
# [NSGA | target=0.60] Gen 120/200 | best Ao=0.8101 | share(Ao>=0.60)=1.00 | mean managed=120.2
# [NSGA | target=0.60] Gen 130/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.4
# [NSGA | target=0.60] Gen 140/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.2
# [NSGA | target=0.60] Gen 150/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.4
# [NSGA | target=0.60] Gen 160/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.8
# [NSGA | target=0.60] Gen 170/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.7
# [NSGA | target=0.60] Gen 180/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=119.8
# [NSGA | target=0.60] Gen 190/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.7
# [NSGA | target=0.60] Gen 200/200 | best Ao=0.8088 | share(Ao>=0.60)=1.00 | mean managed=120.2
# [TARGET SUMMARY] target=0.60 | best Ao=0.8088 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.70
# ======================================================================
# [NSGA | target=0.70] Gen 10/200 | best Ao=0.8178 | share(Ao>=0.70)=1.00 | mean managed=128.8
# [NSGA | target=0.70] Gen 20/200 | best Ao=0.8190 | share(Ao>=0.70)=1.00 | mean managed=132.6
# [NSGA | target=0.70] Gen 30/200 | best Ao=0.8153 | share(Ao>=0.70)=1.00 | mean managed=134.2
# [NSGA | target=0.70] Gen 40/200 | best Ao=0.8191 | share(Ao>=0.70)=1.00 | mean managed=137.1
# [NSGA | target=0.70] Gen 50/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=139.2
# [NSGA | target=0.70] Gen 60/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.5
# [NSGA | target=0.70] Gen 70/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.6
# [NSGA | target=0.70] Gen 80/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.7
# [NSGA | target=0.70] Gen 90/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=141.0
# [NSGA | target=0.70] Gen 100/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.3
# [NSGA | target=0.70] Gen 110/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.2
# [NSGA | target=0.70] Gen 120/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.7
# [NSGA | target=0.70] Gen 130/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.9
# [NSGA | target=0.70] Gen 140/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.9
# [NSGA | target=0.70] Gen 150/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.6
# [NSGA | target=0.70] Gen 160/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.8
# [NSGA | target=0.70] Gen 170/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=141.1
# [NSGA | target=0.70] Gen 180/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.9
# [NSGA | target=0.70] Gen 190/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.8
# [NSGA | target=0.70] Gen 200/200 | best Ao=0.8184 | share(Ao>=0.70)=1.00 | mean managed=140.8
# [TARGET SUMMARY] target=0.70 | best Ao=0.8184 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.80
# ======================================================================
# [NSGA | target=0.80] Gen 10/200 | best Ao=0.8166 | share(Ao>=0.80)=0.70 | mean managed=132.4
# [NSGA | target=0.80] Gen 20/200 | best Ao=0.8185 | share(Ao>=0.80)=0.78 | mean managed=131.3
# [NSGA | target=0.80] Gen 30/200 | best Ao=0.8185 | share(Ao>=0.80)=0.75 | mean managed=135.3
# [NSGA | target=0.80] Gen 40/200 | best Ao=0.8205 | share(Ao>=0.80)=0.84 | mean managed=139.8
# [NSGA | target=0.80] Gen 50/200 | best Ao=0.8205 | share(Ao>=0.80)=0.80 | mean managed=140.9
# [NSGA | target=0.80] Gen 60/200 | best Ao=0.8169 | share(Ao>=0.80)=0.84 | mean managed=144.0
# [NSGA | target=0.80] Gen 70/200 | best Ao=0.8169 | share(Ao>=0.80)=0.96 | mean managed=143.4
# [NSGA | target=0.80] Gen 80/200 | best Ao=0.8209 | share(Ao>=0.80)=1.00 | mean managed=143.1
# [NSGA | target=0.80] Gen 90/200 | best Ao=0.8209 | share(Ao>=0.80)=1.00 | mean managed=143.6
# [NSGA | target=0.80] Gen 100/200 | best Ao=0.8169 | share(Ao>=0.80)=1.00 | mean managed=142.6
# [NSGA | target=0.80] Gen 110/200 | best Ao=0.8169 | share(Ao>=0.80)=1.00 | mean managed=143.2
# [NSGA | target=0.80] Gen 120/200 | best Ao=0.8172 | share(Ao>=0.80)=1.00 | mean managed=143.6
# [NSGA | target=0.80] Gen 130/200 | best Ao=0.8172 | share(Ao>=0.80)=1.00 | mean managed=142.9
# [NSGA | target=0.80] Gen 140/200 | best Ao=0.8188 | share(Ao>=0.80)=1.00 | mean managed=143.3
# [NSGA | target=0.80] Gen 150/200 | best Ao=0.8207 | share(Ao>=0.80)=1.00 | mean managed=143.6
# [NSGA | target=0.80] Gen 160/200 | best Ao=0.8178 | share(Ao>=0.80)=1.00 | mean managed=143.0
# [NSGA | target=0.80] Gen 170/200 | best Ao=0.8169 | share(Ao>=0.80)=1.00 | mean managed=142.7
# [NSGA | target=0.80] Gen 180/200 | best Ao=0.8179 | share(Ao>=0.80)=1.00 | mean managed=142.4
# [NSGA | target=0.80] Gen 190/200 | best Ao=0.8179 | share(Ao>=0.80)=1.00 | mean managed=142.5
# [NSGA | target=0.80] Gen 200/200 | best Ao=0.8169 | share(Ao>=0.80)=1.00 | mean managed=141.9
# [TARGET SUMMARY] target=0.80 | best Ao=0.8169 | share_ge_target=1.00
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.85
# ======================================================================
# [NSGA | target=0.85] Gen 10/200 | best Ao=0.8444 | share(Ao>=0.85)=0.00 | mean managed=167.2
# [NSGA | target=0.85] Gen 20/200 | best Ao=0.8581 | share(Ao>=0.85)=0.07 | mean managed=185.0
# [NSGA | target=0.85] Gen 30/200 | best Ao=0.8542 | share(Ao>=0.85)=0.10 | mean managed=191.1
# [NSGA | target=0.85] Gen 40/200 | best Ao=0.8581 | share(Ao>=0.85)=0.06 | mean managed=196.3
# [NSGA | target=0.85] Gen 50/200 | best Ao=0.8559 | share(Ao>=0.85)=0.12 | mean managed=201.7
# [NSGA | target=0.85] Gen 60/200 | best Ao=0.8528 | share(Ao>=0.85)=0.09 | mean managed=202.0
# [NSGA | target=0.85] Gen 70/200 | best Ao=0.8550 | share(Ao>=0.85)=0.12 | mean managed=205.5
# [NSGA | target=0.85] Gen 80/200 | best Ao=0.8581 | share(Ao>=0.85)=0.19 | mean managed=208.5
# [NSGA | target=0.85] Gen 90/200 | best Ao=0.8581 | share(Ao>=0.85)=0.20 | mean managed=210.2
# [NSGA | target=0.85] Gen 100/200 | best Ao=0.8581 | share(Ao>=0.85)=0.21 | mean managed=210.5
# [NSGA | target=0.85] Gen 110/200 | best Ao=0.8581 | share(Ao>=0.85)=0.19 | mean managed=210.9
# [NSGA | target=0.85] Gen 120/200 | best Ao=0.8581 | share(Ao>=0.85)=0.20 | mean managed=211.2
# [NSGA | target=0.85] Gen 130/200 | best Ao=0.8581 | share(Ao>=0.85)=0.20 | mean managed=212.3
# [NSGA | target=0.85] Gen 140/200 | best Ao=0.8581 | share(Ao>=0.85)=0.25 | mean managed=213.2
# [NSGA | target=0.85] Gen 150/200 | best Ao=0.8581 | share(Ao>=0.85)=0.26 | mean managed=213.2
# [NSGA | target=0.85] Gen 160/200 | best Ao=0.8555 | share(Ao>=0.85)=0.23 | mean managed=213.6
# [NSGA | target=0.85] Gen 170/200 | best Ao=0.8555 | share(Ao>=0.85)=0.23 | mean managed=212.6
# [NSGA | target=0.85] Gen 180/200 | best Ao=0.8555 | share(Ao>=0.85)=0.21 | mean managed=213.6
# [NSGA | target=0.85] Gen 190/200 | best Ao=0.8555 | share(Ao>=0.85)=0.21 | mean managed=214.0
# [NSGA | target=0.85] Gen 200/200 | best Ao=0.8555 | share(Ao>=0.85)=0.20 | mean managed=213.7
# [TARGET SUMMARY] target=0.85 | best Ao=0.8555 | share_ge_target=0.20
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.90
# ======================================================================
# [NSGA | target=0.90] Gen 10/200 | best Ao=0.8417 | share(Ao>=0.90)=0.00 | mean managed=164.0
# [NSGA | target=0.90] Gen 20/200 | best Ao=0.8612 | share(Ao>=0.90)=0.00 | mean managed=192.4
# [NSGA | target=0.90] Gen 30/200 | best Ao=0.8733 | share(Ao>=0.90)=0.00 | mean managed=224.6
# [NSGA | target=0.90] Gen 40/200 | best Ao=0.8896 | share(Ao>=0.90)=0.00 | mean managed=241.8
# [NSGA | target=0.90] Gen 50/200 | best Ao=0.8928 | share(Ao>=0.90)=0.00 | mean managed=247.7
# [NSGA | target=0.90] Gen 60/200 | best Ao=0.9002 | share(Ao>=0.90)=0.03 | mean managed=262.7
# [NSGA | target=0.90] Gen 70/200 | best Ao=0.9013 | share(Ao>=0.90)=0.06 | mean managed=269.1
# [NSGA | target=0.90] Gen 80/200 | best Ao=0.9030 | share(Ao>=0.90)=0.04 | mean managed=264.7
# [NSGA | target=0.90] Gen 90/200 | best Ao=0.9040 | share(Ao>=0.90)=0.05 | mean managed=276.2
# [NSGA | target=0.90] Gen 100/200 | best Ao=0.9056 | share(Ao>=0.90)=0.09 | mean managed=279.7
# [NSGA | target=0.90] Gen 110/200 | best Ao=0.9033 | share(Ao>=0.90)=0.07 | mean managed=280.6
# [NSGA | target=0.90] Gen 120/200 | best Ao=0.9050 | share(Ao>=0.90)=0.07 | mean managed=277.4
# [NSGA | target=0.90] Gen 130/200 | best Ao=0.9027 | share(Ao>=0.90)=0.06 | mean managed=284.5
# [NSGA | target=0.90] Gen 140/200 | best Ao=0.9054 | share(Ao>=0.90)=0.07 | mean managed=283.9
# [NSGA | target=0.90] Gen 150/200 | best Ao=0.9054 | share(Ao>=0.90)=0.07 | mean managed=293.2
# [NSGA | target=0.90] Gen 160/200 | best Ao=0.9036 | share(Ao>=0.90)=0.07 | mean managed=295.5
# [NSGA | target=0.90] Gen 170/200 | best Ao=0.9027 | share(Ao>=0.90)=0.07 | mean managed=294.6
# [NSGA | target=0.90] Gen 180/200 | best Ao=0.9027 | share(Ao>=0.90)=0.07 | mean managed=296.8
# [NSGA | target=0.90] Gen 190/200 | best Ao=0.9027 | share(Ao>=0.90)=0.06 | mean managed=298.5
# [NSGA | target=0.90] Gen 200/200 | best Ao=0.9019 | share(Ao>=0.90)=0.05 | mean managed=296.0
# [TARGET SUMMARY] target=0.90 | best Ao=0.9019 | share_ge_target=0.05
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.92
# ======================================================================
# [NSGA | target=0.92] Gen 10/200 | best Ao=0.8458 | share(Ao>=0.92)=0.00 | mean managed=174.5
# [NSGA | target=0.92] Gen 20/200 | best Ao=0.8680 | share(Ao>=0.92)=0.00 | mean managed=213.4
# [NSGA | target=0.92] Gen 30/200 | best Ao=0.8833 | share(Ao>=0.92)=0.00 | mean managed=235.7
# [NSGA | target=0.92] Gen 40/200 | best Ao=0.8916 | share(Ao>=0.92)=0.00 | mean managed=256.2
# [NSGA | target=0.92] Gen 50/200 | best Ao=0.9044 | share(Ao>=0.92)=0.00 | mean managed=277.8
# [NSGA | target=0.92] Gen 60/200 | best Ao=0.9085 | share(Ao>=0.92)=0.00 | mean managed=283.8
# [NSGA | target=0.92] Gen 70/200 | best Ao=0.9120 | share(Ao>=0.92)=0.00 | mean managed=297.9
# [NSGA | target=0.92] Gen 80/200 | best Ao=0.9173 | share(Ao>=0.92)=0.00 | mean managed=301.7
# [NSGA | target=0.92] Gen 90/200 | best Ao=0.9192 | share(Ao>=0.92)=0.00 | mean managed=307.1
# [NSGA | target=0.92] Gen 100/200 | best Ao=0.9227 | share(Ao>=0.92)=0.04 | mean managed=306.3
# [NSGA | target=0.92] Gen 110/200 | best Ao=0.9217 | share(Ao>=0.92)=0.05 | mean managed=305.2
# [NSGA | target=0.92] Gen 120/200 | best Ao=0.9231 | share(Ao>=0.92)=0.04 | mean managed=308.3
# [NSGA | target=0.92] Gen 130/200 | best Ao=0.9231 | share(Ao>=0.92)=0.03 | mean managed=313.6
# [NSGA | target=0.92] Gen 140/200 | best Ao=0.9231 | share(Ao>=0.92)=0.03 | mean managed=312.8
# [NSGA | target=0.92] Gen 150/200 | best Ao=0.9231 | share(Ao>=0.92)=0.03 | mean managed=314.8
# [NSGA | target=0.92] Gen 160/200 | best Ao=0.9205 | share(Ao>=0.92)=0.04 | mean managed=313.9
# [NSGA | target=0.92] Gen 170/200 | best Ao=0.9221 | share(Ao>=0.92)=0.06 | mean managed=314.6
# [NSGA | target=0.92] Gen 180/200 | best Ao=0.9217 | share(Ao>=0.92)=0.07 | mean managed=315.6
# [NSGA | target=0.92] Gen 190/200 | best Ao=0.9214 | share(Ao>=0.92)=0.04 | mean managed=316.6
# [NSGA | target=0.92] Gen 200/200 | best Ao=0.9222 | share(Ao>=0.92)=0.04 | mean managed=317.6
# [TARGET SUMMARY] target=0.92 | best Ao=0.9222 | share_ge_target=0.04
#
# ======================================================================
# [TARGET SWEEP] RUN START | target_ao = 0.94
# ======================================================================
# [NSGA | target=0.94] Gen 10/200 | best Ao=0.8429 | share(Ao>=0.94)=0.00 | mean managed=168.8
# [NSGA | target=0.94] Gen 20/200 | best Ao=0.8627 | share(Ao>=0.94)=0.00 | mean managed=204.4
# [NSGA | target=0.94] Gen 30/200 | best Ao=0.8787 | share(Ao>=0.94)=0.00 | mean managed=225.7
# [NSGA | target=0.94] Gen 40/200 | best Ao=0.8909 | share(Ao>=0.94)=0.00 | mean managed=244.7
# [NSGA | target=0.94] Gen 50/200 | best Ao=0.9001 | share(Ao>=0.94)=0.00 | mean managed=258.2
# [NSGA | target=0.94] Gen 60/200 | best Ao=0.9061 | share(Ao>=0.94)=0.00 | mean managed=267.1
# [NSGA | target=0.94] Gen 70/200 | best Ao=0.9108 | share(Ao>=0.94)=0.00 | mean managed=274.1
# [NSGA | target=0.94] Gen 80/200 | best Ao=0.9153 | share(Ao>=0.94)=0.00 | mean managed=291.5
# [NSGA | target=0.94] Gen 90/200 | best Ao=0.9186 | share(Ao>=0.94)=0.00 | mean managed=296.2
# [NSGA | target=0.94] Gen 100/200 | best Ao=0.9216 | share(Ao>=0.94)=0.00 | mean managed=298.2
# [NSGA | target=0.94] Gen 110/200 | best Ao=0.9223 | share(Ao>=0.94)=0.00 | mean managed=305.9
# [NSGA | target=0.94] Gen 120/200 | best Ao=0.9275 | share(Ao>=0.94)=0.00 | mean managed=316.0
# [NSGA | target=0.94] Gen 130/200 | best Ao=0.9285 | share(Ao>=0.94)=0.00 | mean managed=317.8
# [NSGA | target=0.94] Gen 140/200 | best Ao=0.9314 | share(Ao>=0.94)=0.00 | mean managed=320.1
# [NSGA | target=0.94] Gen 150/200 | best Ao=0.9314 | share(Ao>=0.94)=0.00 | mean managed=323.2
# [NSGA | target=0.94] Gen 160/200 | best Ao=0.9365 | share(Ao>=0.94)=0.00 | mean managed=339.4
# [NSGA | target=0.94] Gen 170/200 | best Ao=0.9399 | share(Ao>=0.94)=0.00 | mean managed=334.8
# [NSGA | target=0.94] Gen 180/200 | best Ao=0.9449 | share(Ao>=0.94)=0.03 | mean managed=343.8
# [NSGA | target=0.94] Gen 190/200 | best Ao=0.9420 | share(Ao>=0.94)=0.03 | mean managed=350.7
# [NSGA | target=0.94] Gen 200/200 | best Ao=0.9406 | share(Ao>=0.94)=0.03 | mean managed=349.0
# [TARGET SUMMARY] target=0.94 | best Ao=0.9406 | share_ge_target=0.03
#
# ======================================================================
# [INTEGRATED SUMMARY]
# All collected solutions        = 960
# Unique integrated solutions    = 960
# ======================================================================
#
# [TARGET-WISE SUMMARY]
#  target_ao  n_solutions   ao_min   ao_max     cost_min     cost_max    wait_min    wait_max  managed_min  managed_max  share_ge_target
#       0.10           80 0.735792 0.812829 3.609100e+07 3.609100e+07 4006.455593 6263.210540            0            0           1.0000
#       0.20           80 0.736930 0.815186 3.609100e+07 3.609100e+07 3944.134165 6226.434644            0            0           1.0000
#       0.30           80 0.736915 0.818855 3.609100e+07 3.609100e+07 3847.857258 6226.921057            0            0           1.0000
#       0.40           80 0.739479 0.816450 3.609100e+07 3.609100e+07 3910.874028 6144.490281            0            0           1.0000
#       0.50           80 0.740406 0.818685 3.609100e+07 3.609100e+07 3852.298192 6114.817607            0            0           1.0000
#       0.60           80 0.731093 0.808773 3.609100e+07 3.609100e+07 4114.567036 6416.248949            0            0           1.0000
#       0.70           80 0.740208 0.818440 3.609100e+07 3.609100e+07 3858.698399 6121.146248            0            0           1.0000
#       0.80           80 0.801733 0.816929 3.609100e+07 3.609100e+07 3898.300217 4304.792997            0            0           1.0000
#       0.85           80 0.836392 0.855516 3.609100e+07 3.679781e+07 2930.985549 3399.223345            0            2           0.2000
#       0.90           80 0.840256 0.901865 3.698469e+07 4.205445e+07 1878.528568 3302.906287            4           18           0.0500
#       0.92           80 0.858307 0.922155 3.705496e+07 4.668143e+07 1451.097355 2864.398438            4           33           0.0375
#       0.94           80 0.845635 0.940586 3.709493e+07 5.881898e+07 1078.808579 3170.286501            4           58           0.0250
#
# ==============================
# [FINAL SUMMARY | REPRESENTATIVE TARGET]
# Representative Target = 0.94
# Best Ao = 0.9406
# Share(Ao >= 0.94) = 0.03
# Candidate spare-demand parts = 623
# ==============================
#
# [BEST POLICY | REPRESENTATIVE TARGET]
# Ao                  = 0.9406
# DT_diag_h           = 7.42
# DT_wait_h           = 1078.81
# DT_restore_h        = 20.46
# DT_total_h          = 1106.69
# stock_cost          = 21075416
# hold_cost           = 1053771
# total_cost          = 58220183
# managed parts       = 58
# total stock units   = 91
# selected pre-buy    = 62
# selected protection = 23
# /tmp/ipykernel_12822/1896910991.py:1345: DeprecationWarning: DataFrameGroupBy.apply operated on the grouping columns. This behavior is deprecated, and in a future version of pandas the grouping columns will be excluded from the operation. Either pass `include_groups=False` to exclude the groupings or explicitly select the grouping columns after groupby to silence this warning.
#   .apply(lambda g: float(np.mean(g["Ao"] >= g.name)))
# [TOP selected managed parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  rad_deg_index  annual_rad_hours  env_resistance  aging_index  aging_multiplier  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0216 RAD-L5-0214      6      6             O          0.001               0.0             1.0     0.000000          1.000000   2.605620       5.211240   0.994545          4994.25      2.98    8.706019     6.194436   0.223237             0            0                0                1        0        0        0                 0               0.300050        228594.0             1.00
# RAD-L6-0766 RAD-L5-0764      6      6             O          0.149            2499.0             2.0     1.209282          2.065907   0.395422       0.790844   0.546538           923.25      2.98   13.035750    10.634721   0.006343             0            0                0                1        0        0        0                 0               0.300008        368373.0             0.15
# RAD-L6-0802 RAD-L5-0800      6      6             O          0.142            2055.0             2.0     1.099735          1.934485   0.368616       0.737232   0.521564           540.00      2.98   14.199656    11.523191   0.003500             0            0                0                1        0        0        0                 0               0.300007        180135.0             0.15
# RAD-L6-0656 RAD-L5-0654      6      6             O          0.129            2202.0             2.0     1.014075          1.837572   0.364576       0.729151   0.517682          3919.50      2.98   16.015350    13.813431   0.024573             0            0                0                1        0        0        0                 0               0.300007        299799.0             0.15
# RAD-L6-0696 RAD-L5-0691      6      6             O          0.132            1892.0             2.0     1.003883          1.826369   0.356806       0.713613   0.510129          5382.75      2.98    8.380125     5.963397   0.032942             0            0                0                1        0        0        0                 0               0.300007        256847.0             0.15
# RAD-L6-0634 RAD-L5-0627      6      6             O          0.143            2078.0             3.0     0.986903          1.807856   0.353602       0.707204   0.506979          1435.50      2.98    7.355887     5.811975   0.008745             0            0                0                1        0        0        0                 0               0.300007        153292.0             0.15
# RAD-L6-0745 RAD-L5-0737      6      6             O          0.119            2227.0             3.0     0.833171          1.648561   0.313561       0.627121   0.465873          1332.75      2.98   15.922238    10.965835   0.007231             0            0                0                1        0        0        0                 0               0.300006        151138.0             0.15
# RAD-L6-0665 RAD-L5-0664      6      6             O          0.113            2083.0             2.0     0.876171          1.691647   0.310043       0.620086   0.462102          1233.00      2.98   12.199689     9.837968   0.006614             0            0                0                1        0        0        0                 0               0.300006        127651.0             0.15
# RAD-L6-0587 RAD-L5-0580      6      6             O          0.143            1956.0             3.0     0.974026          1.793942   0.309484       0.618969   0.461500          4635.00      2.98   11.871844     7.858115   0.024620             0            0                0                1        0        0        0                 0               0.300006        189677.0             0.15
# RAD-L6-0702 RAD-L5-0700      6      6             O          0.143            2418.0             2.0     1.150639          1.994480   0.303738       0.607476   0.455276          1466.25      2.98    5.493638     4.154904   0.007663             0            0                0                1        0        0        0                 0               0.300006        112679.0             0.15
# RAD-L6-0740 RAD-L5-0737      6      6             O          0.106            1810.0             2.0     0.797439          1.613593   0.298086       0.596171   0.449083           982.50      2.98    9.218138     6.263835   0.005062             0            0                0                1        0        0        0                 0               0.300006        149543.0             0.15
# RAD-L6-0631 RAD-L5-0627      6      6             O          0.109            1946.0             3.0     0.740005          1.558935   0.284971       0.569943   0.434442          6352.50      2.98   11.220056     8.704654   0.031055             1            1                1                1        0        0        1                 1               0.300005        253682.0             0.15
# RAD-L6-0603 RAD-L5-0600      6      6             O          0.127            2464.0             2.0     1.025836          1.850585   0.282412       0.564824   0.431540          1446.00      2.98   12.989194    10.348646   0.007057             0            0                0                1        0        0        0                 0               0.300005        114473.0             0.15
# RAD-L6-0648 RAD-L5-0645      6      6             O          0.100            2114.0             3.0     0.690701          1.513494   0.282208       0.564415   0.431307          3423.00      2.98   14.851444    11.207077   0.016610             0            0                0                1        0        0        0                 0               0.300005        293062.0             0.15
# RAD-L6-0772 RAD-L5-0764      6      6             O          0.141            1939.0             3.0     0.958538          1.777349   0.281843       0.563687   0.430893          4479.00      2.98    8.340151     6.039198   0.021660             0            0                0                1        0        0        0                 0               0.300005        232525.0             0.15
#
# [TOP unmanaged but high baseline-wait parts | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  rad_deg_index  annual_rad_hours  env_resistance  aging_index  aging_multiplier  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0103 RAD-L5-0096      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.082179       0.164358   0.151562          6552.00      2.98    7.635225     6.464073   0.009233             1            1                0                0        0        0        0                 0                6552.00        190682.0             0.15
# RAD-L6-0162 RAD-L5-0160      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.108409       0.216818   0.194924          6521.25      2.98   14.417814    10.577072   0.012131             1            1                0                0        0        0        0                 0                6521.25        239094.0             0.15
# RAD-L6-0639 RAD-L5-0636      6      6             O          0.126            2303.0             3.0     0.889658          1.705392   0.147646       0.295291   0.255685          6459.00      2.98   12.151181     9.848678   0.016362             1            1                1                0        0        0        0                 0                6459.00        268293.0             0.15
# RAD-L6-0797 RAD-L5-0791      6      6             O          0.105            2223.0             2.0     0.825763          1.641249   0.155776       0.311551   0.267690          6401.25      2.98   18.156938    13.814015   0.017119             1            1                1                0        0        0        0                 0                6401.25        155057.0             0.15
# RAD-L6-0326 RAD-L5-0325      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.091389       0.182779   0.167048          6382.50      2.98   13.315088    11.521704   0.010011             1            1                0                0        0        0        0                 0                6382.50        282101.0             0.15
# RAD-L6-0785 RAD-L5-0782      6      6             O          0.064            2038.0             3.0     0.435978          1.298990   0.036860       0.073719   0.071067          6289.50      2.98    4.096950     3.153471   0.003974             1            0                0                0        0        0        0                 0                6289.50        482305.0             0.15
# RAD-L6-0102 RAD-L5-0096      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.035740       0.071480   0.068985          6192.75      2.98   11.592506     8.618008   0.003797             1            0                0                0        0        0        0                 0                6192.75        150323.0             0.15
# RAD-L6-0826 RAD-L5-0819      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.016105       0.032210   0.031696          6130.50      2.98   11.711701    10.633187   0.001694             1            0                0                0        0        0        0                 0                6130.50        127471.0             0.15
# RAD-L6-0723 RAD-L5-0718      6      6             O          0.071            1990.0             2.0     0.542163          1.384443   0.158186       0.316373   0.271212          6091.50      2.98    5.323501     4.683676   0.016521             1            1                1                0        0        0        0                 0                6091.50        376812.0             0.15
# RAD-L6-0466 RAD-L5-0462      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.119894       0.239788   0.213206          5804.25      2.98   10.691364     7.542879   0.011938             1            1                0                0        0        0        0                 0                5804.25        201275.0             0.15
# RAD-L6-0209 RAD-L5-0205      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.106656       0.213312   0.192096          5767.50      2.98   13.841102    11.992088   0.010561             1            1                0                0        0        0        0                 0                5767.50        126949.0             0.15
# RAD-L6-0888 RAD-L5-0886      6      6             O          0.001               0.0             4.0     0.000000          1.000000   0.027522       0.055044   0.053557          5742.75      2.98   11.685619     8.511944   0.002712             1            0                0                0        0        0        0                 0                5742.75        208983.0             0.15
# RAD-L6-0593 RAD-L5-0591      6      6             O          0.061            2102.0             2.0     0.470330          1.326042   0.038356       0.076713   0.073844          5706.00      2.98    8.274827     7.718882   0.003755             1            0                0                0        0        0        0                 0                5706.00        193315.0             0.15
# RAD-L6-0174 RAD-L5-0169      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.080681       0.161363   0.149017          5569.50      2.98   15.748689    14.281090   0.007718             1            1                0                0        0        0        0                 0                5569.50        206012.0             0.15
# RAD-L6-0465 RAD-L5-0462      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.020217       0.040434   0.039628          5513.25      2.98    6.564431     4.468487   0.001911             1            0                0                0        0        0        0                 0                5513.25        202465.0             0.15
#
# [TOP protection candidates | representative target]
#     Part_ID   Parent_ID  Level  Depth Maint_Echelon  rad_deg_index  annual_rad_hours  env_resistance  aging_index  aging_multiplier  annual_FR  lambda_eff_2y  p_need_2y  baseline_wait_h  T_diag_h  T_repair_h  T_restore_h  ao_impact  is_long_lead  prebuy_flag  protection_flag  selected_manage  sO_best  sI_best  sD_best  total_stock_best  wait_per_failure_best  unit_proc_cost  critical_weight
# RAD-L6-0631 RAD-L5-0627      6      6             O          0.109            1946.0             3.0     0.740005          1.558935   0.284971       0.569943   0.434442          6352.50      2.98   11.220056     8.704654   0.031055             1            1                1                1        0        0        1                 1               0.300005        253682.0             0.15
# RAD-L6-0747 RAD-L5-0746      6      6             O          0.108            2388.0             3.0     0.768308          1.585635   0.263303       0.526606   0.409394          5968.50      2.98   12.058069     8.719334   0.026962             1            1                1                1        1        0        0                 1               0.300000        398886.0             0.15
# RAD-L6-0640 RAD-L5-0636      6      6             O          0.077            2242.0             3.0     0.537466          1.380547   0.259738       0.519476   0.405168          5965.50      2.98    9.074327     8.235088   0.026582             1            1                1                1        1        0        0                 1               0.300000        167349.0             0.15
# RAD-L6-0761 RAD-L5-0755      6      6             O          0.106            2215.0             2.0     0.833000          1.648392   0.222794       0.445589   0.359553          6614.25      2.98    9.357806     6.342833   0.025269             1            1                1                1        1        0        0                 1               0.300000        306479.0             0.15
# RAD-L6-0642 RAD-L5-0636      6      6             O          0.067            2528.0             2.0     0.540875          1.383373   0.249350       0.498700   0.392681          5774.25      2.98    7.542112     5.376862   0.024690             1            1                1                1        1        0        0                 1               0.300000        333830.0             0.15
# RAD-L6-0744 RAD-L5-0737      6      6             O          0.087            1839.0             2.0     0.655226          1.481620   0.233810       0.467619   0.373508          5873.25      2.98    7.497263     5.371874   0.023548             1            1                1                1        1        0        0                 1               0.300000        134558.0             0.15
# RAD-L6-0692 RAD-L5-0691      6      6             O          0.103            1892.0             2.0     0.781650          1.598379   0.227552       0.455104   0.365618          5689.50      2.98   11.918400     8.494386   0.022213             1            1                1                1        1        0        0                 1               0.300000        267571.0             0.15
# RAD-L6-0733 RAD-L5-0727      6      6             O          0.128            2406.0             2.0     1.027818          1.852787   0.222512       0.445023   0.359191          5681.25      2.98   14.311053    11.957099   0.021703             1            1                1                1        1        0        0                 1               0.300000        301892.0             0.15
# RAD-L6-0217 RAD-L5-0214      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.191592       0.383184   0.318313          6463.50      2.98    7.495556     5.305444   0.021232             1            1                1                1        0        0        1                 1               0.300004        132367.0             0.15
# RAD-L6-0153 RAD-L5-0151      6      6             O          0.001               0.0             1.0     0.000000          1.000000   0.195979       0.391958   0.324268          6088.50      2.98   19.088062    12.697607   0.020484             1            1                1                1        1        0        0                 1               0.300000        326534.0             0.15
# RAD-L6-0661 RAD-L5-0654      6      6             O          0.112            2202.0             3.0     0.781683          1.598411   0.210045       0.420091   0.343013          5646.00      2.98   10.824451     7.882488   0.020346             1            1                1                1        1        0        0                 1               0.300000        210507.0             0.15
# RAD-L6-0811 RAD-L5-0810      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.189339       0.378678   0.315234          6186.75      2.98    5.400525     4.079621   0.020081             1            1                1                1        1        0        0                 1               0.300000        285020.0             0.15
# RAD-L6-0863 RAD-L5-0855      6      6             O          0.001               0.0             5.0     0.000000          1.000000   0.184533       0.369066   0.308620          5985.00      2.98    4.117426     3.777800   0.018933             1            1                1                1        1        0        0                 1               0.300000        145640.0             0.15
# RAD-L6-0994 RAD-L5-0986      6      6             O          0.001               0.0             4.0     0.000000          1.000000   0.186203       0.372406   0.310925          5922.00      2.98   10.801050     8.045831   0.018917             1            1                1                1        1        0        0                 1               0.300000        183052.0             0.15
# RAD-L6-0229 RAD-L5-0224      6      6             O          0.001               0.0             2.0     0.000000          1.000000   0.173776       0.347551   0.293584          6276.75      2.98    5.916301     4.767444   0.018700             1            1                1                1        1        0        0                 1               0.300000        424589.0             0.15
